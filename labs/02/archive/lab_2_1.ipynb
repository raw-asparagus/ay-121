# %%
import os
from dataclasses import dataclass, replace
from pathlib import Path
from typing import Callable, Mapping, Sequence

import numpy as np
import matplotlib.pyplot as plt

from ugradiolab import Spectrum, SpectrumPlot

plt.rcParams['figure.dpi'] = 300
# Out:
# /Users/junruiting/GitHub/ay-121/.venv/lib/python3.14/site-packages/rtlsdr/__init__.py:19: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
def apply_power_boost_db(
    spectra: Sequence[Spectrum],
    boost_db: float,
) -> list[Spectrum]:
    """Apply a flat power boost in dB to Spectrum PSD and uncertainties."""
    scale = 10.0 ** (boost_db / 10.0)
    return [
        replace(
            spectrum,
            psd=np.asarray(spectrum.psd, dtype=float) * scale,
            std=np.asarray(spectrum.std, dtype=float) * scale,
        )
        for spectrum in spectra
    ]


def load_spectra_cached(data_dir) -> list[Spectrum]:
    """Load pre-built Spectrum products generated by the complete-preview notebook."""
    data_path = Path(data_dir)
    spectra_dir = data_path if data_path.name.endswith('_spectra') else data_path.parent / f"{data_path.name}_spectra"

    spectra_files = sorted(spectra_dir.glob('*.npz'))

    print(f"Loading pre-processed Spectrum from {spectra_dir}")
    return [Spectrum.load(path) for path in spectra_files]


def select_spectrum_by_center_freq(
    spectra: Sequence[Spectrum],
    center_freq_hz: float,
    tol_hz: float = 0.5e6,
) -> Spectrum:
    """Return the spectrum whose centre frequency is nearest the target."""
    matches = [
        spectrum for spectrum in spectra
        if abs(spectrum.center_freq - center_freq_hz) < tol_hz
    ]
    return min(matches, key=lambda spectrum: abs(spectrum.center_freq - center_freq_hz))


def select_spectra_by_center_freq(
    spectra: Sequence[Spectrum],
    center_freqs_hz: Sequence[float],
    tol_hz: float = 0.5e6,
) -> dict[float, Spectrum]:
    """Return spectra keyed by requested centre frequency."""
    return {
        center_freq_hz: select_spectrum_by_center_freq(
            spectra,
            center_freq_hz,
            tol_hz=tol_hz,
        )
        for center_freq_hz in center_freqs_hz
    }


@dataclass(frozen=True)
class YFactorMeasurement:
    center_freq_hz: float
    p_hot: float
    sigma_p_hot: float
    p_cold: float
    sigma_p_cold: float
    y: float
    sigma_y: float
    y_db: float
    sigma_y_db: float
    t_rx_k: float
    sigma_t_rx_meas_k: float
    sigma_t_rx_total_k: float
    t_hot_k: float
    sigma_t_hot_k: float
    t_cold_k: float
    sigma_t_cold_k: float

    @property
    def center_freq_mhz(self) -> int:
        return int(round(self.center_freq_hz / 1e6))

    def as_row(self) -> dict[str, float]:
        return {
            "LO_MHz": self.center_freq_mhz,
            "P_hot": self.p_hot,
            "sigma_P_hot": self.sigma_p_hot,
            "P_cold": self.p_cold,
            "sigma_P_cold": self.sigma_p_cold,
            "Y": self.y,
            "sigma_Y": self.sigma_y,
            "Y_dB": self.y_db,
            "sigma_Y_dB": self.sigma_y_db,
            "T_rx_K": self.t_rx_k,
            "sigma_T_rx_meas_K": self.sigma_t_rx_meas_k,
            "sigma_T_rx_total_K": self.sigma_t_rx_total_k,
            "T_hot_K": self.t_hot_k,
            "sigma_T_hot_K": self.sigma_t_hot_k,
            "T_cold_K": self.t_cold_k,
            "sigma_T_cold_K": self.sigma_t_cold_k,
        }


def receiver_temperature_from_y(y: float, t_hot_k: float, t_cold_k: float) -> float:
    """Receiver temperature from the Y-factor relation."""
    return (t_hot_k - y * t_cold_k) / (y - 1.0)


def measure_y_factor(
    hot: Spectrum,
    cold: Spectrum,
    *,
    t_hot_k: float,
    sigma_t_hot_k: float,
    t_cold_k: float,
    sigma_t_cold_k: float,
) -> YFactorMeasurement:
    """Measure Y-factor and propagated receiver temperature uncertainties."""
    p_hot = float(hot.total_power)
    p_cold = float(cold.total_power)
    sigma_p_hot = hot.total_power_sigma
    sigma_p_cold = cold.total_power_sigma

    y = p_hot / p_cold
    sigma_y = y * np.sqrt(
        (sigma_p_hot / p_hot) ** 2 + (sigma_p_cold / p_cold) ** 2
    )
    y_db = 10.0 * np.log10(y)
    sigma_y_db = (10.0 / np.log(10.0)) * (sigma_y / y)

    t_rx_k = receiver_temperature_from_y(y, t_hot_k, t_cold_k)
    d_tdy = (t_cold_k - t_hot_k) / (y - 1.0) ** 2
    d_tdth = 1.0 / (y - 1.0)
    d_tdtc = -y / (y - 1.0)

    sigma_t_rx_meas_k = abs(d_tdy) * sigma_y
    sigma_t_rx_total_k = float(np.sqrt(
        (d_tdy * sigma_y) ** 2
        + (d_tdth * sigma_t_hot_k) ** 2
        + (d_tdtc * sigma_t_cold_k) ** 2
    ))

    return YFactorMeasurement(
        center_freq_hz=hot.center_freq,
        p_hot=p_hot,
        sigma_p_hot=sigma_p_hot,
        p_cold=p_cold,
        sigma_p_cold=sigma_p_cold,
        y=y,
        sigma_y=float(sigma_y),
        y_db=float(y_db),
        sigma_y_db=float(sigma_y_db),
        t_rx_k=float(t_rx_k),
        sigma_t_rx_meas_k=float(sigma_t_rx_meas_k),
        sigma_t_rx_total_k=sigma_t_rx_total_k,
        t_hot_k=float(t_hot_k),
        sigma_t_hot_k=float(sigma_t_hot_k),
        t_cold_k=float(t_cold_k),
        sigma_t_cold_k=float(sigma_t_cold_k),
    )


def measure_y_factor_series(
    hot_spectra: Sequence[Spectrum],
    cold_spectra: Sequence[Spectrum],
    *,
    center_freqs_hz: Sequence[float],
    t_hot_k: float,
    sigma_t_hot_k: float,
    t_cold_k: Mapping[int | float, float],
    sigma_t_cold_k: Mapping[int | float, float],
    tol_hz: float = 0.5e6,
) -> list[YFactorMeasurement]:
    """Measure Y-factor quantities across multiple LO settings."""
    measurements = []
    for center_freq_hz in center_freqs_hz:
        hot = select_spectrum_by_center_freq(
            hot_spectra,
            center_freq_hz,
            tol_hz=tol_hz,
        )
        cold = select_spectrum_by_center_freq(
            cold_spectra,
            center_freq_hz,
            tol_hz=tol_hz,
        )
        lo_mhz = int(round(center_freq_hz / 1e6))
        t_cold = _lookup_temperature(t_cold_k, center_freq_hz, lo_mhz)
        sigma_t_cold = _lookup_temperature(sigma_t_cold_k, center_freq_hz, lo_mhz)
        measurements.append(
            measure_y_factor(
                hot,
                cold,
                t_hot_k=t_hot_k,
                sigma_t_hot_k=sigma_t_hot_k,
                t_cold_k=t_cold,
                sigma_t_cold_k=sigma_t_cold,
            )
        )
    return measurements


def _lookup_temperature(
    values: Mapping[int | float, float],
    center_freq_hz: float,
    lo_mhz: int,
) -> float:
    if lo_mhz in values:
        return float(values[lo_mhz])
    if center_freq_hz in values:
        return float(values[center_freq_hz])
    raise KeyError(
        f"No temperature entry found for center_freq={center_freq_hz / 1e6:.0f} MHz"
    )

# %%
DATA_ROOT = os.path.join('..', '..', 'data', 'lab02')

STANDARD_SPECTRA_DIR = os.path.join(DATA_ROOT, 'standard_combined_spectra')
CYGNUS_SPECTRA_DIR = os.path.join(DATA_ROOT, 'cygnus-x_combined_spectra')
HUMAN_SPECTRA_DIR = os.path.join(DATA_ROOT, 'human_combined_spectra')
SGP_SPECTRA_DIR = os.path.join(DATA_ROOT, 'SGP_combined_spectra')

HUMAN_POWER_BOOST_DB = 12.0

# %%
LONG_DIR = STANDARD_SPECTRA_DIR

long_spectra = load_spectra_cached(LONG_DIR)
long_spectra.sort(key=lambda s: s.center_freq)

for spec in long_spectra:
    print(f'  LO={spec.center_freq/1e6:.0f} MHz  nblocks={spec.nblocks}  total_power={spec.total_power:.4f}')
# Out:
# Loading pre-processed Spectrum from ../../data/lab02/standard_combined_spectra
#   LO=1420 MHz  nblocks=32768  total_power=38.8252
#   LO=1421 MHz  nblocks=32768  total_power=37.0380

# %%
target_center_freqs_hz = [1420e6, 1421e6]
selected_long = select_spectra_by_center_freq(long_spectra, target_center_freqs_hz, tol_hz=0.5e6)
spec_plots = [SpectrumPlot.coerce(selected_long[center_freq_hz]) for center_freq_hz in target_center_freqs_hz]

smoothing_methods = [
    ('Rectangular (boxcar)',  dict(method='boxcar',   M=128)),
    ('Gaussian',              dict(method='gaussian', sigma=64)),
    ('Savitzky-Golay',        dict(method='savgol',   window_length=257, polyorder=3)),
]

for title, kwargs in smoothing_methods:
    fig, axes = plt.subplots(1, 2, figsize=(11, 3), dpi=300, sharey=True)
    for idx, (ax, spec_plot, label) in enumerate(zip(axes, spec_plots, ['1420 MHz', '1421 MHz'])):
        spec_plot.plot_psd(
            ax=ax,
            title=f'LO = {label}',
            smooth_kwargs=kwargs,
            mask_dc=True,
            x_mode='absolute',
            yscale='log',
            color='C0',
            smooth_color='C0',
            raw_label='raw',
            smooth_label='smoothed',
            ylabel='PSD (counts²/Hz)' if idx == 0 else None,
            legend=(idx == 0),
            legend_fontsize=8,
            title_loc='left',
            raw_linewidth=0.5,
            raw_alpha=0.35,
            smooth_linewidth=1.2,
        )

    fig.suptitle(title)
    fig.tight_layout()
    plt.show()

# %%
if not long_spectra:
    raise ValueError('No spectra found in LONG_DIR. Run lab_2_0_complete_preview.ipynb first.')

axes = SpectrumPlot.plot_stack(
    long_spectra,
    title='LO: 1420 & 1421 MHz over 8192 blocks',
    show_std=True,
    mask_dc=True,
    x_mode='absolute',
    yscale='linear',
    panel_title_fn=lambda plot: f'LO = {plot.center_freq/1e6:.0f} MHz  (nblocks={plot.nblocks})',
    panel_title_loc='left',
)
axes[0].figure.tight_layout()
plt.show()

# %%
CYGNUS_DIR = CYGNUS_SPECTRA_DIR

cygnus_spectra = load_spectra_cached(CYGNUS_DIR)
cygnus_spectra.sort(key=lambda s: s.center_freq)

for spec in cygnus_spectra:
    print(f'  LO={spec.center_freq/1e6:.0f} MHz  nblocks={spec.nblocks}  total_power={spec.total_power:.4f}')
# Out:
# Loading pre-processed Spectrum from ../../data/lab02/cygnus-x_combined_spectra
#   LO=1420 MHz  nblocks=32768  total_power=44.3148
#   LO=1421 MHz  nblocks=32768  total_power=43.7444

# %%
if not cygnus_spectra:
    raise ValueError('No spectra found in CYGNUS_DIR. Run lab_2_0_complete_preview.ipynb first.')

axes = SpectrumPlot.plot_stack(
    cygnus_spectra,
    title='Cygnus-X PSD',
    show_std=True,
    mask_dc=True,
    x_mode='absolute',
    yscale='linear',
    panel_title_fn=lambda plot: f'LO = {plot.center_freq/1e6:.0f} MHz  (nblocks={plot.nblocks})',
    panel_title_loc='left',
)
axes[0].figure.tight_layout()
plt.show()

# %%
target_center_freqs_hz = [1420e6, 1421e6]
savgol_kwargs = dict(method='savgol', window_length=257, polyorder=3)

standard_by_lo = select_spectra_by_center_freq(long_spectra, target_center_freqs_hz, tol_hz=0.5e6)
cygnus_by_lo = select_spectra_by_center_freq(cygnus_spectra, target_center_freqs_hz, tol_hz=0.5e6)

fig, axes = plt.subplots(2, 1, figsize=(11, 5.5), dpi=300, sharex=True, sharey=True)

for idx, (ax, center_freq_hz) in enumerate(zip(axes, target_center_freqs_hz)):
    SpectrumPlot.coerce(standard_by_lo[center_freq_hz]).plot_compare(
        cygnus_by_lo[center_freq_hz],
        ax=ax,
        title=f'LO = {center_freq_hz/1e6:.0f} MHz',
        labels=('Standard', 'Cygnus-X'),
        colors=('C0', 'C1'),
        smooth_kwargs=savgol_kwargs,
        show_std=True,
        mask_dc=True,
        x_mode='absolute',
        yscale='log',
        ylabel='PSD (counts²/Hz)' if idx == 0 else None,
        legend=(idx == 0),
        legend_fontsize=8,
        title_loc='left',
    )

x_min, x_max, y_min, y_max = SpectrumPlot.shared_limits(
    [*standard_by_lo.values(), *cygnus_by_lo.values()],
    smooth_kwargs=savgol_kwargs,
    show_std=True,
    mask_dc=True,
    x_mode='absolute',
    yscale='log',
)
axes[0].set_xlim(x_min, x_max)
axes[0].set_ylim(y_min, y_max)
fig.suptitle('Savitzky-Golay smoothed PSD: Standard vs Cygnus-X (with raw + ±std)')
fig.tight_layout()
plt.show()

# %%
HUMAN_DIR = HUMAN_SPECTRA_DIR

human_spectra = load_spectra_cached(HUMAN_DIR)
human_spectra.sort(key=lambda s: s.center_freq)

human_spectra_boosted = apply_power_boost_db(human_spectra, HUMAN_POWER_BOOST_DB)
human_spectra_boosted.sort(key=lambda s: s.center_freq)

print(f'Applying flat human boost: +{HUMAN_POWER_BOOST_DB:.1f} dB')
for raw_spec, boosted_spec in zip(human_spectra, human_spectra_boosted):
    gain_db = 10.0 * np.log10(boosted_spec.total_power / raw_spec.total_power)
    print(
        f'  LO={raw_spec.center_freq/1e6:.0f} MHz  '
        f'raw={raw_spec.total_power:.4f}  boosted={boosted_spec.total_power:.4f}  '
        f'({gain_db:+.3f} dB)'
    )
# Out:
# Loading pre-processed Spectrum from ../../data/lab02/human_combined_spectra
# Applying flat human boost: +12.0 dB
#   LO=1420 MHz  raw=110.4312  boosted=1750.2165  (+12.000 dB)
#   LO=1421 MHz  raw=107.4256  boosted=1702.5808  (+12.000 dB)

# %%
if not human_spectra_boosted:
    raise ValueError('No spectra found in HUMAN_DIR. Run lab_2_0_complete_preview.ipynb first.')

axes = SpectrumPlot.plot_stack(
    human_spectra_boosted,
    title='Human combined PSD (+12 dB boost)',
    show_std=True,
    mask_dc=True,
    x_mode='absolute',
    yscale='linear',
    panel_title_fn=lambda plot: f'LO = {plot.center_freq/1e6:.0f} MHz  (nblocks={plot.nblocks})',
    panel_title_loc='left',
)
axes[0].figure.tight_layout()
plt.show()

# %%
SGP_DIR = SGP_SPECTRA_DIR

sgp_spectra = load_spectra_cached(SGP_DIR)
sgp_spectra.sort(key=lambda s: s.center_freq)

for spec in sgp_spectra:
    print(f'  LO={spec.center_freq/1e6:.0f} MHz  nblocks={spec.nblocks}  total_power={spec.total_power:.4f}')
# Out:
# Loading pre-processed Spectrum from ../../data/lab02/SGP_combined_spectra
#   LO=1420 MHz  nblocks=32768  total_power=816.4308
#   LO=1421 MHz  nblocks=32768  total_power=773.9379

# %%
if not sgp_spectra:
    raise ValueError('No spectra found in SGP_DIR. Run lab_2_0_complete_preview.ipynb first.')

axes = SpectrumPlot.plot_stack(
    sgp_spectra,
    title='SGP PSD',
    show_std=True,
    mask_dc=True,
    x_mode='absolute',
    yscale='linear',
    panel_title_fn=lambda plot: f'LO = {plot.center_freq/1e6:.0f} MHz  (nblocks={plot.nblocks})',
    panel_title_loc='left',
)
axes[0].figure.tight_layout()
plt.show()

# %%
target_center_freqs_hz = [1420e6, 1421e6]
savgol_kwargs = dict(method='savgol', window_length=257, polyorder=3)

human_by_lo = select_spectra_by_center_freq(human_spectra_boosted, target_center_freqs_hz, tol_hz=0.5e6)
sgp_by_lo = select_spectra_by_center_freq(sgp_spectra, target_center_freqs_hz, tol_hz=0.5e6)

fig, axes = plt.subplots(2, 1, figsize=(11, 5.5), dpi=300, sharex=True, sharey=True)

for idx, (ax, center_freq_hz) in enumerate(zip(axes, target_center_freqs_hz)):
    SpectrumPlot.coerce(human_by_lo[center_freq_hz]).plot_compare(
        sgp_by_lo[center_freq_hz],
        ax=ax,
        title=f'LO = {center_freq_hz/1e6:.0f} MHz',
        labels=(f'Human (+{HUMAN_POWER_BOOST_DB:.0f} dB)', 'SGP'),
        colors=('C0', 'C1'),
        smooth_kwargs=savgol_kwargs,
        show_std=True,
        mask_dc=True,
        x_mode='absolute',
        yscale='log',
        ylabel='PSD (counts²/Hz)' if idx == 0 else None,
        legend=(idx == 0),
        legend_fontsize=8,
        title_loc='left',
    )

x_min, x_max, y_min, y_max = SpectrumPlot.shared_limits(
    [*human_by_lo.values(), *sgp_by_lo.values()],
    smooth_kwargs=savgol_kwargs,
    show_std=True,
    mask_dc=True,
    x_mode='absolute',
    yscale='log',
)
axes[0].set_xlim(x_min, x_max)
axes[0].set_ylim(y_min, y_max)
fig.suptitle(f'Savitzky-Golay smoothed PSD: Human (+{HUMAN_POWER_BOOST_DB:.0f} dB) vs SGP (counts²/Hz)')
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Analysis
#
# Compute Y-factor and $T_{rx}$ from `human_combined_spectra` boosted by +12 dB (hot) and `SGP_combined_spectra` (cold), including propagated error bars.
#
# Prerequisite: run `lab_2_0_complete_preview.ipynb` first to generate cached Spectrum products.
#
# - Power error bars are propagated from `Spectrum.std` into total integrated power.
# - `T_{rx}` is reported with two uncertainties:
#   - measurement-only (from power/Y uncertainty)
#   - total (includes assumed $T_{hot}$ and $T_{cold}$ uncertainties)
#
# Edit the temperature assumptions in the next cell if needed.

# %%
# Y-factor and T_rx with propagated error bars
TARGET_CENTER_FREQS_HZ = [1420e6, 1421e6]
LO_TOL_HZ = 0.5e6

HUMAN_DIR = HUMAN_SPECTRA_DIR
SGP_DIR = SGP_SPECTRA_DIR

HUMAN_POWER_BOOST_DB = globals().get('HUMAN_POWER_BOOST_DB', 12.0)

if 'human_spectra_boosted' in globals() and len(human_spectra_boosted) > 0:
    hot_spectra = sorted(human_spectra_boosted, key=lambda s: s.center_freq)
else:
    _human_raw = load_spectra_cached(HUMAN_DIR)
    _human_raw.sort(key=lambda s: s.center_freq)
    hot_spectra = apply_power_boost_db(_human_raw, HUMAN_POWER_BOOST_DB)
    hot_spectra.sort(key=lambda s: s.center_freq)

if 'sgp_spectra' in globals() and len(sgp_spectra) > 0:
    cold_spectra = sorted(sgp_spectra, key=lambda s: s.center_freq)
else:
    cold_spectra = load_spectra_cached(SGP_DIR)
    cold_spectra.sort(key=lambda s: s.center_freq)

# Temperature assumptions (edit as needed)
T_HOT_K = 310.0
SIGMA_T_HOT_K = 1.0
T_COLD_K = {1420: 30.0, 1421: 12.0}
SIGMA_T_COLD_K = {1420: 10.0, 1421: 3.0}

measurements = measure_y_factor_series(
    hot_spectra,
    cold_spectra,
    center_freqs_hz=TARGET_CENTER_FREQS_HZ,
    t_hot_k=T_HOT_K,
    sigma_t_hot_k=SIGMA_T_HOT_K,
    t_cold_k=T_COLD_K,
    sigma_t_cold_k=SIGMA_T_COLD_K,
    tol_hz=LO_TOL_HZ,
)
rows = [measurement.as_row() for measurement in measurements]

print(f'Y-factor and T_rx summary (human boosted by +{HUMAN_POWER_BOOST_DB:.1f} dB)')
print('-' * 128)
print(' LO    P_hot ± sigma      P_cold ± sigma      Y ± sigma (dB)          T_rx ± sigma_meas ± sigma_total [K]')
print('-' * 128)
for measurement in measurements:
    print(
        f" {measurement.center_freq_mhz:4d}  "
        f"{measurement.p_hot:.6f} ± {measurement.sigma_p_hot:.6f}  "
        f"{measurement.p_cold:.6f} ± {measurement.sigma_p_cold:.6f}  "
        f"{measurement.y:.6f} ± {measurement.sigma_y:.6f} "
        f"({measurement.y_db:.4f} ± {measurement.sigma_y_db:.4f} dB)  "
        f"{measurement.t_rx_k:.3f} ± {measurement.sigma_t_rx_meas_k:.3f} ± {measurement.sigma_t_rx_total_k:.3f}"
    )

los = np.array([measurement.center_freq_mhz for measurement in measurements], dtype=float)
y_vals = np.array([measurement.y for measurement in measurements], dtype=float)
y_err = np.array([measurement.sigma_y for measurement in measurements], dtype=float)
trx_vals = np.array([measurement.t_rx_k for measurement in measurements], dtype=float)
trx_err_total = np.array([measurement.sigma_t_rx_total_k for measurement in measurements], dtype=float)

fig, axes = plt.subplots(2, 1, figsize=(7, 6), dpi=300)

axes[0].errorbar(los, y_vals, yerr=y_err, fmt='o', capsize=4, lw=1.0, color='C0')
axes[0].set_xlabel('LO (MHz)')
axes[0].set_ylabel('Y-factor')
axes[0].set_title('Y-factor with propagated uncertainty', fontsize=9, loc='left')
axes[0].grid(True, lw=0.4, alpha=0.5)

axes[1].errorbar(los, trx_vals, yerr=trx_err_total, fmt='s', capsize=4, lw=1.0, color='C1')
axes[1].set_xlabel('LO (MHz)')
axes[1].set_ylabel(r'$T_{rx}$ (K)')
axes[1].set_title('Receiver temperature with error bars', fontsize=9, loc='left')
axes[1].grid(True, lw=0.4, alpha=0.5)

fig.tight_layout()
plt.show()
# Out:
# Y-factor and T_rx summary (human boosted by +12.0 dB)
# --------------------------------------------------------------------------------------------------------------------------------
#  LO    P_hot ± sigma      P_cold ± sigma      Y ± sigma (dB)          T_rx ± sigma_meas ± sigma_total [K]
# --------------------------------------------------------------------------------------------------------------------------------
#  1420  1750.216482 ± 0.158577  816.430786 ± 0.035978  2.143741 ± 0.000216 (3.3117 ± 0.0004 dB)  214.811 ± 0.046 ± 18.764
#  1421  1702.580800 ± 0.154168  773.937866 ± 0.035652  2.199893 ± 0.000223 (3.4240 ± 0.0004 dB)  236.355 ± 0.046 ± 5.563
