# %% [markdown]
# # Solar Diameter and Sunspot Characterisation
#
# Measurement of the solar angular diameter from the Bessel-function modulation of fringe amplitude, and detection of sunspot signatures from visibility anomalies at the Bessel nulls.

# %%
from __future__ import annotations

import sys
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np

# -- local utilities ---------------------------------------------------------
sys.path.insert(0, str(Path("..").resolve()))
from utils import (
    # constants
    F_S_HZ, N_FFT, F_RF0_HZ, PLOT_BAND_GHZ,
    C_LIGHT_MS, OMEGA_EARTH_RAD_S, SIDEREAL_DAY_S,
    NCH_LAT_DEG, NCH_LON_DEG,
    NOMINAL_B_EW_M, BAD_CHANNELS,
    SOLAR_DIAMETER_ARCMIN_NOMINAL,
    # data loading
    load_processed_sun_chip_series,
    # geometry
    lst_deg, hour_angle_deg, hour_angle_rad,
    geometric_delay_s, projected_baseline_lambda,
    fringe_frequency_hz, fringe_period_s, x_coordinate,
    # fringe models
    FringeModelParams, SolarDiskParams, SunspotParams,
    point_source_visibility, point_source_fringes,
    uniform_disk_visibility_amplitude, uniform_disk_visibility_signed,
    uniform_disk_zeros, solar_visibility, fringe_envelope,
    # baseline fitting
    BaselineResult,
    fft_baseline_single_channel, fft_baseline_broadband,
    phase_slope_baseline_single_channel, phase_slope_baseline_broadband,
    lag_delay_single_capture, lag_delay_baseline_series,
    nls_baseline_single_channel, nls_baseline_broadband,
    combined_baseline,
    # solar analysis
    SolarDiameterResult, SunspotDetection,
    extract_fringe_envelope, find_bessel_zeros_in_envelope,
    solar_diameter_from_zeros, fit_solar_diameter_bessel,
    detect_sunspot_anomalies, characterize_sunspot_flux,
    # plotting
    PRIMARY_COLOR, SECONDARY_COLOR, TERTIARY_COLOR, QUATERNARY_COLOR,
    NEUTRAL_COLOR, COMPONENT_COLORS,
    SCATTER_S_FINE, SCATTER_S_STANDARD,
    LW_FINE, LW_GUIDE, LW_STANDARD, LW_MODEL,
    MARKER_MS_SMALL,
    TEXTWIDTH_IN, TICK_SIZE,
)
from utils.plotter import (
    plot_fringe_model_comparison,
    plot_bessel_envelope_fit,
    plot_solar_diameter_summary,
    plot_sunspot_residuals,
)

# %matplotlib inline
plt.rcParams.update({"figure.dpi": 130, "figure.facecolor": "white"})
print("Imports OK.")
# Out:
# Imports OK.

# %%
DATA_DIR = Path("../../../data/lab03/sun_calibration/chips")
chip_paths = sorted(DATA_DIR.glob("sun_calibration_chip_*.npz"))
print(f"Found {len(chip_paths)} chip files:")
for p in chip_paths:
    print(f"  {p.name}")

chip_data = load_processed_sun_chip_series(chip_paths)
# Out:
# Found 3 chip files:
#   sun_calibration_chip_00.npz
#   sun_calibration_chip_01.npz
#   sun_calibration_chip_02.npz

# %%
# -------------------------------------------------------------------
# Unpack key arrays
# -------------------------------------------------------------------
captures   = chip_data.captures          # CaptureSeries
corr_dc    = chip_data.corr_dc           # (N_cap, N_CH) complex, DC-corrected
F_SKY_GHZ  = chip_data.f_sky_ghz         # (N_CH,) sky frequency in GHz
DF_HZ      = chip_data.df_hz             # channel spacing in Hz

# Timing and coordinates (pre-computed in export)
unix_mid   = captures.unix_mid           # (N_cap,) midpoint timestamps
ha_deg_arr = chip_data.ha_deg
ha_rad_arr = np.deg2rad(ha_deg_arr)
sun_ra     = chip_data.sun_ra_deg        # (N_cap,) Sun RA in degrees
sun_dec    = chip_data.sun_dec_deg       # (N_cap,) Sun Dec in degrees

# Derived quantities
F_SKY_HZ   = F_SKY_GHZ * 1e9
dec_rad_mean = np.deg2rad(np.nanmean(sun_dec))

# Analysis band mask
band_mask = (F_SKY_GHZ >= PLOT_BAND_GHZ[0]) & (F_SKY_GHZ <= PLOT_BAND_GHZ[1])
band_center_hz = np.mean(F_SKY_HZ[band_mask])

# Chip boundaries (for per-chip analysis)
chip_slices = chip_data.chip_slices
N_chips = len(chip_slices)

print(f"Total captures:     {len(unix_mid)}")
print(f"Channels:           {len(F_SKY_GHZ)}  ({F_SKY_GHZ[0]:.3f} -- {F_SKY_GHZ[-1]:.3f} GHz)")
print(f"Analysis band:      {PLOT_BAND_GHZ[0]:.3f} -- {PLOT_BAND_GHZ[1]:.3f} GHz  ({band_mask.sum()} channels)")
print(f"Band centre:        {band_center_hz/1e9:.4f} GHz")
print(f"Mean Sun dec:       {np.rad2deg(dec_rad_mean):.3f} deg")
print(f"HA range:           {ha_deg_arr.min():.1f} to {ha_deg_arr.max():.1f} deg")
print(f"Chips:              {N_chips}")
# Out:
# Total captures:     8226
# Channels:           1024  (10.290 -- 10.540 GHz)
# Analysis band:      10.415 -- 10.485 GHz  (287 channels)
# Band centre:        10.4499 GHz
# Mean Sun dec:       -0.083 deg
# HA range:           -79.9 to 22.0 deg
# Chips:              3

# %%
# -------------------------------------------------------------------
# Compute baseline (needed for solar analysis)
# Run all four methods per chip + pooled across all chips, then combine.
# -------------------------------------------------------------------
band_hz = (PLOT_BAND_GHZ[0] * 1e9, PLOT_BAND_GHZ[1] * 1e9)
all_baseline_results = []

for ci, sl in enumerate(chip_slices):
    ha_chip = ha_rad_arr[sl]
    corr_chip = corr_dc[sl]
    dec_chip = np.deg2rad(np.nanmean(sun_dec[sl]))

    res_fft, _ = fft_baseline_broadband(
        ha_chip, corr_chip, dec_chip, F_SKY_HZ,
        bad_channels=BAD_CHANNELS, band_hz=band_hz,
    )
    res_ps, _ = phase_slope_baseline_broadband(
        ha_chip, corr_chip, dec_chip, F_SKY_HZ,
        bad_channels=BAD_CHANNELS, band_hz=band_hz,
    )
    res_lag = lag_delay_baseline_series(
        ha_chip, corr_chip, dec_chip, DF_HZ,
        bad_channels=BAD_CHANNELS,
    )
    res_nls, _ = nls_baseline_broadband(
        ha_chip, corr_chip, dec_chip, F_SKY_HZ,
        bad_channels=BAD_CHANNELS, band_hz=band_hz,
    )
    all_baseline_results.extend([res_fft, res_ps, res_lag, res_nls])

# Pooled (all chips combined)
res_fft_p, _ = fft_baseline_broadband(
    ha_rad_arr, corr_dc, dec_rad_mean, F_SKY_HZ,
    bad_channels=BAD_CHANNELS, band_hz=band_hz,
)
res_ps_p, _ = phase_slope_baseline_broadband(
    ha_rad_arr, corr_dc, dec_rad_mean, F_SKY_HZ,
    bad_channels=BAD_CHANNELS, band_hz=band_hz,
)
res_lag_p = lag_delay_baseline_series(
    ha_rad_arr, corr_dc, dec_rad_mean, DF_HZ,
    bad_channels=BAD_CHANNELS,
)
res_nls_p, _ = nls_baseline_broadband(
    ha_rad_arr, corr_dc, dec_rad_mean, F_SKY_HZ,
    bad_channels=BAD_CHANNELS, band_hz=band_hz,
)
all_baseline_results.extend([res_fft_p, res_ps_p, res_lag_p, res_nls_p])

combined = combined_baseline(all_baseline_results)
B_EW = combined.b_ew_m
B_NS = combined.b_ns_m if np.isfinite(combined.b_ns_m) else 0.0
print(f"Combined B_EW = {B_EW:.4f} +/- {combined.b_ew_err_m:.4f} m")
print(f"Combined B_NS = {B_NS:.4f} +/- {combined.b_ns_err_m:.4f} m")

# Nominal disk parameters
R_nominal = np.deg2rad(SOLAR_DIAMETER_ARCMIN_NOMINAL / 2.0 / 60.0)

# %% [markdown]
# # Part VI: Solar Diameter Measurement
#
# ## 6.1 Theory recap
#
# The fringe amplitude envelope is modulated by the Bessel function $|2J_1(x)/x|$ where $x = 2\pi|u|R$ and $R$ is the angular radius of the Sun. We extract the envelope from the data and fit it in two ways:
#
# 1. **Zero-crossing method** — locate the nulls in the amplitude envelope and use $R = j_{1,k}/(2\pi |u_k|)$.
# 2. **Full Bessel fit** — nonlinear least-squares fit of $A\,|2J_1(2\pi |u| R)/(2\pi |u| R)|$ to the envelope, fitting amplitude $A$ and radius $R$ simultaneously.
#
# ## 6.2 Amplitude envelope extraction
#
# We compute the band-averaged visibility amplitude $\langle|V(\nu,h)|\rangle_\nu$ at each capture as a function of projected baseline $|u|$.

# %%
# --- Extract fringe amplitude envelope ---
u_obs, env_obs, env_std = extract_fringe_envelope(
    ha_rad_arr, corr_dc, dec_rad_mean, B_EW, F_SKY_HZ,
    band_mask=band_mask,
    smooth_window=5,
)

# Quick view
fig, ax = plt.subplots(figsize=(TEXTWIDTH_IN, 2.8))
ax.scatter(np.abs(u_obs), env_obs, s=SCATTER_S_FINE, color=PRIMARY_COLOR, alpha=0.3,
           label="observed envelope")
ax.set_xlabel(r"Projected baseline $|u|$ [$\lambda$]")
ax.set_ylabel("Band-averaged amplitude")
ax.set_title("Fringe amplitude envelope", fontsize=TICK_SIZE)
ax.legend(fontsize=TICK_SIZE)
fig.tight_layout()
plt.show()

print(f"Projected baseline range: {np.abs(u_obs).min():.0f} -- {np.abs(u_obs).max():.0f} wavelengths")
# Out:
# Projected baseline range: 0 -- 515 wavelengths

# %% [markdown]
# ## 6.3 Method A: Diameter from Bessel zero crossings
#
# We search for local minima in the smoothed amplitude envelope to identify the Bessel nulls, then convert each null's projected baseline to an angular radius estimate.

# %%
# --- Method A: Zero-crossing diameter ---
u_zeros = find_bessel_zeros_in_envelope(u_obs, env_obs, smooth_window=11)

if len(u_zeros) > 0:
    diameter_zeros = solar_diameter_from_zeros(u_zeros)
    print(f"Detected {len(u_zeros)} null(s) at |u| = {np.abs(u_zeros)}")
    print(f"Zero-crossing diameter: {diameter_zeros.diameter_arcmin:.2f} +/- "
          f"{diameter_zeros.diameter_err_arcmin:.2f} arcmin")
    if "R_rad_per_null" in diameter_zeros.fitted_params:
        for k, (R_est, u_est) in enumerate(zip(
            diameter_zeros.fitted_params["R_rad_per_null"],
            diameter_zeros.fitted_params["u_observed"],
        )):
            print(f"  Null {k+1}: |u| = {u_est:.1f} lambda -> "
                  f"diameter = {np.rad2deg(2*R_est)*60:.2f} arcmin")
else:
    diameter_zeros = None
    print("No Bessel nulls detected in the envelope (baseline range may be insufficient).")
# Out:
# Detected 1039 null(s) at |u| = [3.72172961e-01 4.62491648e-01 1.03580261e+00 ... 4.82816859e+02
#  4.84239897e+02 4.86786266e+02]
# Zero-crossing diameter: 23402.07 +/- 122.92 arcmin
#   Null 1: |u| = 0.4 lambda -> diameter = 11266.04 arcmin
#   Null 2: |u| = 0.5 lambda -> diameter = 16599.08 arcmin
#   Null 3: |u| = 1.0 lambda -> diameter = 10747.71 arcmin
#   Null 4: |u| = 1.2 lambda -> diameter = 12480.74 arcmin
#   Null 5: |u| = 1.3 lambda -> diameter = 14108.42 arcmin
#   Null 6: |u| = 2.1 lambda -> diameter = 10443.44 arcmin
#   Null 7: |u| = 2.4 lambda -> diameter = 10223.09 arcmin
#   Null 8: |u| = 2.5 lambda -> diameter = 11202.25 arcmin
#   Null 9: |u| = 2.6 lambda -> diameter = 12099.01 arcmin
#   Null 10: |u| = 2.7 lambda -> diameter = 12942.66 arcmin
#   Null 11: |u| = 3.2 lambda -> diameter = 12091.50 arcmin
#   Null 12: |u| = 3.3 lambda -> diameter = 12755.69 arcmin
#   Null 13: |u| = 3.4 lambda -> diameter = 13437.86 arcmin
#   Null 14: |u| = 3.5 lambda -> diameter = 14056.59 arcmin
#   Null 15: |u| = 3.6 lambda -> diameter = 14644.09 arcmin
#   Null 16: |u| = 3.7 lambda -> diameter = 15204.55 arcmin
#   Null 17: |u| = 4.1 lambda -> diameter = 14631.03 arcmin
#   Null 18: |u| = 4.1 lambda -> diameter = 15126.38 arcmin
#   Null 19: |u| = 4.3 lambda -> diameter = 15557.30 arcmin
#   Null 20: |u| = 4.3 lambda -> diameter = 16038.26 arcmin
#   Null 21: |u| = 4.4 lambda -> diameter = 16469.38 arcmin
#   Null 22: |u| = 4.5 lambda -> diameter = 16886.04 arcmin
#   Null 23: |u| = 4.6 lambda -> diameter = 17280.50 arcmin
#   Null 24: |u| = 4.7 lambda -> diameter = 17632.04 arcmin
#   Null 25: |u| = 4.8 lambda -> diameter = 18029.26 arcmin
#   Null 26: |u| = 4.9 lambda -> diameter = 18371.99 arcmin
#   Null 27: |u| = 5.0 lambda -> diameter = 18707.20 arcmin
#   Null 28: |u| = 5.2 lambda -> diameter = 18660.93 arcmin
#   Null 29: |u| = 5.3 lambda -> diameter = 19002.84 arcmin
#   Null 30: |u| = 5.4 lambda -> diameter = 19303.29 arcmin
#   Null 31: |u| = 5.5 lambda -> diameter = 19590.84 arcmin
#   Null 32: |u| = 5.8 lambda -> diameter = 19227.05 arcmin
#   Null 33: |u| = 5.9 lambda -> diameter = 19497.58 arcmin
#   Null 34: |u| = 6.2 lambda -> diameter = 19122.38 arcmin
#   Null 35: |u| = 6.2 lambda -> diameter = 19405.90 arcmin
#   Null 36: |u| = 6.3 lambda -> diameter = 19661.27 arcmin
#   Null 37: |u| = 6.4 lambda -> diameter = 19903.47 arcmin
#   Null 38: |u| = 6.5 lambda -> diameter = 20095.32 arcmin
#   Null 39: |u| = 6.9 lambda -> diameter = 19612.92 arcmin
#   Null 40: |u| = 7.1 lambda -> diameter = 19358.61 arcmin
#   Null 41: |u| = 7.3 lambda -> diameter = 19557.10 arcmin
#   Null 42: |u| = 7.3 lambda -> diameter = 19786.31 arcmin
#   Null 43: |u| = 7.4 lambda -> diameter = 20000.66 arcmin
#   Null 44: |u| = 7.5 lambda -> diameter = 20208.53 arcmin
#   Null 45: |u| = 7.6 lambda -> diameter = 20401.57 arcmin
#   Null 46: |u| = 7.7 lambda -> diameter = 20577.91 arcmin
#   Null 47: |u| = 7.8 lambda -> diameter = 20787.50 arcmin
#   Null 48: |u| = 7.9 lambda -> diameter = 20964.37 arcmin
#   Null 49: |u| = 8.0 lambda -> diameter = 21151.57 arcmin
#   Null 50: |u| = 8.1 lambda -> diameter = 21325.21 arcmin
#   Null 51: |u| = 8.2 lambda -> diameter = 21478.27 arcmin
#   Null 52: |u| = 8.3 lambda -> diameter = 21665.60 arcmin
#   Null 53: |u| = 8.4 lambda -> diameter = 21826.60 arcmin
#   Null 54: |u| = 8.5 lambda -> diameter = 21987.67 arcmin
#   Null 55: |u| = 8.6 lambda -> diameter = 22109.16 arcmin
#   Null 56: |u| = 9.0 lambda -> diameter = 21417.05 arcmin
#   Null 57: |u| = 9.2 lambda -> diameter = 21375.75 arcmin
#   Null 58: |u| = 9.3 lambda -> diameter = 21521.63 arcmin
#   Null 59: |u| = 9.4 lambda -> diameter = 21702.56 arcmin
#   Null 60: |u| = 9.5 lambda -> diameter = 21850.76 arcmin
#   Null 61: |u| = 9.6 lambda -> diameter = 21989.61 arcmin
#   Null 62: |u| = 9.7 lambda -> diameter = 22124.20 arcmin
#   Null 63: |u| = 9.8 lambda -> diameter = 22241.24 arcmin
#   Null 64: |u| = 9.9 lambda -> diameter = 22398.94 arcmin
#   Null 65: |u| = 10.0 lambda -> diameter = 22530.13 arcmin
#   Null 66: |u| = 10.1 lambda -> diameter = 22656.77 arcmin
#   Null 67: |u| = 10.1 lambda -> diameter = 22784.57 arcmin
#   Null 68: |u| = 10.2 lambda -> diameter = 22891.67 arcmin
#   Null 69: |u| = 10.3 lambda -> diameter = 23029.97 arcmin
#   Null 70: |u| = 10.4 lambda -> diameter = 23150.87 arcmin
#   Null 71: |u| = 10.5 lambda -> diameter = 23266.82 arcmin
#   Null 72: |u| = 10.6 lambda -> diameter = 23381.53 arcmin
#   Null 73: |u| = 10.8 lambda -> diameter = 23350.84 arcmin
#   Null 74: |u| = 10.9 lambda -> diameter = 23433.21 arcmin
#   Null 75: |u| = 11.0 lambda -> diameter = 23510.95 arcmin
#   Null 76: |u| = 11.2 lambda -> diameter = 23490.90 arcmin
#   Null 77: |u| = 11.3 lambda -> diameter = 23570.44 arcmin
#   Null 78: |u| = 11.4 lambda -> diameter = 23626.21 arcmin
#   Null 79: |u| = 11.5 lambda -> diameter = 23732.36 arcmin
#   Null 80: |u| = 11.6 lambda -> diameter = 23759.84 arcmin
#   Null 81: |u| = 12.0 lambda -> diameter = 23247.41 arcmin
#   Null 82: |u| = 12.2 lambda -> diameter = 23264.49 arcmin
#   Null 83: |u| = 12.2 lambda -> diameter = 23379.63 arcmin
#   Null 84: |u| = 12.4 lambda -> diameter = 23418.52 arcmin
#   Null 85: |u| = 12.5 lambda -> diameter = 23445.49 arcmin
#   Null 86: |u| = 12.6 lambda -> diameter = 23477.19 arcmin
#   Null 87: |u| = 12.9 lambda -> diameter = 23238.72 arcmin
#   Null 88: |u| = 13.0 lambda -> diameter = 23333.46 arcmin
#   Null 89: |u| = 13.1 lambda -> diameter = 23410.74 arcmin
#   Null 90: |u| = 13.2 lambda -> diameter = 23515.21 arcmin
#   Null 91: |u| = 13.3 lambda -> diameter = 23605.68 arcmin
#   Null 92: |u| = 13.4 lambda -> diameter = 23697.79 arcmin
#   Null 93: |u| = 13.5 lambda -> diameter = 23782.70 arcmin
#   Null 94: |u| = 14.2 lambda -> diameter = 22892.33 arcmin
#   Null 95: |u| = 14.2 lambda -> diameter = 22994.80 arcmin
#   Null 96: |u| = 14.3 lambda -> diameter = 23081.87 arcmin
#   Null 97: |u| = 14.4 lambda -> diameter = 23169.77 arcmin
#   Null 98: |u| = 15.0 lambda -> diameter = 22516.07 arcmin
#   Null 99: |u| = 15.1 lambda -> diameter = 22592.03 arcmin
#   Null 100: |u| = 15.3 lambda -> diameter = 22580.56 arcmin
#   Null 101: |u| = 15.4 lambda -> diameter = 22655.10 arcmin
#   Null 102: |u| = 15.6 lambda -> diameter = 22479.32 arcmin
#   Null 103: |u| = 15.7 lambda -> diameter = 22542.92 arcmin
#   Null 104: |u| = 16.1 lambda -> diameter = 22224.48 arcmin
#   Null 105: |u| = 16.3 lambda -> diameter = 22215.24 arcmin
#   Null 106: |u| = 16.4 lambda -> diameter = 22297.82 arcmin
#   Null 107: |u| = 16.5 lambda -> diameter = 22377.12 arcmin
#   Null 108: |u| = 16.6 lambda -> diameter = 22454.44 arcmin
#   Null 109: |u| = 16.7 lambda -> diameter = 22524.18 arcmin
#   Null 110: |u| = 16.8 lambda -> diameter = 22610.00 arcmin
#   Null 111: |u| = 16.9 lambda -> diameter = 22688.10 arcmin
#   Null 112: |u| = 17.0 lambda -> diameter = 22765.68 arcmin
#   Null 113: |u| = 17.0 lambda -> diameter = 22836.90 arcmin
#   Null 114: |u| = 17.3 lambda -> diameter = 22745.77 arcmin
#   Null 115: |u| = 17.4 lambda -> diameter = 22826.15 arcmin
#   Null 116: |u| = 17.5 lambda -> diameter = 22859.96 arcmin
#   Null 117: |u| = 17.6 lambda -> diameter = 22941.10 arcmin
#   Null 118: |u| = 17.7 lambda -> diameter = 23001.25 arcmin
#   Null 119: |u| = 17.8 lambda -> diameter = 23079.97 arcmin
#   Null 120: |u| = 17.9 lambda -> diameter = 23153.11 arcmin
#   Null 121: |u| = 17.9 lambda -> diameter = 23222.32 arcmin
#   Null 122: |u| = 18.1 lambda -> diameter = 23271.30 arcmin
#   Null 123: |u| = 18.3 lambda -> diameter = 23142.57 arcmin
#   Null 124: |u| = 18.7 lambda -> diameter = 22884.55 arcmin
#   Null 125: |u| = 18.8 lambda -> diameter = 22943.03 arcmin
#   Null 126: |u| = 18.9 lambda -> diameter = 23016.83 arcmin
#   Null 127: |u| = 19.0 lambda -> diameter = 23084.29 arcmin
#   Null 128: |u| = 19.0 lambda -> diameter = 23149.28 arcmin
#   Null 129: |u| = 19.1 lambda -> diameter = 23213.40 arcmin
#   Null 130: |u| = 19.2 lambda -> diameter = 23270.47 arcmin
#   Null 131: |u| = 19.3 lambda -> diameter = 23340.29 arcmin
#   Null 132: |u| = 19.4 lambda -> diameter = 23401.75 arcmin
#   Null 133: |u| = 19.5 lambda -> diameter = 23465.75 arcmin
#   Null 134: |u| = 19.6 lambda -> diameter = 23526.70 arcmin
#   Null 135: |u| = 19.7 lambda -> diameter = 23581.52 arcmin
#   Null 136: |u| = 19.8 lambda -> diameter = 23651.59 arcmin
#   Null 137: |u| = 19.9 lambda -> diameter = 23708.44 arcmin
#   Null 138: |u| = 20.0 lambda -> diameter = 23765.53 arcmin
#   Null 139: |u| = 20.1 lambda -> diameter = 23825.10 arcmin
#   Null 140: |u| = 20.2 lambda -> diameter = 23876.90 arcmin
#   Null 141: |u| = 20.3 lambda -> diameter = 23941.82 arcmin
#   Null 142: |u| = 20.4 lambda -> diameter = 23999.60 arcmin
#   Null 143: |u| = 20.5 lambda -> diameter = 24056.29 arcmin
#   Null 144: |u| = 20.6 lambda -> diameter = 24110.58 arcmin
#   Null 145: |u| = 20.7 lambda -> diameter = 24157.56 arcmin
#   Null 146: |u| = 20.8 lambda -> diameter = 24220.53 arcmin
#   Null 147: |u| = 20.9 lambda -> diameter = 24273.71 arcmin
#   Null 148: |u| = 20.9 lambda -> diameter = 24327.57 arcmin
#   Null 149: |u| = 21.0 lambda -> diameter = 24384.25 arcmin
#   Null 150: |u| = 21.1 lambda -> diameter = 24427.59 arcmin
#   Null 151: |u| = 21.2 lambda -> diameter = 24489.02 arcmin
#   Null 152: |u| = 21.3 lambda -> diameter = 24541.04 arcmin
#   Null 153: |u| = 21.4 lambda -> diameter = 24592.77 arcmin
#   Null 154: |u| = 21.5 lambda -> diameter = 24643.01 arcmin
#   Null 155: |u| = 21.6 lambda -> diameter = 24683.31 arcmin
#   Null 156: |u| = 21.7 lambda -> diameter = 24743.02 arcmin
#   Null 157: |u| = 21.8 lambda -> diameter = 24793.28 arcmin
#   Null 158: |u| = 21.9 lambda -> diameter = 24844.39 arcmin
#   Null 159: |u| = 22.0 lambda -> diameter = 24891.68 arcmin
#   Null 160: |u| = 22.1 lambda -> diameter = 24930.88 arcmin
#   Null 161: |u| = 22.2 lambda -> diameter = 24988.29 arcmin
#   Null 162: |u| = 22.3 lambda -> diameter = 25034.69 arcmin
#   Null 163: |u| = 22.4 lambda -> diameter = 25082.63 arcmin
#   Null 164: |u| = 22.5 lambda -> diameter = 25129.77 arcmin
#   Null 165: |u| = 22.6 lambda -> diameter = 25165.69 arcmin
#   Null 166: |u| = 22.7 lambda -> diameter = 25220.72 arcmin
#   Null 167: |u| = 22.8 lambda -> diameter = 25266.74 arcmin
#   Null 168: |u| = 22.9 lambda -> diameter = 25312.66 arcmin
#   Null 169: |u| = 22.9 lambda -> diameter = 25356.64 arcmin
#   Null 170: |u| = 23.0 lambda -> diameter = 25392.91 arcmin
#   Null 171: |u| = 23.1 lambda -> diameter = 25444.90 arcmin
#   Null 172: |u| = 23.2 lambda -> diameter = 25487.41 arcmin
#   Null 173: |u| = 23.3 lambda -> diameter = 25533.16 arcmin
#   Null 174: |u| = 23.4 lambda -> diameter = 25576.46 arcmin
#   Null 175: |u| = 23.6 lambda -> diameter = 25543.43 arcmin
#   Null 176: |u| = 23.7 lambda -> diameter = 25577.40 arcmin
#   Null 177: |u| = 24.1 lambda -> diameter = 25298.59 arcmin
#   Null 178: |u| = 24.5 lambda -> diameter = 25036.18 arcmin
#   Null 179: |u| = 24.6 lambda -> diameter = 25011.89 arcmin
#   Null 180: |u| = 25.0 lambda -> diameter = 24812.66 arcmin
#   Null 181: |u| = 25.1 lambda -> diameter = 24792.35 arcmin
#   Null 182: |u| = 25.2 lambda -> diameter = 24835.24 arcmin
#   Null 183: |u| = 25.3 lambda -> diameter = 24878.19 arcmin
#   Null 184: |u| = 25.4 lambda -> diameter = 24913.55 arcmin
#   Null 185: |u| = 25.5 lambda -> diameter = 24961.74 arcmin
#   Null 186: |u| = 25.6 lambda -> diameter = 25003.20 arcmin
#   Null 187: |u| = 25.7 lambda -> diameter = 25044.75 arcmin
#   Null 188: |u| = 25.8 lambda -> diameter = 25085.81 arcmin
#   Null 189: |u| = 25.9 lambda -> diameter = 25113.68 arcmin
#   Null 190: |u| = 26.0 lambda -> diameter = 25166.09 arcmin
#   Null 191: |u| = 26.1 lambda -> diameter = 25206.71 arcmin
#   Null 192: |u| = 26.2 lambda -> diameter = 25246.74 arcmin
#   Null 193: |u| = 26.4 lambda -> diameter = 25209.12 arcmin
#   Null 194: |u| = 26.4 lambda -> diameter = 25248.85 arcmin
#   Null 195: |u| = 26.6 lambda -> diameter = 25272.47 arcmin
#   Null 196: |u| = 26.7 lambda -> diameter = 25235.63 arcmin
#   Null 197: |u| = 26.9 lambda -> diameter = 25254.06 arcmin
#   Null 198: |u| = 27.0 lambda -> diameter = 25208.40 arcmin
#   Null 199: |u| = 27.2 lambda -> diameter = 25159.75 arcmin
#   Null 200: |u| = 28.2 lambda -> diameter = 24432.08 arcmin
#   Null 201: |u| = 28.7 lambda -> diameter = 24067.11 arcmin
#   Null 202: |u| = 31.0 lambda -> diameter = 22409.40 arcmin
#   Null 203: |u| = 31.7 lambda -> diameter = 22037.52 arcmin
#   Null 204: |u| = 32.2 lambda -> diameter = 21828.94 arcmin
#   Null 205: |u| = 32.3 lambda -> diameter = 21865.81 arcmin
#   Null 206: |u| = 32.4 lambda -> diameter = 21904.58 arcmin
#   Null 207: |u| = 32.5 lambda -> diameter = 21920.00 arcmin
#   Null 208: |u| = 32.6 lambda -> diameter = 21951.15 arcmin
#   Null 209: |u| = 32.7 lambda -> diameter = 21968.48 arcmin
#   Null 210: |u| = 32.9 lambda -> diameter = 21979.73 arcmin
#   Null 211: |u| = 33.0 lambda -> diameter = 22023.26 arcmin
#   Null 212: |u| = 33.2 lambda -> diameter = 22001.15 arcmin
#   Null 213: |u| = 33.5 lambda -> diameter = 21854.51 arcmin
#   Null 214: |u| = 33.6 lambda -> diameter = 21894.83 arcmin
#   Null 215: |u| = 33.7 lambda -> diameter = 21934.58 arcmin
#   Null 216: |u| = 33.8 lambda -> diameter = 21968.69 arcmin
#   Null 217: |u| = 33.9 lambda -> diameter = 22014.57 arcmin
#   Null 218: |u| = 34.0 lambda -> diameter = 22054.05 arcmin
#   Null 219: |u| = 34.1 lambda -> diameter = 22092.82 arcmin
#   Null 220: |u| = 34.2 lambda -> diameter = 22132.26 arcmin
#   Null 221: |u| = 34.3 lambda -> diameter = 22167.30 arcmin
#   Null 222: |u| = 34.4 lambda -> diameter = 22210.36 arcmin
#   Null 223: |u| = 34.5 lambda -> diameter = 22248.85 arcmin
#   Null 224: |u| = 34.6 lambda -> diameter = 22286.34 arcmin
#   Null 225: |u| = 34.7 lambda -> diameter = 22324.97 arcmin
#   Null 226: |u| = 34.8 lambda -> diameter = 22358.41 arcmin
#   Null 227: |u| = 34.9 lambda -> diameter = 22400.81 arcmin
#   Null 228: |u| = 35.0 lambda -> diameter = 22438.62 arcmin
#   Null 229: |u| = 35.3 lambda -> diameter = 22339.72 arcmin
#   Null 230: |u| = 35.4 lambda -> diameter = 22373.11 arcmin
#   Null 231: |u| = 35.5 lambda -> diameter = 22391.61 arcmin
#   Null 232: |u| = 35.7 lambda -> diameter = 22385.90 arcmin
#   Null 233: |u| = 35.8 lambda -> diameter = 22423.77 arcmin
#   Null 234: |u| = 35.9 lambda -> diameter = 22449.02 arcmin
#   Null 235: |u| = 36.1 lambda -> diameter = 22425.25 arcmin
#   Null 236: |u| = 36.2 lambda -> diameter = 22453.18 arcmin
#   Null 237: |u| = 36.3 lambda -> diameter = 22486.23 arcmin
#   Null 238: |u| = 36.4 lambda -> diameter = 22505.14 arcmin
#   Null 239: |u| = 36.5 lambda -> diameter = 22539.68 arcmin
#   Null 240: |u| = 36.6 lambda -> diameter = 22574.45 arcmin
#   Null 241: |u| = 36.7 lambda -> diameter = 22611.37 arcmin
#   Null 242: |u| = 36.8 lambda -> diameter = 22641.86 arcmin
#   Null 243: |u| = 36.9 lambda -> diameter = 22681.71 arcmin
#   Null 244: |u| = 37.0 lambda -> diameter = 22715.82 arcmin
#   Null 245: |u| = 37.1 lambda -> diameter = 22749.41 arcmin
#   Null 246: |u| = 37.2 lambda -> diameter = 22784.45 arcmin
#   Null 247: |u| = 37.3 lambda -> diameter = 22814.04 arcmin
#   Null 248: |u| = 37.3 lambda -> diameter = 22853.03 arcmin
#   Null 249: |u| = 37.4 lambda -> diameter = 22885.79 arcmin
#   Null 250: |u| = 37.5 lambda -> diameter = 22918.62 arcmin
#   Null 251: |u| = 37.6 lambda -> diameter = 22953.61 arcmin
#   Null 252: |u| = 37.7 lambda -> diameter = 22982.48 arcmin
#   Null 253: |u| = 37.8 lambda -> diameter = 23020.38 arcmin
#   Null 254: |u| = 37.9 lambda -> diameter = 23053.41 arcmin
#   Null 255: |u| = 38.0 lambda -> diameter = 23086.65 arcmin
#   Null 256: |u| = 38.1 lambda -> diameter = 23119.81 arcmin
#   Null 257: |u| = 38.2 lambda -> diameter = 23146.91 arcmin
#   Null 258: |u| = 38.3 lambda -> diameter = 23184.08 arcmin
#   Null 259: |u| = 38.4 lambda -> diameter = 23216.48 arcmin
#   Null 260: |u| = 38.5 lambda -> diameter = 23248.15 arcmin
#   Null 261: |u| = 38.6 lambda -> diameter = 23279.67 arcmin
#   Null 262: |u| = 38.7 lambda -> diameter = 23306.25 arcmin
#   Null 263: |u| = 38.8 lambda -> diameter = 23343.07 arcmin
#   Null 264: |u| = 38.9 lambda -> diameter = 23373.62 arcmin
#   Null 265: |u| = 39.0 lambda -> diameter = 23405.65 arcmin
#   Null 266: |u| = 39.1 lambda -> diameter = 23436.29 arcmin
#   Null 267: |u| = 39.2 lambda -> diameter = 23462.16 arcmin
#   Null 268: |u| = 39.2 lambda -> diameter = 23499.32 arcmin
#   Null 269: |u| = 39.5 lambda -> diameter = 23407.65 arcmin
#   Null 270: |u| = 39.6 lambda -> diameter = 23433.93 arcmin
#   Null 271: |u| = 39.7 lambda -> diameter = 23459.51 arcmin
#   Null 272: |u| = 39.8 lambda -> diameter = 23488.67 arcmin
#   Null 273: |u| = 40.0 lambda -> diameter = 23464.83 arcmin
#   Null 274: |u| = 40.2 lambda -> diameter = 23439.74 arcmin
#   Null 275: |u| = 40.3 lambda -> diameter = 23469.68 arcmin
#   Null 276: |u| = 40.4 lambda -> diameter = 23498.44 arcmin
#   Null 277: |u| = 40.6 lambda -> diameter = 23476.84 arcmin
#   Null 278: |u| = 40.7 lambda -> diameter = 23502.62 arcmin
#   Null 279: |u| = 41.0 lambda -> diameter = 23423.55 arcmin
#   Null 280: |u| = 41.1 lambda -> diameter = 23444.32 arcmin
#   Null 281: |u| = 41.2 lambda -> diameter = 23474.29 arcmin
#   Null 282: |u| = 41.3 lambda -> diameter = 23502.71 arcmin
#   Null 283: |u| = 41.4 lambda -> diameter = 23527.89 arcmin
#   Null 284: |u| = 41.5 lambda -> diameter = 23561.49 arcmin
#   Null 285: |u| = 41.6 lambda -> diameter = 23583.62 arcmin
#   Null 286: |u| = 41.7 lambda -> diameter = 23616.20 arcmin
#   Null 287: |u| = 41.8 lambda -> diameter = 23646.65 arcmin
#   Null 288: |u| = 41.9 lambda -> diameter = 23671.14 arcmin
#   Null 289: |u| = 41.9 lambda -> diameter = 23703.98 arcmin
#   Null 290: |u| = 42.0 lambda -> diameter = 23732.44 arcmin
#   Null 291: |u| = 42.1 lambda -> diameter = 23760.61 arcmin
#   Null 292: |u| = 42.3 lambda -> diameter = 23745.96 arcmin
#   Null 293: |u| = 42.7 lambda -> diameter = 23624.49 arcmin
#   Null 294: |u| = 42.8 lambda -> diameter = 23643.82 arcmin
#   Null 295: |u| = 43.2 lambda -> diameter = 23504.79 arcmin
#   Null 296: |u| = 43.3 lambda -> diameter = 23528.62 arcmin
#   Null 297: |u| = 43.4 lambda -> diameter = 23560.62 arcmin
#   Null 298: |u| = 43.5 lambda -> diameter = 23588.28 arcmin
#   Null 299: |u| = 43.6 lambda -> diameter = 23615.69 arcmin
#   Null 300: |u| = 43.7 lambda -> diameter = 23642.93 arcmin
#   Null 301: |u| = 43.8 lambda -> diameter = 23666.57 arcmin
#   Null 302: |u| = 43.8 lambda -> diameter = 23697.85 arcmin
#   Null 303: |u| = 43.9 lambda -> diameter = 23725.32 arcmin
#   Null 304: |u| = 44.0 lambda -> diameter = 23752.13 arcmin
#   Null 305: |u| = 44.1 lambda -> diameter = 23778.27 arcmin
#   Null 306: |u| = 44.2 lambda -> diameter = 23799.61 arcmin
#   Null 307: |u| = 44.3 lambda -> diameter = 23831.55 arcmin
#   Null 308: |u| = 44.4 lambda -> diameter = 23858.38 arcmin
#   Null 309: |u| = 44.5 lambda -> diameter = 23885.00 arcmin
#   Null 310: |u| = 44.6 lambda -> diameter = 23911.20 arcmin
#   Null 311: |u| = 44.7 lambda -> diameter = 23932.97 arcmin
#   Null 312: |u| = 44.8 lambda -> diameter = 23963.23 arcmin
#   Null 313: |u| = 44.9 lambda -> diameter = 23988.27 arcmin
#   Null 314: |u| = 45.0 lambda -> diameter = 24015.06 arcmin
#   Null 315: |u| = 45.1 lambda -> diameter = 24041.61 arcmin
#   Null 316: |u| = 45.2 lambda -> diameter = 24063.12 arcmin
#   Null 317: |u| = 45.3 lambda -> diameter = 24092.75 arcmin
#   Null 318: |u| = 45.4 lambda -> diameter = 24117.33 arcmin
#   Null 319: |u| = 45.5 lambda -> diameter = 24142.63 arcmin
#   Null 320: |u| = 45.6 lambda -> diameter = 24167.71 arcmin
#   Null 321: |u| = 45.7 lambda -> diameter = 24189.02 arcmin
#   Null 322: |u| = 45.7 lambda -> diameter = 24217.44 arcmin
#   Null 323: |u| = 45.8 lambda -> diameter = 24241.81 arcmin
#   Null 324: |u| = 45.9 lambda -> diameter = 24267.11 arcmin
#   Null 325: |u| = 46.0 lambda -> diameter = 24292.06 arcmin
#   Null 326: |u| = 46.1 lambda -> diameter = 24313.26 arcmin
#   Null 327: |u| = 46.2 lambda -> diameter = 24340.36 arcmin
#   Null 328: |u| = 46.3 lambda -> diameter = 24365.57 arcmin
#   Null 329: |u| = 46.4 lambda -> diameter = 24390.41 arcmin
#   Null 330: |u| = 46.5 lambda -> diameter = 24413.02 arcmin
#   Null 331: |u| = 46.6 lambda -> diameter = 24433.54 arcmin
#   Null 332: |u| = 46.7 lambda -> diameter = 24462.23 arcmin
#   Null 333: |u| = 46.8 lambda -> diameter = 24485.93 arcmin
#   Null 334: |u| = 46.9 lambda -> diameter = 24509.22 arcmin
#   Null 335: |u| = 47.0 lambda -> diameter = 24532.83 arcmin
#   Null 336: |u| = 47.1 lambda -> diameter = 24553.23 arcmin
#   Null 337: |u| = 47.2 lambda -> diameter = 24579.90 arcmin
#   Null 338: |u| = 47.3 lambda -> diameter = 24604.33 arcmin
#   Null 339: |u| = 47.4 lambda -> diameter = 24627.27 arcmin
#   Null 340: |u| = 47.5 lambda -> diameter = 24650.13 arcmin
#   Null 341: |u| = 47.6 lambda -> diameter = 24669.56 arcmin
#   Null 342: |u| = 47.6 lambda -> diameter = 24695.92 arcmin
#   Null 343: |u| = 47.7 lambda -> diameter = 24719.97 arcmin
#   Null 344: |u| = 47.8 lambda -> diameter = 24742.61 arcmin
#   Null 345: |u| = 48.0 lambda -> diameter = 24701.66 arcmin
#   Null 346: |u| = 48.1 lambda -> diameter = 24724.01 arcmin
#   Null 347: |u| = 48.2 lambda -> diameter = 24746.14 arcmin
#   Null 348: |u| = 48.3 lambda -> diameter = 24772.16 arcmin
#   Null 349: |u| = 48.5 lambda -> diameter = 24743.60 arcmin
#   Null 350: |u| = 48.8 lambda -> diameter = 24684.19 arcmin
#   Null 351: |u| = 48.9 lambda -> diameter = 24707.73 arcmin
#   Null 352: |u| = 49.0 lambda -> diameter = 24729.25 arcmin
#   Null 353: |u| = 49.1 lambda -> diameter = 24752.20 arcmin
#   Null 354: |u| = 49.2 lambda -> diameter = 24770.39 arcmin
#   Null 355: |u| = 49.3 lambda -> diameter = 24796.03 arcmin
#   Null 356: |u| = 49.3 lambda -> diameter = 24818.27 arcmin
#   Null 357: |u| = 49.4 lambda -> diameter = 24840.51 arcmin
#   Null 358: |u| = 49.5 lambda -> diameter = 24862.88 arcmin
#   Null 359: |u| = 49.6 lambda -> diameter = 24879.99 arcmin
#   Null 360: |u| = 49.7 lambda -> diameter = 24905.59 arcmin
#   Null 361: |u| = 49.8 lambda -> diameter = 24927.26 arcmin
#   Null 362: |u| = 49.9 lambda -> diameter = 24948.29 arcmin
#   Null 363: |u| = 50.0 lambda -> diameter = 24970.24 arcmin
#   Null 364: |u| = 50.1 lambda -> diameter = 24987.63 arcmin
#   Null 365: |u| = 50.2 lambda -> diameter = 25012.70 arcmin
#   Null 366: |u| = 50.3 lambda -> diameter = 25034.30 arcmin
#   Null 367: |u| = 50.4 lambda -> diameter = 25055.02 arcmin
#   Null 368: |u| = 50.5 lambda -> diameter = 25075.94 arcmin
#   Null 369: |u| = 50.6 lambda -> diameter = 25093.19 arcmin
#   Null 370: |u| = 50.7 lambda -> diameter = 25118.04 arcmin
#   Null 371: |u| = 50.8 lambda -> diameter = 25138.66 arcmin
#   Null 372: |u| = 50.9 lambda -> diameter = 25159.61 arcmin
#   Null 373: |u| = 51.0 lambda -> diameter = 25180.48 arcmin
#   Null 374: |u| = 51.1 lambda -> diameter = 25197.17 arcmin
#   Null 375: |u| = 51.1 lambda -> diameter = 25221.04 arcmin
#   Null 376: |u| = 51.3 lambda -> diameter = 25226.46 arcmin
#   Null 377: |u| = 51.6 lambda -> diameter = 25111.89 arcmin
#   Null 378: |u| = 51.7 lambda -> diameter = 25128.90 arcmin
#   Null 379: |u| = 52.1 lambda -> diameter = 25015.03 arcmin
#   Null 380: |u| = 52.3 lambda -> diameter = 24993.08 arcmin
#   Null 381: |u| = 52.4 lambda -> diameter = 25007.95 arcmin
#   Null 382: |u| = 52.5 lambda -> diameter = 25027.66 arcmin
#   Null 383: |u| = 52.7 lambda -> diameter = 24991.89 arcmin
#   Null 384: |u| = 52.8 lambda -> diameter = 25016.12 arcmin
#   Null 385: |u| = 52.9 lambda -> diameter = 25035.89 arcmin
#   Null 386: |u| = 53.0 lambda -> diameter = 25056.79 arcmin
#   Null 387: |u| = 53.1 lambda -> diameter = 25076.41 arcmin
#   Null 388: |u| = 53.2 lambda -> diameter = 25092.84 arcmin
#   Null 389: |u| = 53.3 lambda -> diameter = 25116.33 arcmin
#   Null 390: |u| = 53.4 lambda -> diameter = 25135.96 arcmin
#   Null 391: |u| = 53.5 lambda -> diameter = 25155.31 arcmin
#   Null 392: |u| = 53.6 lambda -> diameter = 25174.60 arcmin
#   Null 393: |u| = 53.7 lambda -> diameter = 25191.23 arcmin
#   Null 394: |u| = 53.8 lambda -> diameter = 25214.35 arcmin
#   Null 395: |u| = 53.9 lambda -> diameter = 25197.61 arcmin
#   Null 396: |u| = 54.0 lambda -> diameter = 25220.38 arcmin
#   Null 397: |u| = 54.4 lambda -> diameter = 25105.26 arcmin
#   Null 398: |u| = 54.5 lambda -> diameter = 25116.53 arcmin
#   Null 399: |u| = 54.6 lambda -> diameter = 25135.67 arcmin
#   Null 400: |u| = 54.7 lambda -> diameter = 25152.42 arcmin
#   Null 401: |u| = 54.8 lambda -> diameter = 25174.67 arcmin
#   Null 402: |u| = 54.9 lambda -> diameter = 25193.32 arcmin
#   Null 403: |u| = 55.0 lambda -> diameter = 25212.78 arcmin
#   Null 404: |u| = 55.1 lambda -> diameter = 25231.63 arcmin
#   Null 405: |u| = 55.2 lambda -> diameter = 25246.82 arcmin
#   Null 406: |u| = 55.3 lambda -> diameter = 25269.59 arcmin
#   Null 407: |u| = 55.4 lambda -> diameter = 25289.36 arcmin
#   Null 408: |u| = 55.5 lambda -> diameter = 25307.25 arcmin
#   Null 409: |u| = 55.6 lambda -> diameter = 25319.12 arcmin
#   Null 410: |u| = 55.7 lambda -> diameter = 25324.64 arcmin
#   Null 411: |u| = 55.9 lambda -> diameter = 25298.66 arcmin
#   Null 412: |u| = 56.0 lambda -> diameter = 25317.31 arcmin
#   Null 413: |u| = 56.1 lambda -> diameter = 25336.47 arcmin
#   Null 414: |u| = 56.2 lambda -> diameter = 25351.20 arcmin
#   Null 415: |u| = 56.3 lambda -> diameter = 25373.86 arcmin
#   Null 416: |u| = 56.4 lambda -> diameter = 25391.92 arcmin
#   Null 417: |u| = 56.5 lambda -> diameter = 25409.89 arcmin
#   Null 418: |u| = 56.5 lambda -> diameter = 25428.55 arcmin
#   Null 419: |u| = 56.6 lambda -> diameter = 25443.16 arcmin
#   Null 420: |u| = 56.7 lambda -> diameter = 25464.81 arcmin
#   Null 421: |u| = 56.8 lambda -> diameter = 25483.10 arcmin
#   Null 422: |u| = 56.9 lambda -> diameter = 25500.72 arcmin
#   Null 423: |u| = 57.0 lambda -> diameter = 25519.31 arcmin
#   Null 424: |u| = 57.1 lambda -> diameter = 25533.78 arcmin
#   Null 425: |u| = 57.2 lambda -> diameter = 25554.88 arcmin
#   Null 426: |u| = 57.3 lambda -> diameter = 25572.84 arcmin
#   Null 427: |u| = 57.4 lambda -> diameter = 25589.27 arcmin
#   Null 428: |u| = 57.5 lambda -> diameter = 25607.38 arcmin
#   Null 429: |u| = 57.6 lambda -> diameter = 25604.94 arcmin
#   Null 430: |u| = 57.8 lambda -> diameter = 25570.41 arcmin
#   Null 431: |u| = 58.2 lambda -> diameter = 25469.21 arcmin
#   Null 432: |u| = 58.3 lambda -> diameter = 25489.74 arcmin
#   Null 433: |u| = 58.4 lambda -> diameter = 25507.93 arcmin
#   Null 434: |u| = 58.5 lambda -> diameter = 25525.34 arcmin
#   Null 435: |u| = 58.6 lambda -> diameter = 25542.70 arcmin
#   Null 436: |u| = 59.1 lambda -> diameter = 25376.34 arcmin
#   Null 437: |u| = 59.2 lambda -> diameter = 25389.71 arcmin
#   Null 438: |u| = 59.3 lambda -> diameter = 25410.28 arcmin
#   Null 439: |u| = 59.4 lambda -> diameter = 25427.80 arcmin
#   Null 440: |u| = 59.5 lambda -> diameter = 25445.79 arcmin
#   Null 441: |u| = 59.6 lambda -> diameter = 25462.82 arcmin
#   Null 442: |u| = 59.7 lambda -> diameter = 25477.13 arcmin
#   Null 443: |u| = 59.8 lambda -> diameter = 25497.83 arcmin
#   Null 444: |u| = 59.9 lambda -> diameter = 25515.38 arcmin
#   Null 445: |u| = 60.0 lambda -> diameter = 25531.97 arcmin
#   Null 446: |u| = 60.0 lambda -> diameter = 25547.52 arcmin
#   Null 447: |u| = 60.1 lambda -> diameter = 25562.49 arcmin
#   Null 448: |u| = 60.3 lambda -> diameter = 25576.00 arcmin
#   Null 449: |u| = 60.3 lambda -> diameter = 25596.38 arcmin
#   Null 450: |u| = 60.4 lambda -> diameter = 25616.50 arcmin
#   Null 451: |u| = 60.5 lambda -> diameter = 25632.97 arcmin
#   Null 452: |u| = 60.7 lambda -> diameter = 25630.70 arcmin
#   Null 453: |u| = 60.8 lambda -> diameter = 25644.64 arcmin
#   Null 454: |u| = 60.9 lambda -> diameter = 25654.25 arcmin
#   Null 455: |u| = 61.0 lambda -> diameter = 25656.29 arcmin
#   Null 456: |u| = 61.1 lambda -> diameter = 25657.12 arcmin
#   Null 457: |u| = 61.2 lambda -> diameter = 25669.61 arcmin
#   Null 458: |u| = 61.3 lambda -> diameter = 25689.06 arcmin
#   Null 459: |u| = 61.4 lambda -> diameter = 25705.92 arcmin
#   Null 460: |u| = 61.5 lambda -> diameter = 25722.74 arcmin
#   Null 461: |u| = 61.6 lambda -> diameter = 25738.52 arcmin
#   Null 462: |u| = 61.7 lambda -> diameter = 25751.59 arcmin
#   Null 463: |u| = 61.8 lambda -> diameter = 25771.16 arcmin
#   Null 464: |u| = 61.9 lambda -> diameter = 25787.66 arcmin
#   Null 465: |u| = 62.0 lambda -> diameter = 25803.87 arcmin
#   Null 466: |u| = 62.1 lambda -> diameter = 25819.08 arcmin
#   Null 467: |u| = 62.2 lambda -> diameter = 25832.12 arcmin
#   Null 468: |u| = 62.3 lambda -> diameter = 25851.64 arcmin
#   Null 469: |u| = 62.4 lambda -> diameter = 25868.34 arcmin
#   Null 470: |u| = 62.5 lambda -> diameter = 25883.82 arcmin
#   Null 471: |u| = 62.6 lambda -> diameter = 25898.93 arcmin
#   Null 472: |u| = 62.7 lambda -> diameter = 25912.39 arcmin
#   Null 473: |u| = 62.7 lambda -> diameter = 25931.02 arcmin
#   Null 474: |u| = 62.8 lambda -> diameter = 25946.06 arcmin
#   Null 475: |u| = 62.9 lambda -> diameter = 25961.96 arcmin
#   Null 476: |u| = 63.1 lambda -> diameter = 25945.49 arcmin
#   Null 477: |u| = 63.3 lambda -> diameter = 25926.69 arcmin
#   Null 478: |u| = 63.4 lambda -> diameter = 25937.63 arcmin
#   Null 479: |u| = 63.7 lambda -> diameter = 25847.01 arcmin
#   Null 480: |u| = 63.8 lambda -> diameter = 25865.44 arcmin
#   Null 481: |u| = 63.9 lambda -> diameter = 25874.98 arcmin
#   Null 482: |u| = 64.1 lambda -> diameter = 25875.64 arcmin
#   Null 483: |u| = 64.2 lambda -> diameter = 25893.90 arcmin
#   Null 484: |u| = 64.3 lambda -> diameter = 25906.27 arcmin
#   Null 485: |u| = 64.4 lambda -> diameter = 25919.82 arcmin
#   Null 486: |u| = 64.4 lambda -> diameter = 25938.21 arcmin
#   Null 487: |u| = 64.5 lambda -> diameter = 25955.05 arcmin
#   Null 488: |u| = 64.6 lambda -> diameter = 25970.60 arcmin
#   Null 489: |u| = 64.7 lambda -> diameter = 25982.77 arcmin
#   Null 490: |u| = 64.8 lambda -> diameter = 26001.02 arcmin
#   Null 491: |u| = 64.9 lambda -> diameter = 26015.90 arcmin
#   Null 492: |u| = 65.0 lambda -> diameter = 26031.33 arcmin
#   Null 493: |u| = 65.1 lambda -> diameter = 26046.37 arcmin
#   Null 494: |u| = 65.2 lambda -> diameter = 26057.63 arcmin
#   Null 495: |u| = 65.3 lambda -> diameter = 26076.52 arcmin
#   Null 496: |u| = 65.4 lambda -> diameter = 26091.22 arcmin
#   Null 497: |u| = 65.5 lambda -> diameter = 26105.23 arcmin
#   Null 498: |u| = 65.6 lambda -> diameter = 26119.98 arcmin
#   Null 499: |u| = 65.7 lambda -> diameter = 26132.32 arcmin
#   Null 500: |u| = 66.3 lambda -> diameter = 25953.90 arcmin
#   Null 501: |u| = 66.4 lambda -> diameter = 25965.93 arcmin
#   Null 502: |u| = 66.8 lambda -> diameter = 25843.85 arcmin
#   Null 503: |u| = 66.9 lambda -> diameter = 25861.44 arcmin
#   Null 504: |u| = 67.0 lambda -> diameter = 25875.87 arcmin
#   Null 505: |u| = 67.1 lambda -> diameter = 25885.53 arcmin
#   Null 506: |u| = 67.2 lambda -> diameter = 25898.65 arcmin
#   Null 507: |u| = 67.3 lambda -> diameter = 25920.67 arcmin
#   Null 508: |u| = 67.4 lambda -> diameter = 25935.11 arcmin
#   Null 509: |u| = 67.5 lambda -> diameter = 25949.05 arcmin
#   Null 510: |u| = 67.6 lambda -> diameter = 25964.35 arcmin
#   Null 511: |u| = 67.7 lambda -> diameter = 25975.61 arcmin
#   Null 512: |u| = 67.7 lambda -> diameter = 25993.38 arcmin
#   Null 513: |u| = 67.8 lambda -> diameter = 26007.96 arcmin
#   Null 514: |u| = 67.9 lambda -> diameter = 26022.34 arcmin
#   Null 515: |u| = 68.3 lambda -> diameter = 25925.64 arcmin
#   Null 516: |u| = 68.6 lambda -> diameter = 25869.02 arcmin
#   Null 517: |u| = 68.7 lambda -> diameter = 25886.56 arcmin
#   Null 518: |u| = 68.8 lambda -> diameter = 25900.28 arcmin
#   Null 519: |u| = 68.9 lambda -> diameter = 25915.06 arcmin
#   Null 520: |u| = 69.0 lambda -> diameter = 25929.95 arcmin
#   Null 521: |u| = 69.1 lambda -> diameter = 25940.86 arcmin
#   Null 522: |u| = 69.2 lambda -> diameter = 25958.82 arcmin
#   Null 523: |u| = 69.3 lambda -> diameter = 25973.12 arcmin
#   Null 524: |u| = 69.4 lambda -> diameter = 25986.54 arcmin
#   Null 525: |u| = 69.4 lambda -> diameter = 26001.14 arcmin
#   Null 526: |u| = 69.5 lambda -> diameter = 26012.53 arcmin
#   Null 527: |u| = 69.6 lambda -> diameter = 26029.08 arcmin
#   Null 528: |u| = 69.7 lambda -> diameter = 26043.71 arcmin
#   Null 529: |u| = 69.8 lambda -> diameter = 26057.67 arcmin
#   Null 530: |u| = 69.9 lambda -> diameter = 26071.79 arcmin
#   Null 531: |u| = 70.0 lambda -> diameter = 26082.90 arcmin
#   Null 532: |u| = 70.1 lambda -> diameter = 26099.64 arcmin
#   Null 533: |u| = 70.2 lambda -> diameter = 26107.89 arcmin
#   Null 534: |u| = 70.3 lambda -> diameter = 26124.57 arcmin
#   Null 535: |u| = 70.4 lambda -> diameter = 26140.56 arcmin
#   Null 536: |u| = 70.5 lambda -> diameter = 26151.51 arcmin
#   Null 537: |u| = 70.6 lambda -> diameter = 26168.12 arcmin
#   Null 538: |u| = 70.7 lambda -> diameter = 26181.83 arcmin
#   Null 539: |u| = 71.3 lambda -> diameter = 25987.66 arcmin
#   Null 540: |u| = 72.3 lambda -> diameter = 25679.95 arcmin
#   Null 541: |u| = 73.8 lambda -> diameter = 25197.76 arcmin
#   Null 542: |u| = 76.9 lambda -> diameter = 24225.55 arcmin
#   Null 543: |u| = 77.1 lambda -> diameter = 24213.42 arcmin
#   Null 544: |u| = 77.3 lambda -> diameter = 24197.09 arcmin
#   Null 545: |u| = 77.4 lambda -> diameter = 24211.56 arcmin
#   Null 546: |u| = 77.5 lambda -> diameter = 24227.09 arcmin
#   Null 547: |u| = 77.6 lambda -> diameter = 24244.25 arcmin
#   Null 548: |u| = 77.8 lambda -> diameter = 24227.07 arcmin
#   Null 549: |u| = 78.0 lambda -> diameter = 24214.59 arcmin
#   Null 550: |u| = 78.1 lambda -> diameter = 24229.94 arcmin
#   Null 551: |u| = 78.3 lambda -> diameter = 24215.07 arcmin
#   Null 552: |u| = 78.4 lambda -> diameter = 24201.17 arcmin
#   Null 553: |u| = 78.5 lambda -> diameter = 24216.13 arcmin
#   Null 554: |u| = 78.7 lambda -> diameter = 24201.97 arcmin
#   Null 555: |u| = 78.9 lambda -> diameter = 24187.84 arcmin
#   Null 556: |u| = 79.0 lambda -> diameter = 24202.68 arcmin
#   Null 557: |u| = 79.2 lambda -> diameter = 24187.70 arcmin
#   Null 558: |u| = 79.3 lambda -> diameter = 24201.19 arcmin
#   Null 559: |u| = 79.4 lambda -> diameter = 24217.04 arcmin
#   Null 560: |u| = 79.5 lambda -> diameter = 24232.13 arcmin
#   Null 561: |u| = 79.7 lambda -> diameter = 24216.48 arcmin
#   Null 562: |u| = 79.9 lambda -> diameter = 24203.99 arcmin
#   Null 563: |u| = 79.9 lambda -> diameter = 24222.51 arcmin
#   Null 564: |u| = 80.1 lambda -> diameter = 24204.59 arcmin
#   Null 565: |u| = 80.4 lambda -> diameter = 24161.94 arcmin
#   Null 566: |u| = 80.5 lambda -> diameter = 24176.35 arcmin
#   Null 567: |u| = 80.6 lambda -> diameter = 24190.86 arcmin
#   Null 568: |u| = 80.7 lambda -> diameter = 24203.06 arcmin
#   Null 569: |u| = 80.8 lambda -> diameter = 24219.99 arcmin
#   Null 570: |u| = 80.9 lambda -> diameter = 24233.97 arcmin
#   Null 571: |u| = 81.0 lambda -> diameter = 24248.70 arcmin
#   Null 572: |u| = 81.1 lambda -> diameter = 24262.69 arcmin
#   Null 573: |u| = 81.2 lambda -> diameter = 24274.41 arcmin
#   Null 574: |u| = 81.3 lambda -> diameter = 24291.28 arcmin
#   Null 575: |u| = 81.4 lambda -> diameter = 24305.49 arcmin
#   Null 576: |u| = 81.5 lambda -> diameter = 24315.48 arcmin
#   Null 577: |u| = 81.8 lambda -> diameter = 24261.61 arcmin
#   Null 578: |u| = 81.9 lambda -> diameter = 24278.41 arcmin
#   Null 579: |u| = 82.1 lambda -> diameter = 24262.23 arcmin
#   Null 580: |u| = 82.4 lambda -> diameter = 24193.85 arcmin
#   Null 581: |u| = 82.5 lambda -> diameter = 24207.88 arcmin
#   Null 582: |u| = 82.6 lambda -> diameter = 24221.97 arcmin
#   Null 583: |u| = 82.9 lambda -> diameter = 24184.50 arcmin
#   Null 584: |u| = 83.0 lambda -> diameter = 24196.33 arcmin
#   Null 585: |u| = 83.1 lambda -> diameter = 24206.75 arcmin
#   Null 586: |u| = 83.3 lambda -> diameter = 24196.97 arcmin
#   Null 587: |u| = 83.5 lambda -> diameter = 24182.19 arcmin
#   Null 588: |u| = 83.6 lambda -> diameter = 24196.51 arcmin
#   Null 589: |u| = 83.7 lambda -> diameter = 24210.05 arcmin
#   Null 590: |u| = 83.8 lambda -> diameter = 24212.75 arcmin
#   Null 591: |u| = 83.9 lambda -> diameter = 24225.51 arcmin
#   Null 592: |u| = 84.0 lambda -> diameter = 24239.10 arcmin
#   Null 593: |u| = 84.1 lambda -> diameter = 24253.33 arcmin
#   Null 594: |u| = 84.2 lambda -> diameter = 24266.98 arcmin
#   Null 595: |u| = 84.3 lambda -> diameter = 24278.68 arcmin
#   Null 596: |u| = 84.4 lambda -> diameter = 24294.36 arcmin
#   Null 597: |u| = 84.5 lambda -> diameter = 24307.59 arcmin
#   Null 598: |u| = 84.6 lambda -> diameter = 24321.54 arcmin
#   Null 599: |u| = 84.7 lambda -> diameter = 24335.06 arcmin
#   Null 600: |u| = 84.8 lambda -> diameter = 24346.73 arcmin
#   Null 601: |u| = 84.8 lambda -> diameter = 24362.78 arcmin
#   Null 602: |u| = 84.9 lambda -> diameter = 24375.95 arcmin
#   Null 603: |u| = 85.0 lambda -> diameter = 24389.63 arcmin
#   Null 604: |u| = 85.1 lambda -> diameter = 24402.80 arcmin
#   Null 605: |u| = 85.2 lambda -> diameter = 24414.37 arcmin
#   Null 606: |u| = 85.3 lambda -> diameter = 24429.84 arcmin
#   Null 607: |u| = 85.4 lambda -> diameter = 24443.29 arcmin
#   Null 608: |u| = 85.5 lambda -> diameter = 24456.75 arcmin
#   Null 609: |u| = 85.6 lambda -> diameter = 24454.01 arcmin
#   Null 610: |u| = 85.8 lambda -> diameter = 24456.19 arcmin
#   Null 611: |u| = 85.9 lambda -> diameter = 24467.56 arcmin
#   Null 612: |u| = 86.1 lambda -> diameter = 24456.03 arcmin
#   Null 613: |u| = 86.2 lambda -> diameter = 24470.27 arcmin
#   Null 614: |u| = 86.3 lambda -> diameter = 24482.72 arcmin
#   Null 615: |u| = 86.4 lambda -> diameter = 24494.13 arcmin
#   Null 616: |u| = 86.5 lambda -> diameter = 24482.70 arcmin
#   Null 617: |u| = 86.6 lambda -> diameter = 24495.97 arcmin
#   Null 618: |u| = 86.7 lambda -> diameter = 24508.93 arcmin
#   Null 619: |u| = 86.8 lambda -> diameter = 24520.89 arcmin
#   Null 620: |u| = 87.0 lambda -> diameter = 24508.09 arcmin
#   Null 621: |u| = 87.1 lambda -> diameter = 24522.00 arcmin
#   Null 622: |u| = 87.2 lambda -> diameter = 24535.16 arcmin
#   Null 623: |u| = 87.3 lambda -> diameter = 24547.13 arcmin
#   Null 624: |u| = 87.5 lambda -> diameter = 24533.90 arcmin
#   Null 625: |u| = 87.6 lambda -> diameter = 24547.20 arcmin
#   Null 626: |u| = 87.7 lambda -> diameter = 24559.72 arcmin
#   Null 627: |u| = 87.8 lambda -> diameter = 24571.68 arcmin
#   Null 628: |u| = 87.9 lambda -> diameter = 24559.72 arcmin
#   Null 629: |u| = 88.0 lambda -> diameter = 24576.26 arcmin
#   Null 630: |u| = 88.1 lambda -> diameter = 24585.23 arcmin
#   Null 631: |u| = 88.2 lambda -> diameter = 24598.29 arcmin
#   Null 632: |u| = 88.3 lambda -> diameter = 24610.48 arcmin
#   Null 633: |u| = 88.5 lambda -> diameter = 24596.31 arcmin
#   Null 634: |u| = 88.6 lambda -> diameter = 24610.40 arcmin
#   Null 635: |u| = 88.7 lambda -> diameter = 24621.30 arcmin
#   Null 636: |u| = 88.8 lambda -> diameter = 24634.07 arcmin
#   Null 637: |u| = 89.0 lambda -> diameter = 24620.80 arcmin
#   Null 638: |u| = 89.1 lambda -> diameter = 24635.96 arcmin
#   Null 639: |u| = 89.2 lambda -> diameter = 24647.84 arcmin
#   Null 640: |u| = 89.3 lambda -> diameter = 24658.67 arcmin
#   Null 641: |u| = 89.4 lambda -> diameter = 24645.68 arcmin
#   Null 642: |u| = 89.5 lambda -> diameter = 24659.47 arcmin
#   Null 643: |u| = 89.7 lambda -> diameter = 24642.99 arcmin
#   Null 644: |u| = 90.0 lambda -> diameter = 24607.88 arcmin
#   Null 645: |u| = 90.1 lambda -> diameter = 24620.36 arcmin
#   Null 646: |u| = 90.2 lambda -> diameter = 24632.48 arcmin
#   Null 647: |u| = 90.4 lambda -> diameter = 24619.57 arcmin
#   Null 648: |u| = 90.5 lambda -> diameter = 24632.50 arcmin
#   Null 649: |u| = 90.6 lambda -> diameter = 24644.29 arcmin
#   Null 650: |u| = 90.7 lambda -> diameter = 24655.16 arcmin
#   Null 651: |u| = 90.9 lambda -> diameter = 24642.35 arcmin
#   Null 652: |u| = 90.9 lambda -> diameter = 24658.23 arcmin
#   Null 653: |u| = 91.0 lambda -> diameter = 24670.42 arcmin
#   Null 654: |u| = 91.1 lambda -> diameter = 24679.25 arcmin
#   Null 655: |u| = 91.2 lambda -> diameter = 24691.84 arcmin
#   Null 656: |u| = 91.4 lambda -> diameter = 24680.32 arcmin
#   Null 657: |u| = 91.5 lambda -> diameter = 24692.15 arcmin
#   Null 658: |u| = 91.6 lambda -> diameter = 24703.18 arcmin
#   Null 659: |u| = 91.7 lambda -> diameter = 24715.68 arcmin
#   Null 660: |u| = 91.8 lambda -> diameter = 24727.34 arcmin
#   Null 661: |u| = 91.9 lambda -> diameter = 24729.96 arcmin
#   Null 662: |u| = 92.1 lambda -> diameter = 24726.77 arcmin
#   Null 663: |u| = 92.2 lambda -> diameter = 24728.11 arcmin
#   Null 664: |u| = 92.3 lambda -> diameter = 24740.07 arcmin
#   Null 665: |u| = 92.4 lambda -> diameter = 24740.28 arcmin
#   Null 666: |u| = 92.5 lambda -> diameter = 24751.54 arcmin
#   Null 667: |u| = 92.6 lambda -> diameter = 24761.97 arcmin
#   Null 668: |u| = 92.8 lambda -> diameter = 24750.77 arcmin
#   Null 669: |u| = 92.9 lambda -> diameter = 24760.95 arcmin
#   Null 670: |u| = 93.0 lambda -> diameter = 24774.80 arcmin
#   Null 671: |u| = 93.1 lambda -> diameter = 24785.35 arcmin
#   Null 672: |u| = 93.3 lambda -> diameter = 24774.57 arcmin
#   Null 673: |u| = 93.5 lambda -> diameter = 24759.50 arcmin
#   Null 674: |u| = 93.6 lambda -> diameter = 24773.06 arcmin
#   Null 675: |u| = 93.8 lambda -> diameter = 24759.81 arcmin
#   Null 676: |u| = 93.9 lambda -> diameter = 24770.12 arcmin
#   Null 677: |u| = 93.9 lambda -> diameter = 24782.49 arcmin
#   Null 678: |u| = 94.0 lambda -> diameter = 24792.21 arcmin
#   Null 679: |u| = 94.2 lambda -> diameter = 24783.27 arcmin
#   Null 680: |u| = 94.5 lambda -> diameter = 24744.51 arcmin
#   Null 681: |u| = 94.7 lambda -> diameter = 24733.81 arcmin
#   Null 682: |u| = 94.8 lambda -> diameter = 24744.88 arcmin
#   Null 683: |u| = 94.9 lambda -> diameter = 24754.98 arcmin
#   Null 684: |u| = 95.0 lambda -> diameter = 24766.90 arcmin
#   Null 685: |u| = 95.3 lambda -> diameter = 24731.46 arcmin
#   Null 686: |u| = 95.3 lambda -> diameter = 24745.43 arcmin
#   Null 687: |u| = 95.5 lambda -> diameter = 24728.88 arcmin
#   Null 688: |u| = 95.7 lambda -> diameter = 24718.30 arcmin
#   Null 689: |u| = 95.8 lambda -> diameter = 24728.39 arcmin
#   Null 690: |u| = 95.9 lambda -> diameter = 24740.34 arcmin
#   Null 691: |u| = 96.1 lambda -> diameter = 24729.66 arcmin
#   Null 692: |u| = 96.4 lambda -> diameter = 24675.84 arcmin
#   Null 693: |u| = 96.5 lambda -> diameter = 24689.90 arcmin
#   Null 694: |u| = 96.6 lambda -> diameter = 24703.56 arcmin
#   Null 695: |u| = 96.7 lambda -> diameter = 24716.29 arcmin
#   Null 696: |u| = 96.8 lambda -> diameter = 24726.33 arcmin
#   Null 697: |u| = 96.9 lambda -> diameter = 24739.43 arcmin
#   Null 698: |u| = 97.0 lambda -> diameter = 24750.79 arcmin
#   Null 699: |u| = 97.1 lambda -> diameter = 24762.56 arcmin
#   Null 700: |u| = 97.2 lambda -> diameter = 24774.02 arcmin
#   Null 701: |u| = 97.3 lambda -> diameter = 24783.32 arcmin
#   Null 702: |u| = 97.4 lambda -> diameter = 24797.32 arcmin
#   Null 703: |u| = 97.4 lambda -> diameter = 24808.89 arcmin
#   Null 704: |u| = 97.5 lambda -> diameter = 24819.88 arcmin
#   Null 705: |u| = 97.6 lambda -> diameter = 24831.55 arcmin
#   Null 706: |u| = 97.7 lambda -> diameter = 24840.73 arcmin
#   Null 707: |u| = 97.8 lambda -> diameter = 24854.41 arcmin
#   Null 708: |u| = 97.9 lambda -> diameter = 24865.69 arcmin
#   Null 709: |u| = 98.0 lambda -> diameter = 24876.99 arcmin
#   Null 710: |u| = 98.1 lambda -> diameter = 24888.52 arcmin
#   Null 711: |u| = 98.2 lambda -> diameter = 24897.54 arcmin
#   Null 712: |u| = 98.3 lambda -> diameter = 24910.92 arcmin
#   Null 713: |u| = 98.4 lambda -> diameter = 24922.61 arcmin
#   Null 714: |u| = 98.5 lambda -> diameter = 24933.51 arcmin
#   Null 715: |u| = 98.6 lambda -> diameter = 24944.39 arcmin
#   Null 716: |u| = 98.7 lambda -> diameter = 24953.93 arcmin
#   Null 717: |u| = 98.8 lambda -> diameter = 24966.82 arcmin
#   Null 718: |u| = 98.9 lambda -> diameter = 24977.56 arcmin
#   Null 719: |u| = 98.9 lambda -> diameter = 24989.48 arcmin
#   Null 720: |u| = 99.3 lambda -> diameter = 24941.41 arcmin
#   Null 721: |u| = 99.5 lambda -> diameter = 24927.80 arcmin
#   Null 722: |u| = 99.6 lambda -> diameter = 24938.91 arcmin
#   Null 723: |u| = 99.7 lambda -> diameter = 24949.67 arcmin
#   Null 724: |u| = 99.8 lambda -> diameter = 24939.89 arcmin
#   Null 725: |u| = 100.0 lambda -> diameter = 24926.74 arcmin
#   Null 726: |u| = 100.3 lambda -> diameter = 24891.77 arcmin
#   Null 727: |u| = 100.5 lambda -> diameter = 24879.53 arcmin
#   Null 728: |u| = 100.7 lambda -> diameter = 24867.93 arcmin
#   Null 729: |u| = 100.8 lambda -> diameter = 24878.54 arcmin
#   Null 730: |u| = 100.9 lambda -> diameter = 24889.30 arcmin
#   Null 731: |u| = 101.1 lambda -> diameter = 24875.98 arcmin
#   Null 732: |u| = 101.2 lambda -> diameter = 24863.60 arcmin
#   Null 733: |u| = 101.3 lambda -> diameter = 24877.03 arcmin
#   Null 734: |u| = 101.5 lambda -> diameter = 24863.02 arcmin
#   Null 735: |u| = 101.6 lambda -> diameter = 24874.02 arcmin
#   Null 736: |u| = 101.7 lambda -> diameter = 24885.15 arcmin
#   Null 737: |u| = 101.8 lambda -> diameter = 24886.05 arcmin
#   Null 738: |u| = 101.9 lambda -> diameter = 24897.28 arcmin
#   Null 739: |u| = 102.0 lambda -> diameter = 24907.93 arcmin
#   Null 740: |u| = 102.1 lambda -> diameter = 24916.68 arcmin
#   Null 741: |u| = 102.2 lambda -> diameter = 24929.14 arcmin
#   Null 742: |u| = 102.3 lambda -> diameter = 24940.78 arcmin
#   Null 743: |u| = 102.4 lambda -> diameter = 24951.69 arcmin
#   Null 744: |u| = 102.5 lambda -> diameter = 24961.75 arcmin
#   Null 745: |u| = 102.6 lambda -> diameter = 24971.10 arcmin
#   Null 746: |u| = 102.7 lambda -> diameter = 24983.57 arcmin
#   Null 747: |u| = 102.8 lambda -> diameter = 24994.30 arcmin
#   Null 748: |u| = 102.9 lambda -> diameter = 25005.13 arcmin
#   Null 749: |u| = 103.0 lambda -> diameter = 25015.90 arcmin
#   Null 750: |u| = 103.1 lambda -> diameter = 25024.83 arcmin
#   Null 751: |u| = 103.2 lambda -> diameter = 25037.14 arcmin
#   Null 752: |u| = 103.2 lambda -> diameter = 25047.84 arcmin
#   Null 753: |u| = 103.3 lambda -> diameter = 25058.78 arcmin
#   Null 754: |u| = 103.4 lambda -> diameter = 25068.78 arcmin
#   Null 755: |u| = 103.5 lambda -> diameter = 25078.01 arcmin
#   Null 756: |u| = 103.6 lambda -> diameter = 25090.54 arcmin
#   Null 757: |u| = 103.7 lambda -> diameter = 25101.21 arcmin
#   Null 758: |u| = 103.8 lambda -> diameter = 25111.61 arcmin
#   Null 759: |u| = 103.9 lambda -> diameter = 25118.96 arcmin
#   Null 760: |u| = 104.3 lambda -> diameter = 25065.04 arcmin
#   Null 761: |u| = 104.4 lambda -> diameter = 25075.62 arcmin
#   Null 762: |u| = 104.5 lambda -> diameter = 25084.50 arcmin
#   Null 763: |u| = 104.6 lambda -> diameter = 25096.34 arcmin
#   Null 764: |u| = 104.6 lambda -> diameter = 25107.07 arcmin
#   Null 765: |u| = 104.7 lambda -> diameter = 25117.37 arcmin
#   Null 766: |u| = 104.8 lambda -> diameter = 25127.99 arcmin
#   Null 767: |u| = 105.0 lambda -> diameter = 25127.90 arcmin
#   Null 768: |u| = 105.1 lambda -> diameter = 25136.97 arcmin
#   Null 769: |u| = 105.2 lambda -> diameter = 25143.71 arcmin
#   Null 770: |u| = 105.3 lambda -> diameter = 25156.23 arcmin
#   Null 771: |u| = 105.3 lambda -> diameter = 25167.66 arcmin
#   Null 772: |u| = 105.6 lambda -> diameter = 25145.61 arcmin
#   Null 773: |u| = 105.7 lambda -> diameter = 25155.93 arcmin
#   Null 774: |u| = 105.9 lambda -> diameter = 25140.33 arcmin
#   Null 775: |u| = 106.0 lambda -> diameter = 25132.12 arcmin
#   Null 776: |u| = 106.1 lambda -> diameter = 25142.66 arcmin
#   Null 777: |u| = 106.3 lambda -> diameter = 25129.91 arcmin
#   Null 778: |u| = 106.5 lambda -> diameter = 25118.07 arcmin
#   Null 779: |u| = 106.6 lambda -> diameter = 25127.54 arcmin
#   Null 780: |u| = 107.0 lambda -> diameter = 25074.35 arcmin
#   Null 781: |u| = 107.1 lambda -> diameter = 25084.37 arcmin
#   Null 782: |u| = 107.2 lambda -> diameter = 25083.29 arcmin
#   Null 783: |u| = 107.3 lambda -> diameter = 25084.87 arcmin
#   Null 784: |u| = 107.4 lambda -> diameter = 25093.18 arcmin
#   Null 785: |u| = 107.6 lambda -> diameter = 25093.44 arcmin
#   Null 786: |u| = 107.7 lambda -> diameter = 25092.32 arcmin
#   Null 787: |u| = 107.8 lambda -> diameter = 25100.70 arcmin
#   Null 788: |u| = 107.9 lambda -> diameter = 25103.82 arcmin
#   Null 789: |u| = 108.1 lambda -> diameter = 25110.78 arcmin
#   Null 790: |u| = 108.2 lambda -> diameter = 25100.71 arcmin
#   Null 791: |u| = 108.3 lambda -> diameter = 25109.14 arcmin
#   Null 792: |u| = 108.4 lambda -> diameter = 25119.60 arcmin
#   Null 793: |u| = 108.5 lambda -> diameter = 25129.88 arcmin
#   Null 794: |u| = 108.7 lambda -> diameter = 25119.80 arcmin
#   Null 795: |u| = 108.8 lambda -> diameter = 25128.55 arcmin
#   Null 796: |u| = 108.9 lambda -> diameter = 25139.09 arcmin
#   Null 797: |u| = 109.0 lambda -> diameter = 25148.14 arcmin
#   Null 798: |u| = 109.2 lambda -> diameter = 25138.77 arcmin
#   Null 799: |u| = 109.3 lambda -> diameter = 25148.83 arcmin
#   Null 800: |u| = 109.3 lambda -> diameter = 25160.37 arcmin
#   Null 801: |u| = 109.4 lambda -> diameter = 25167.34 arcmin
#   Null 802: |u| = 109.7 lambda -> diameter = 25134.49 arcmin
#   Null 803: |u| = 110.1 lambda -> diameter = 25081.12 arcmin
#   Null 804: |u| = 110.2 lambda -> diameter = 25089.96 arcmin
#   Null 805: |u| = 110.4 lambda -> diameter = 25080.67 arcmin
#   Null 806: |u| = 110.5 lambda -> diameter = 25079.06 arcmin
#   Null 807: |u| = 110.6 lambda -> diameter = 25088.24 arcmin
#   Null 808: |u| = 110.8 lambda -> diameter = 25088.40 arcmin
#   Null 809: |u| = 110.8 lambda -> diameter = 25098.41 arcmin
#   Null 810: |u| = 111.0 lambda -> diameter = 25088.36 arcmin
#   Null 811: |u| = 111.2 lambda -> diameter = 25078.48 arcmin
#   Null 812: |u| = 111.3 lambda -> diameter = 25090.25 arcmin
#   Null 813: |u| = 111.4 lambda -> diameter = 25096.79 arcmin
#   Null 814: |u| = 111.5 lambda -> diameter = 25107.00 arcmin
#   Null 815: |u| = 111.6 lambda -> diameter = 25115.12 arcmin
#   Null 816: |u| = 111.7 lambda -> diameter = 25126.34 arcmin
#   Null 817: |u| = 111.8 lambda -> diameter = 25136.36 arcmin
#   Null 818: |u| = 111.9 lambda -> diameter = 25145.99 arcmin
#   Null 819: |u| = 112.0 lambda -> diameter = 25156.19 arcmin
#   Null 820: |u| = 112.1 lambda -> diameter = 25164.14 arcmin
#   Null 821: |u| = 112.1 lambda -> diameter = 25175.69 arcmin
#   Null 822: |u| = 112.2 lambda -> diameter = 25185.64 arcmin
#   Null 823: |u| = 112.3 lambda -> diameter = 25195.25 arcmin
#   Null 824: |u| = 112.4 lambda -> diameter = 25205.13 arcmin
#   Null 825: |u| = 112.5 lambda -> diameter = 25213.19 arcmin
#   Null 826: |u| = 112.6 lambda -> diameter = 25224.70 arcmin
#   Null 827: |u| = 112.7 lambda -> diameter = 25234.23 arcmin
#   Null 828: |u| = 112.8 lambda -> diameter = 25244.04 arcmin
#   Null 829: |u| = 112.9 lambda -> diameter = 25253.68 arcmin
#   Null 830: |u| = 113.2 lambda -> diameter = 25220.46 arcmin
#   Null 831: |u| = 113.3 lambda -> diameter = 25229.88 arcmin
#   Null 832: |u| = 113.4 lambda -> diameter = 25218.98 arcmin
#   Null 833: |u| = 113.5 lambda -> diameter = 25230.16 arcmin
#   Null 834: |u| = 113.6 lambda -> diameter = 25239.49 arcmin
#   Null 835: |u| = 113.7 lambda -> diameter = 25247.91 arcmin
#   Null 836: |u| = 113.9 lambda -> diameter = 25236.58 arcmin
#   Null 837: |u| = 114.0 lambda -> diameter = 25248.12 arcmin
#   Null 838: |u| = 114.1 lambda -> diameter = 25255.53 arcmin
#   Null 839: |u| = 114.2 lambda -> diameter = 25265.19 arcmin
#   Null 840: |u| = 114.4 lambda -> diameter = 25254.50 arcmin
#   Null 841: |u| = 114.5 lambda -> diameter = 25265.87 arcmin
#   Null 842: |u| = 114.6 lambda -> diameter = 25274.59 arcmin
#   Null 843: |u| = 114.7 lambda -> diameter = 25283.56 arcmin
#   Null 844: |u| = 114.8 lambda -> diameter = 25271.99 arcmin
#   Null 845: |u| = 114.9 lambda -> diameter = 25282.93 arcmin
#   Null 846: |u| = 115.0 lambda -> diameter = 25291.26 arcmin
#   Null 847: |u| = 115.1 lambda -> diameter = 25300.55 arcmin
#   Null 848: |u| = 115.2 lambda -> diameter = 25309.80 arcmin
#   Null 849: |u| = 115.7 lambda -> diameter = 25237.08 arcmin
#   Null 850: |u| = 116.0 lambda -> diameter = 25208.46 arcmin
#   Null 851: |u| = 116.0 lambda -> diameter = 25216.73 arcmin
#   Null 852: |u| = 116.1 lambda -> diameter = 25226.38 arcmin
#   Null 853: |u| = 116.2 lambda -> diameter = 25235.32 arcmin
#   Null 854: |u| = 116.3 lambda -> diameter = 25244.76 arcmin
#   Null 855: |u| = 116.5 lambda -> diameter = 25234.01 arcmin
#   Null 856: |u| = 116.7 lambda -> diameter = 25233.48 arcmin
#   Null 857: |u| = 117.2 lambda -> diameter = 25142.84 arcmin
#   Null 858: |u| = 117.3 lambda -> diameter = 25153.54 arcmin
#   Null 859: |u| = 117.4 lambda -> diameter = 25161.55 arcmin
#   Null 860: |u| = 117.5 lambda -> diameter = 25172.23 arcmin
#   Null 861: |u| = 117.6 lambda -> diameter = 25181.79 arcmin
#   Null 862: |u| = 117.7 lambda -> diameter = 25191.42 arcmin
#   Null 863: |u| = 117.8 lambda -> diameter = 25200.80 arcmin
#   Null 864: |u| = 117.9 lambda -> diameter = 25208.81 arcmin
#   Null 865: |u| = 117.9 lambda -> diameter = 25219.62 arcmin
#   Null 866: |u| = 118.0 lambda -> diameter = 25228.81 arcmin
#   Null 867: |u| = 118.1 lambda -> diameter = 25237.57 arcmin
#   Null 868: |u| = 118.2 lambda -> diameter = 25247.02 arcmin
#   Null 869: |u| = 118.3 lambda -> diameter = 25254.81 arcmin
#   Null 870: |u| = 118.5 lambda -> diameter = 25255.77 arcmin
#   Null 871: |u| = 118.7 lambda -> diameter = 25226.09 arcmin
#   Null 872: |u| = 118.8 lambda -> diameter = 25233.74 arcmin
#   Null 873: |u| = 118.9 lambda -> diameter = 25244.01 arcmin
#   Null 874: |u| = 119.0 lambda -> diameter = 25251.95 arcmin
#   Null 875: |u| = 119.2 lambda -> diameter = 25243.33 arcmin
#   Null 876: |u| = 119.3 lambda -> diameter = 25250.70 arcmin
#   Null 877: |u| = 119.4 lambda -> diameter = 25261.34 arcmin
#   Null 878: |u| = 119.7 lambda -> diameter = 25231.52 arcmin
#   Null 879: |u| = 119.8 lambda -> diameter = 25239.31 arcmin
#   Null 880: |u| = 119.8 lambda -> diameter = 25249.63 arcmin
#   Null 881: |u| = 119.9 lambda -> diameter = 25257.65 arcmin
#   Null 882: |u| = 120.1 lambda -> diameter = 25248.59 arcmin
#   Null 883: |u| = 120.2 lambda -> diameter = 25256.18 arcmin
#   Null 884: |u| = 120.3 lambda -> diameter = 25265.45 arcmin
#   Null 885: |u| = 120.6 lambda -> diameter = 25237.25 arcmin
#   Null 886: |u| = 120.7 lambda -> diameter = 25244.30 arcmin
#   Null 887: |u| = 120.9 lambda -> diameter = 25226.13 arcmin
#   Null 888: |u| = 121.0 lambda -> diameter = 25235.22 arcmin
#   Null 889: |u| = 121.1 lambda -> diameter = 25244.13 arcmin
#   Null 890: |u| = 121.2 lambda -> diameter = 25252.08 arcmin
#   Null 891: |u| = 121.3 lambda -> diameter = 25262.48 arcmin
#   Null 892: |u| = 121.4 lambda -> diameter = 25271.47 arcmin
#   Null 893: |u| = 121.5 lambda -> diameter = 25280.72 arcmin
#   Null 894: |u| = 121.6 lambda -> diameter = 25289.63 arcmin
#   Null 895: |u| = 121.7 lambda -> diameter = 25297.00 arcmin
#   Null 896: |u| = 122.0 lambda -> diameter = 25249.64 arcmin
#   Null 897: |u| = 122.1 lambda -> diameter = 25257.21 arcmin
#   Null 898: |u| = 122.2 lambda -> diameter = 25267.69 arcmin
#   Null 899: |u| = 122.3 lambda -> diameter = 25273.73 arcmin
#   Null 900: |u| = 122.4 lambda -> diameter = 25284.53 arcmin
#   Null 901: |u| = 122.5 lambda -> diameter = 25294.77 arcmin
#   Null 902: |u| = 122.6 lambda -> diameter = 25302.41 arcmin
#   Null 903: |u| = 122.7 lambda -> diameter = 25312.74 arcmin
#   Null 904: |u| = 122.8 lambda -> diameter = 25321.50 arcmin
#   Null 905: |u| = 122.9 lambda -> diameter = 25330.44 arcmin
#   Null 906: |u| = 122.9 lambda -> diameter = 25339.52 arcmin
#   Null 907: |u| = 123.1 lambda -> diameter = 25346.55 arcmin
#   Null 908: |u| = 123.1 lambda -> diameter = 25357.16 arcmin
#   Null 909: |u| = 123.3 lambda -> diameter = 25355.34 arcmin
#   Null 910: |u| = 123.6 lambda -> diameter = 25307.38 arcmin
#   Null 911: |u| = 124.0 lambda -> diameter = 25260.35 arcmin
#   Null 912: |u| = 124.1 lambda -> diameter = 25267.99 arcmin
#   Null 913: |u| = 124.3 lambda -> diameter = 25259.60 arcmin
#   Null 914: |u| = 124.5 lambda -> diameter = 25249.33 arcmin
#   Null 915: |u| = 124.6 lambda -> diameter = 25257.40 arcmin
#   Null 916: |u| = 124.7 lambda -> diameter = 25266.20 arcmin
#   Null 917: |u| = 124.8 lambda -> diameter = 25275.20 arcmin
#   Null 918: |u| = 125.1 lambda -> diameter = 25236.11 arcmin
#   Null 919: |u| = 125.2 lambda -> diameter = 25243.31 arcmin
#   Null 920: |u| = 125.3 lambda -> diameter = 25253.85 arcmin
#   Null 921: |u| = 125.4 lambda -> diameter = 25264.23 arcmin
#   Null 922: |u| = 125.4 lambda -> diameter = 25273.48 arcmin
#   Null 923: |u| = 125.5 lambda -> diameter = 25280.73 arcmin
#   Null 924: |u| = 125.6 lambda -> diameter = 25290.87 arcmin
#   Null 925: |u| = 125.7 lambda -> diameter = 25299.57 arcmin
#   Null 926: |u| = 125.8 lambda -> diameter = 25307.99 arcmin
#   Null 927: |u| = 125.9 lambda -> diameter = 25316.90 arcmin
#   Null 928: |u| = 126.0 lambda -> diameter = 25324.30 arcmin
#   Null 929: |u| = 126.1 lambda -> diameter = 25334.24 arcmin
#   Null 930: |u| = 126.2 lambda -> diameter = 25343.12 arcmin
#   Null 931: |u| = 126.3 lambda -> diameter = 25351.79 arcmin
#   Null 932: |u| = 126.4 lambda -> diameter = 25360.49 arcmin
#   Null 933: |u| = 126.5 lambda -> diameter = 25368.07 arcmin
#   Null 934: |u| = 126.6 lambda -> diameter = 25377.92 arcmin
#   Null 935: |u| = 126.6 lambda -> diameter = 25386.72 arcmin
#   Null 936: |u| = 126.7 lambda -> diameter = 25395.58 arcmin
#   Null 937: |u| = 126.8 lambda -> diameter = 25404.00 arcmin
#   Null 938: |u| = 126.9 lambda -> diameter = 25410.76 arcmin
#   Null 939: |u| = 127.0 lambda -> diameter = 25420.87 arcmin
#   Null 940: |u| = 127.1 lambda -> diameter = 25429.58 arcmin
#   Null 941: |u| = 127.2 lambda -> diameter = 25438.18 arcmin
#   Null 942: |u| = 127.3 lambda -> diameter = 25446.17 arcmin
#   Null 943: |u| = 127.4 lambda -> diameter = 25453.91 arcmin
#   Null 944: |u| = 127.5 lambda -> diameter = 25463.66 arcmin
#   Null 945: |u| = 127.6 lambda -> diameter = 25471.81 arcmin
#   Null 946: |u| = 127.7 lambda -> diameter = 25480.57 arcmin
#   Null 947: |u| = 127.8 lambda -> diameter = 25488.87 arcmin
#   Null 948: |u| = 127.9 lambda -> diameter = 25496.19 arcmin
#   Null 949: |u| = 127.9 lambda -> diameter = 25506.33 arcmin
#   Null 950: |u| = 128.0 lambda -> diameter = 25514.69 arcmin
#   Null 951: |u| = 128.1 lambda -> diameter = 25522.85 arcmin
#   Null 952: |u| = 128.3 lambda -> diameter = 25511.54 arcmin
#   Null 953: |u| = 128.5 lambda -> diameter = 25501.91 arcmin
#   Null 954: |u| = 128.8 lambda -> diameter = 25473.82 arcmin
#   Null 955: |u| = 128.9 lambda -> diameter = 25482.75 arcmin
#   Null 956: |u| = 129.0 lambda -> diameter = 25473.56 arcmin
#   Null 957: |u| = 129.2 lambda -> diameter = 25463.02 arcmin
#   Null 958: |u| = 129.5 lambda -> diameter = 25436.69 arcmin
#   Null 959: |u| = 129.7 lambda -> diameter = 25417.24 arcmin
#   Null 960: |u| = 129.8 lambda -> diameter = 25424.58 arcmin
#   Null 961: |u| = 129.9 lambda -> diameter = 25434.32 arcmin
#   Null 962: |u| = 130.0 lambda -> diameter = 25442.70 arcmin
#   Null 963: |u| = 130.1 lambda -> diameter = 25450.73 arcmin
#   Null 964: |u| = 130.5 lambda -> diameter = 25395.18 arcmin
#   Null 965: |u| = 130.6 lambda -> diameter = 25403.63 arcmin
#   Null 966: |u| = 131.0 lambda -> diameter = 25358.38 arcmin
#   Null 967: |u| = 131.1 lambda -> diameter = 25366.60 arcmin
#   Null 968: |u| = 131.3 lambda -> diameter = 25357.04 arcmin
#   Null 969: |u| = 131.4 lambda -> diameter = 25366.92 arcmin
#   Null 970: |u| = 131.4 lambda -> diameter = 25375.23 arcmin
#   Null 971: |u| = 131.5 lambda -> diameter = 25382.43 arcmin
#   Null 972: |u| = 131.7 lambda -> diameter = 25372.95 arcmin
#   Null 973: |u| = 131.8 lambda -> diameter = 25382.98 arcmin
#   Null 974: |u| = 131.9 lambda -> diameter = 25390.99 arcmin
#   Null 975: |u| = 132.0 lambda -> diameter = 25398.22 arcmin
#   Null 976: |u| = 132.9 lambda -> diameter = 25249.06 arcmin
#   Null 977: |u| = 133.0 lambda -> diameter = 25257.57 arcmin
#   Null 978: |u| = 133.1 lambda -> diameter = 25264.38 arcmin
#   Null 979: |u| = 133.2 lambda -> diameter = 25274.37 arcmin
#   Null 980: |u| = 133.3 lambda -> diameter = 25282.47 arcmin
#   Null 981: |u| = 145.1 lambda -> diameter = 23250.20 arcmin
#   Null 982: |u| = 145.5 lambda -> diameter = 23202.25 arcmin
#   Null 983: |u| = 321.6 lambda -> diameter = 10510.09 arcmin
#   Null 984: |u| = 323.3 lambda -> diameter = 10465.93 arcmin
#   Null 985: |u| = 324.9 lambda -> diameter = 10424.51 arcmin
#   Null 986: |u| = 326.1 lambda -> diameter = 10398.25 arcmin
#   Null 987: |u| = 328.1 lambda -> diameter = 10345.32 arcmin
#   Null 988: |u| = 329.4 lambda -> diameter = 10312.51 arcmin
#   Null 989: |u| = 330.5 lambda -> diameter = 10288.31 arcmin
#   Null 990: |u| = 331.7 lambda -> diameter = 10263.25 arcmin
#   Null 991: |u| = 332.4 lambda -> diameter = 10252.15 arcmin
#   Null 992: |u| = 333.3 lambda -> diameter = 10234.07 arcmin
#   Null 993: |u| = 333.5 lambda -> diameter = 10237.60 arcmin
#   Null 994: |u| = 334.6 lambda -> diameter = 10215.32 arcmin
#   Null 995: |u| = 335.4 lambda -> diameter = 10201.11 arcmin
#   Null 996: |u| = 336.5 lambda -> diameter = 10178.96 arcmin
#   Null 997: |u| = 337.8 lambda -> diameter = 10147.65 arcmin
#   Null 998: |u| = 340.1 lambda -> diameter = 10091.55 arcmin
#   Null 999: |u| = 341.3 lambda -> diameter = 10064.43 arcmin
#   Null 1000: |u| = 342.1 lambda -> diameter = 10052.17 arcmin
#   Null 1001: |u| = 343.0 lambda -> diameter = 10033.74 arcmin
#   Null 1002: |u| = 343.3 lambda -> diameter = 10036.41 arcmin
#   Null 1003: |u| = 344.3 lambda -> diameter = 10016.04 arcmin
#   Null 1004: |u| = 345.6 lambda -> diameter = 9988.41 arcmin
#   Null 1005: |u| = 347.0 lambda -> diameter = 9960.46 arcmin
#   Null 1006: |u| = 347.6 lambda -> diameter = 9951.02 arcmin
#   Null 1007: |u| = 349.6 lambda -> diameter = 9904.24 arcmin
#   Null 1008: |u| = 350.5 lambda -> diameter = 9889.01 arcmin
#   Null 1009: |u| = 351.7 lambda -> diameter = 9866.21 arcmin
#   Null 1010: |u| = 352.2 lambda -> diameter = 9860.95 arcmin
#   Null 1011: |u| = 353.4 lambda -> diameter = 9836.37 arcmin
#   Null 1012: |u| = 354.2 lambda -> diameter = 9824.76 arcmin
#   Null 1013: |u| = 355.3 lambda -> diameter = 9804.46 arcmin
#   Null 1014: |u| = 356.1 lambda -> diameter = 9792.81 arcmin
#   Null 1015: |u| = 359.0 lambda -> diameter = 9721.90 arcmin
#   Null 1016: |u| = 360.1 lambda -> diameter = 9702.36 arcmin
#   Null 1017: |u| = 360.8 lambda -> diameter = 9693.34 arcmin
#   Null 1018: |u| = 416.9 lambda -> diameter = 8395.66 arcmin
#   Null 1019: |u| = 417.8 lambda -> diameter = 8387.36 arcmin
#   Null 1020: |u| = 418.7 lambda -> diameter = 8377.23 arcmin
#   Null 1021: |u| = 419.8 lambda -> diameter = 8363.78 arcmin
#   Null 1022: |u| = 420.6 lambda -> diameter = 8354.45 arcmin
#   Null 1023: |u| = 421.5 lambda -> diameter = 8344.66 arcmin
#   Null 1024: |u| = 422.4 lambda -> diameter = 8334.99 arcmin
#   Null 1025: |u| = 423.4 lambda -> diameter = 8325.24 arcmin
#   Null 1026: |u| = 424.3 lambda -> diameter = 8314.90 arcmin
#   Null 1027: |u| = 425.2 lambda -> diameter = 8305.57 arcmin
#   Null 1028: |u| = 426.2 lambda -> diameter = 8293.65 arcmin
#   Null 1029: |u| = 427.1 lambda -> diameter = 8285.10 arcmin
#   Null 1030: |u| = 428.1 lambda -> diameter = 8273.93 arcmin
#   Null 1031: |u| = 428.9 lambda -> diameter = 8265.67 arcmin
#   Null 1032: |u| = 429.9 lambda -> diameter = 8254.55 arcmin
#   Null 1033: |u| = 430.8 lambda -> diameter = 8246.15 arcmin
#   Null 1034: |u| = 431.8 lambda -> diameter = 8234.41 arcmin
#   Null 1035: |u| = 434.5 lambda -> diameter = 8191.02 arcmin
#   Null 1036: |u| = 439.1 lambda -> diameter = 8113.66 arcmin
#   Null 1037: |u| = 482.8 lambda -> diameter = 7385.41 arcmin
#   Null 1038: |u| = 484.2 lambda -> diameter = 7370.81 arcmin
#   Null 1039: |u| = 486.8 lambda -> diameter = 7339.32 arcmin

# %% [markdown]
# ## 6.4 Method B: Full Bessel envelope fit
#
# A nonlinear least-squares fit of $A\,|2J_1(2\pi|u|R)/(2\pi|u|R)|$ to the entire envelope gives a more robust diameter estimate by using all data points, not just the nulls.

# %%
# --- Method B: Full Bessel envelope fit ---
diameter_fit = fit_solar_diameter_bessel(
    np.abs(u_obs), env_obs,
    envelope_std=env_std,
    initial_diameter_arcmin=SOLAR_DIAMETER_ARCMIN_NOMINAL,
)

print(f"Bessel fit diameter: {diameter_fit.diameter_arcmin:.2f} +/- "
      f"{diameter_fit.diameter_err_arcmin:.2f} arcmin")
if "chi2_reduced" in diameter_fit.fitted_params:
    print(f"  Reduced chi-squared: {diameter_fit.fitted_params['chi2_reduced']:.2f}")
if "amplitude" in diameter_fit.fitted_params:
    print(f"  Amplitude scale: {diameter_fit.fitted_params['amplitude']:.4f}")

# Compute the fitted model for plotting
R_fit = diameter_fit.fitted_params.get("R_rad", R_nominal)
A_fit = diameter_fit.fitted_params.get("amplitude", np.nanmax(env_obs))
u_plot = np.linspace(0, np.abs(u_obs).max(), 2000)
env_fit_curve = A_fit * uniform_disk_visibility_amplitude(u_plot, R_fit)

# Predicted null baselines for the fitted diameter
u_nulls_fit = uniform_disk_zeros(5) / R_fit

# Plot
fig, ax = plot_bessel_envelope_fit(
    np.abs(u_obs), env_obs,
    fitted_envelope=A_fit * uniform_disk_visibility_amplitude(np.abs(u_obs), R_fit),
    zero_crossings_u=u_nulls_fit[u_nulls_fit < np.abs(u_obs).max()],
    fitted_diameter_arcmin=diameter_fit.diameter_arcmin,
)
plt.show()
# Out:
# Bessel fit diameter: 0.00 +/- 197.40 arcmin
#   Reduced chi-squared: 1239.11
#   Amplitude scale: 0.1017

# %% [markdown]
# ## 6.5 Diameter summary
#
# We compare the zero-crossing and full-fit diameter estimates against the known optical solar diameter ($\sim 31.6'$ at this time of year).

# %%
# --- Diameter summary ---
diameters = []
errors = []
labels = []

if diameter_zeros is not None and np.isfinite(diameter_zeros.diameter_arcmin):
    diameters.append(diameter_zeros.diameter_arcmin)
    errors.append(diameter_zeros.diameter_err_arcmin)
    labels.append("Zero crossings")

if np.isfinite(diameter_fit.diameter_arcmin):
    diameters.append(diameter_fit.diameter_arcmin)
    errors.append(diameter_fit.diameter_err_arcmin)
    labels.append("Bessel fit")

if diameters:
    fig, ax = plot_solar_diameter_summary(
        np.array(diameters), np.array(errors), labels,
        nominal_arcmin=SOLAR_DIAMETER_ARCMIN_NOMINAL,
    )
    plt.show()

    print("\n--- Diameter Summary ---")
    for l, d, e in zip(labels, diameters, errors):
        pct_err = abs(d - SOLAR_DIAMETER_ARCMIN_NOMINAL) / SOLAR_DIAMETER_ARCMIN_NOMINAL * 100
        print(f"  {l:<20}: {d:.2f} +/- {e:.2f} arcmin  "
              f"({pct_err:.1f}% from nominal {SOLAR_DIAMETER_ARCMIN_NOMINAL}')")
else:
    print("No diameter estimates available — projected baseline range may not span a Bessel null.")
# Out:
# --- Diameter Summary ---
#   Zero crossings      : 23402.07 +/- 122.92 arcmin  (73957.2% from nominal 31.6')
#   Bessel fit          : 0.00 +/- 197.40 arcmin  (100.0% from nominal 31.6')

# %% [markdown]
# # Part VII: Sunspot Characterisation
#
# ## 7.1 Physical basis
#
# At X-band ($\sim 10\;\mathrm{GHz}$), the quiet Sun has a brightness temperature $T_b \approx 10\,000$–$20\,000\;\mathrm{K}$ from the chromosphere and transition region. Sunspots — magnetically active regions — can appear as either enhanced or suppressed emission depending on the observing frequency and the spot's altitude in the solar atmosphere.
#
# The key interferometric diagnostic is the **residual amplitude at the Bessel nulls**. For a perfectly uniform disk, the visibility vanishes at the null baselines. Any asymmetric structure (sunspots, active regions, limb brightening) breaks this cancellation:
#
# $$f_{\mathrm{spot}} \approx \frac{|V_{\mathrm{null}}|}{|V(0)|}.$$
#
# This gives the **flux fraction** of the anomalous component. If multiple nulls are observed, the variation of the residual amplitude with baseline constrains the spot size and position.
#
# ## 7.2 Residual analysis at Bessel nulls

# %%
# --- Sunspot detection: residuals from the uniform-disk model ---
# Compute the disk model at the observed baselines
disk_model_at_obs = A_fit * uniform_disk_visibility_amplitude(np.abs(u_obs), R_fit)
residuals = env_obs - disk_model_at_obs

# Noise estimate from the envelope standard error
noise_est = env_std.copy()
noise_est[noise_est < 1e-10] = np.nanmedian(noise_est[noise_est > 0])

# Detect anomalies
detections = detect_sunspot_anomalies(
    np.abs(u_obs), env_obs, disk_model_at_obs, noise_est,
    sigma_threshold=3.0,
)

print(f"Detected {len(detections)} sunspot anomaly(ies) at >3 sigma:")
for d in detections:
    print(f"  Null {d.null_index}: |u| = {d.u_lambda_at_null:.0f} lambda, "
          f"residual = {d.residual_amplitude:.4f}, "
          f"significance = {d.significance_sigma:.1f} sigma, "
          f"flux fraction = {d.estimated_flux_fraction:.4f}")

# Also use the simpler characterization
spot_info = characterize_sunspot_flux(
    np.abs(u_obs), env_obs,
    diameter_fit.diameter_arcmin,
    n_nulls=3,
)

print("\n--- Sunspot flux fractions at theoretical null locations ---")
for k in range(len(spot_info["null_u_R"])):
    print(f"  Null {k+1}: |u|_theory = {spot_info['null_u_observed'][k]:.0f} lambda, "
          f"amplitude = {spot_info['null_amplitude'][k]:.4f}, "
          f"flux fraction = {spot_info['flux_fraction'][k]:.4f}")
# Out:
# Detected 1199 sunspot anomaly(ies) at >3 sigma:
#   Null 1: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 2: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 3: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 4: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 5: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 6: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 7: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 8: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 9: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 10: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 11: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 12: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 13: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 14: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 15: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 16: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 17: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 18: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 19: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 20: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 21: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 22: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 23: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 24: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 25: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 26: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 27: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 28: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 29: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 30: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 31: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 32: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 33: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 34: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 35: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 36: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 37: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 38: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 39: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 40: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 41: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 42: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 43: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 44: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 45: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 46: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 47: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 48: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 49: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 50: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 51: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 52: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 53: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 54: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 55: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 56: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 57: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 58: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 59: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 60: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 61: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 62: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 63: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 64: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 65: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 66: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 67: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 68: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 69: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 70: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 71: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 72: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 73: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 74: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 75: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 76: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 77: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 78: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 79: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 80: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 81: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 82: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 83: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 84: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 85: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 86: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 87: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 88: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 89: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 90: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 91: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 92: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 93: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 94: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 95: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 96: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 97: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 98: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 99: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 100: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 101: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 102: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 103: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 104: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 105: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 106: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 107: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 108: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 109: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 110: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 111: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 112: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 113: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 114: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 115: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 116: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 117: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 118: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 119: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 120: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 121: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 122: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 123: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 124: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 125: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 126: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 127: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 128: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 129: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 130: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 131: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 132: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 133: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 134: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 135: |u| = 511 lambda, residual = 0.6071, significance = 105.5 sigma, flux fraction = 1.0000
#   Null 136: |u| = 508 lambda, residual = 0.5817, significance = 103.6 sigma, flux fraction = 0.9641
#   Null 137: |u| = 508 lambda, residual = 0.5817, significance = 103.6 sigma, flux fraction = 0.9641
#   Null 138: |u| = 508 lambda, residual = 0.5817, significance = 103.6 sigma, flux fraction = 0.9641
#   Null 139: |u| = 508 lambda, residual = 0.5817, significance = 103.6 sigma, flux fraction = 0.9641
#   Null 140: |u| = 508 lambda, residual = 0.5817, significance = 103.6 sigma, flux fraction = 0.9641
#   Null 141: |u| = 506 lambda, residual = 0.5787, significance = 110.0 sigma, flux fraction = 0.9599
#   Null 142: |u| = 506 lambda, residual = 0.5787, significance = 110.0 sigma, flux fraction = 0.9599
#   Null 143: |u| = 506 lambda, residual = 0.5787, significance = 110.0 sigma, flux fraction = 0.9599
#   Null 144: |u| = 506 lambda, residual = 0.5609, significance = 126.2 sigma, flux fraction = 0.9347
#   Null 145: |u| = 505 lambda, residual = 0.5608, significance = 111.0 sigma, flux fraction = 0.9346
#   Null 146: |u| = 505 lambda, residual = 0.5548, significance = 122.3 sigma, flux fraction = 0.9261
#   Null 147: |u| = 504 lambda, residual = 0.5543, significance = 110.4 sigma, flux fraction = 0.9255
#   Null 148: |u| = 503 lambda, residual = 0.5226, significance = 99.0 sigma, flux fraction = 0.8807
#   Null 149: |u| = 503 lambda, residual = 0.5226, significance = 99.0 sigma, flux fraction = 0.8807
#   Null 150: |u| = 503 lambda, residual = 0.5200, significance = 99.0 sigma, flux fraction = 0.8770
#   Null 151: |u| = 502 lambda, residual = 0.4222, significance = 93.1 sigma, flux fraction = 0.7390
#   Null 152: |u| = 502 lambda, residual = 0.4125, significance = 120.4 sigma, flux fraction = 0.7255
#   Null 153: |u| = 502 lambda, residual = 0.4125, significance = 120.4 sigma, flux fraction = 0.7255
#   Null 154: |u| = 501 lambda, residual = 0.3903, significance = 92.4 sigma, flux fraction = 0.6941
#   Null 155: |u| = 501 lambda, residual = 0.3823, significance = 112.6 sigma, flux fraction = 0.6828
#   Null 156: |u| = 500 lambda, residual = 0.3572, significance = 93.2 sigma, flux fraction = 0.6473
#   Null 157: |u| = 500 lambda, residual = 0.3572, significance = 93.2 sigma, flux fraction = 0.6473
#   Null 158: |u| = 499 lambda, residual = 0.3301, significance = 87.4 sigma, flux fraction = 0.6092
#   Null 159: |u| = 499 lambda, residual = 0.3158, significance = 100.7 sigma, flux fraction = 0.5890
#   Null 160: |u| = 497 lambda, residual = 0.2346, significance = 84.5 sigma, flux fraction = 0.4744
#   Null 161: |u| = 496 lambda, residual = 0.1805, significance = 64.2 sigma, flux fraction = 0.3981
#   Null 162: |u| = 495 lambda, residual = 0.1723, significance = 60.3 sigma, flux fraction = 0.3865
#   Null 163: |u| = 494 lambda, residual = 0.1224, significance = 71.0 sigma, flux fraction = 0.3161
#   Null 164: |u| = 494 lambda, residual = 0.1176, significance = 49.5 sigma, flux fraction = 0.3093
#   Null 165: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 166: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 167: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 168: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 169: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 170: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 171: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 172: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 173: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 174: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 175: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 176: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 177: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 178: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 179: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 180: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 181: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 182: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 183: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 184: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 185: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 186: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 187: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 188: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 189: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 190: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 191: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 192: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 193: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 194: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 195: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 196: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 197: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 198: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 199: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 200: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 201: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 202: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 203: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 204: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 205: |u| = 467 lambda, residual = 0.1144, significance = 48.7 sigma, flux fraction = 0.3048
#   Null 206: |u| = 465 lambda, residual = 0.1136, significance = 48.3 sigma, flux fraction = 0.3037
#   Null 207: |u| = 465 lambda, residual = 0.1136, significance = 48.3 sigma, flux fraction = 0.3037
#   Null 208: |u| = 464 lambda, residual = 0.1091, significance = 47.2 sigma, flux fraction = 0.2973
#   Null 209: |u| = 464 lambda, residual = 0.1091, significance = 47.2 sigma, flux fraction = 0.2973
#   Null 210: |u| = 463 lambda, residual = 0.1084, significance = 47.6 sigma, flux fraction = 0.2964
#   Null 211: |u| = 463 lambda, residual = 0.1084, significance = 47.6 sigma, flux fraction = 0.2964
#   Null 212: |u| = 463 lambda, residual = 0.1084, significance = 47.6 sigma, flux fraction = 0.2964
#   Null 213: |u| = 463 lambda, residual = 0.1073, significance = 47.4 sigma, flux fraction = 0.2948
#   Null 214: |u| = 463 lambda, residual = 0.1049, significance = 54.3 sigma, flux fraction = 0.2915
#   Null 215: |u| = 462 lambda, residual = 0.1045, significance = 48.4 sigma, flux fraction = 0.2909
#   Null 216: |u| = 462 lambda, residual = 0.1045, significance = 48.4 sigma, flux fraction = 0.2909
#   Null 217: |u| = 462 lambda, residual = 0.1045, significance = 48.4 sigma, flux fraction = 0.2909
#   Null 218: |u| = 462 lambda, residual = 0.1045, significance = 48.4 sigma, flux fraction = 0.2909
#   Null 219: |u| = 461 lambda, residual = 0.1041, significance = 50.3 sigma, flux fraction = 0.2902
#   Null 220: |u| = 460 lambda, residual = 0.0971, significance = 45.4 sigma, flux fraction = 0.2804
#   Null 221: |u| = 460 lambda, residual = 0.0971, significance = 45.4 sigma, flux fraction = 0.2804
#   Null 222: |u| = 459 lambda, residual = 0.0913, significance = 42.9 sigma, flux fraction = 0.2722
#   Null 223: |u| = 459 lambda, residual = 0.0913, significance = 42.9 sigma, flux fraction = 0.2722
#   Null 224: |u| = 459 lambda, residual = 0.0913, significance = 42.9 sigma, flux fraction = 0.2722
#   Null 225: |u| = 458 lambda, residual = 0.0875, significance = 43.6 sigma, flux fraction = 0.2669
#   Null 226: |u| = 458 lambda, residual = 0.0875, significance = 43.6 sigma, flux fraction = 0.2669
#   Null 227: |u| = 458 lambda, residual = 0.0875, significance = 43.6 sigma, flux fraction = 0.2669
#   Null 228: |u| = 458 lambda, residual = 0.0875, significance = 43.6 sigma, flux fraction = 0.2669
#   Null 229: |u| = 458 lambda, residual = 0.0875, significance = 43.6 sigma, flux fraction = 0.2669
#   Null 230: |u| = 457 lambda, residual = 0.0820, significance = 41.0 sigma, flux fraction = 0.2591
#   Null 231: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 232: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 233: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 234: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 235: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 236: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 237: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 238: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 239: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 240: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 241: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 242: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 243: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 244: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 245: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 246: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 247: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 248: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 249: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 250: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 251: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 252: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 253: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 254: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 255: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 256: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 257: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 258: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 259: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 260: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 261: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 262: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 263: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 264: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 265: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 266: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 267: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 268: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 269: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 270: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 271: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 272: |u| = 435 lambda, residual = -0.0807, significance = 117.3 sigma, flux fraction = 0.0296
#   Null 273: |u| = 434 lambda, residual = -0.0800, significance = 109.3 sigma, flux fraction = 0.0306
#   Null 274: |u| = 433 lambda, residual = -0.0787, significance = 106.3 sigma, flux fraction = 0.0324
#   Null 275: |u| = 433 lambda, residual = -0.0787, significance = 106.3 sigma, flux fraction = 0.0324
#   Null 276: |u| = 433 lambda, residual = -0.0777, significance = 101.3 sigma, flux fraction = 0.0338
#   Null 277: |u| = 432 lambda, residual = -0.0749, significance = 92.7 sigma, flux fraction = 0.0377
#   Null 278: |u| = 432 lambda, residual = -0.0749, significance = 92.7 sigma, flux fraction = 0.0377
#   Null 279: |u| = 431 lambda, residual = -0.0689, significance = 74.4 sigma, flux fraction = 0.0462
#   Null 280: |u| = 431 lambda, residual = -0.0689, significance = 74.4 sigma, flux fraction = 0.0462
#   Null 281: |u| = 430 lambda, residual = -0.0685, significance = 72.7 sigma, flux fraction = 0.0468
#   Null 282: |u| = 430 lambda, residual = -0.0685, significance = 72.7 sigma, flux fraction = 0.0468
#   Null 283: |u| = 428 lambda, residual = -0.0609, significance = 62.7 sigma, flux fraction = 0.0575
#   Null 284: |u| = 428 lambda, residual = -0.0609, significance = 62.7 sigma, flux fraction = 0.0575
#   Null 285: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 286: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 287: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 288: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 289: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 290: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 291: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 292: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 293: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 294: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 295: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 296: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 297: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 298: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 299: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 300: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 301: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 302: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 303: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 304: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 305: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 306: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 307: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 308: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 309: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 310: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 311: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 312: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 313: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 314: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 315: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 316: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 317: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 318: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 319: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 320: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 321: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 322: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 323: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 324: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 325: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 326: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 327: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 328: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 329: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 330: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 331: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 332: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 333: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 334: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 335: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 336: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 337: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 338: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 339: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 340: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 341: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 342: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 343: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 344: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 345: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 346: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 347: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 348: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 349: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 350: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 351: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 352: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 353: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 354: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 355: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 356: |u| = 386 lambda, residual = 0.0587, significance = 30.6 sigma, flux fraction = 0.2262
#   Null 357: |u| = 384 lambda, residual = 0.0575, significance = 32.2 sigma, flux fraction = 0.2246
#   Null 358: |u| = 384 lambda, residual = 0.0575, significance = 32.2 sigma, flux fraction = 0.2246
#   Null 359: |u| = 384 lambda, residual = 0.0575, significance = 32.2 sigma, flux fraction = 0.2246
#   Null 360: |u| = 384 lambda, residual = 0.0575, significance = 32.2 sigma, flux fraction = 0.2246
#   Null 361: |u| = 384 lambda, residual = 0.0571, significance = 31.3 sigma, flux fraction = 0.2241
#   Null 362: |u| = 383 lambda, residual = 0.0569, significance = 29.8 sigma, flux fraction = 0.2237
#   Null 363: |u| = 382 lambda, residual = 0.0551, significance = 30.5 sigma, flux fraction = 0.2212
#   Null 364: |u| = 379 lambda, residual = 0.0535, significance = 29.8 sigma, flux fraction = 0.2189
#   Null 365: |u| = 379 lambda, residual = 0.0535, significance = 29.8 sigma, flux fraction = 0.2189
#   Null 366: |u| = 379 lambda, residual = 0.0535, significance = 29.8 sigma, flux fraction = 0.2189
#   Null 367: |u| = 376 lambda, residual = 0.0351, significance = 19.5 sigma, flux fraction = 0.1929
#   Null 368: |u| = 375 lambda, residual = 0.0342, significance = 21.2 sigma, flux fraction = 0.1917
#   Null 369: |u| = 372 lambda, residual = 0.0331, significance = 19.4 sigma, flux fraction = 0.1901
#   Null 370: |u| = 372 lambda, residual = 0.0331, significance = 19.4 sigma, flux fraction = 0.1901
#   Null 371: |u| = 372 lambda, residual = 0.0331, significance = 19.4 sigma, flux fraction = 0.1901
#   Null 372: |u| = 372 lambda, residual = 0.0331, significance = 19.4 sigma, flux fraction = 0.1901
#   Null 373: |u| = 372 lambda, residual = 0.0331, significance = 19.4 sigma, flux fraction = 0.1901
#   Null 374: |u| = 372 lambda, residual = 0.0331, significance = 19.4 sigma, flux fraction = 0.1901
#   Null 375: |u| = 372 lambda, residual = 0.0331, significance = 19.4 sigma, flux fraction = 0.1901
#   Null 376: |u| = 372 lambda, residual = 0.0331, significance = 18.7 sigma, flux fraction = 0.1901
#   Null 377: |u| = 304 lambda, residual = 0.0304, significance = 18.0 sigma, flux fraction = 0.1863
#   Null 378: |u| = 304 lambda, residual = 0.0312, significance = 17.0 sigma, flux fraction = 0.1874
#   Null 379: |u| = 304 lambda, residual = 0.0312, significance = 17.0 sigma, flux fraction = 0.1874
#   Null 380: |u| = 304 lambda, residual = 0.0312, significance = 17.0 sigma, flux fraction = 0.1874
#   Null 381: |u| = 304 lambda, residual = 0.0312, significance = 17.0 sigma, flux fraction = 0.1874
#   Null 382: |u| = 304 lambda, residual = 0.0312, significance = 17.0 sigma, flux fraction = 0.1874
#   Null 383: |u| = 302 lambda, residual = 0.0331, significance = 18.6 sigma, flux fraction = 0.1902
#   Null 384: |u| = 302 lambda, residual = 0.0334, significance = 18.6 sigma, flux fraction = 0.1905
#   Null 385: |u| = 302 lambda, residual = 0.0334, significance = 18.6 sigma, flux fraction = 0.1905
#   Null 386: |u| = 301 lambda, residual = 0.0335, significance = 20.4 sigma, flux fraction = 0.1907
#   Null 387: |u| = 301 lambda, residual = 0.0352, significance = 20.0 sigma, flux fraction = 0.1930
#   Null 388: |u| = 300 lambda, residual = 0.0367, significance = 20.4 sigma, flux fraction = 0.1952
#   Null 389: |u| = 300 lambda, residual = 0.0377, significance = 21.2 sigma, flux fraction = 0.1967
#   Null 390: |u| = 299 lambda, residual = 0.0387, significance = 22.3 sigma, flux fraction = 0.1980
#   Null 391: |u| = 298 lambda, residual = 0.0407, significance = 22.5 sigma, flux fraction = 0.2008
#   Null 392: |u| = 298 lambda, residual = 0.0407, significance = 22.5 sigma, flux fraction = 0.2008
#   Null 393: |u| = 298 lambda, residual = 0.0407, significance = 22.5 sigma, flux fraction = 0.2008
#   Null 394: |u| = 298 lambda, residual = 0.0407, significance = 22.5 sigma, flux fraction = 0.2008
#   Null 395: |u| = 298 lambda, residual = 0.0420, significance = 23.7 sigma, flux fraction = 0.2027
#   Null 396: |u| = 298 lambda, residual = 0.0420, significance = 23.7 sigma, flux fraction = 0.2027
#   Null 397: |u| = 296 lambda, residual = 0.0434, significance = 22.6 sigma, flux fraction = 0.2047
#   Null 398: |u| = 296 lambda, residual = 0.0437, significance = 22.7 sigma, flux fraction = 0.2051
#   Null 399: |u| = 296 lambda, residual = 0.0437, significance = 22.7 sigma, flux fraction = 0.2051
#   Null 400: |u| = 296 lambda, residual = 0.0437, significance = 22.7 sigma, flux fraction = 0.2051
#   Null 401: |u| = 296 lambda, residual = 0.0437, significance = 22.7 sigma, flux fraction = 0.2051
#   Null 402: |u| = 296 lambda, residual = 0.0437, significance = 22.7 sigma, flux fraction = 0.2051
#   Null 403: |u| = 294 lambda, residual = 0.0438, significance = 23.6 sigma, flux fraction = 0.2052
#   Null 404: |u| = 294 lambda, residual = 0.0451, significance = 25.3 sigma, flux fraction = 0.2071
#   Null 405: |u| = 294 lambda, residual = 0.0451, significance = 25.3 sigma, flux fraction = 0.2071
#   Null 406: |u| = 294 lambda, residual = 0.0451, significance = 25.3 sigma, flux fraction = 0.2071
#   Null 407: |u| = 294 lambda, residual = 0.0451, significance = 25.3 sigma, flux fraction = 0.2071
#   Null 408: |u| = 291 lambda, residual = 0.0470, significance = 27.0 sigma, flux fraction = 0.2098
#   Null 409: |u| = 291 lambda, residual = 0.0470, significance = 27.0 sigma, flux fraction = 0.2098
#   Null 410: |u| = 290 lambda, residual = 0.0475, significance = 24.5 sigma, flux fraction = 0.2104
#   Null 411: |u| = 290 lambda, residual = 0.0475, significance = 24.5 sigma, flux fraction = 0.2104
#   Null 412: |u| = 290 lambda, residual = 0.0496, significance = 28.5 sigma, flux fraction = 0.2134
#   Null 413: |u| = 289 lambda, residual = 0.0532, significance = 27.0 sigma, flux fraction = 0.2185
#   Null 414: |u| = 289 lambda, residual = 0.0549, significance = 26.8 sigma, flux fraction = 0.2209
#   Null 415: |u| = 289 lambda, residual = 0.0549, significance = 26.8 sigma, flux fraction = 0.2209
#   Null 416: |u| = 289 lambda, residual = 0.0549, significance = 26.8 sigma, flux fraction = 0.2209
#   Null 417: |u| = 289 lambda, residual = 0.0549, significance = 26.8 sigma, flux fraction = 0.2209
#   Null 418: |u| = 289 lambda, residual = 0.0549, significance = 26.8 sigma, flux fraction = 0.2209
#   Null 419: |u| = 289 lambda, residual = 0.0549, significance = 26.8 sigma, flux fraction = 0.2209
#   Null 420: |u| = 289 lambda, residual = 0.0549, significance = 26.8 sigma, flux fraction = 0.2209
#   Null 421: |u| = 289 lambda, residual = 0.0549, significance = 26.8 sigma, flux fraction = 0.2209
#   Null 422: |u| = 289 lambda, residual = 0.0549, significance = 26.8 sigma, flux fraction = 0.2209
#   Null 423: |u| = 289 lambda, residual = 0.0549, significance = 26.8 sigma, flux fraction = 0.2209
#   Null 424: |u| = 289 lambda, residual = 0.0549, significance = 26.8 sigma, flux fraction = 0.2209
#   Null 425: |u| = 289 lambda, residual = 0.0549, significance = 26.8 sigma, flux fraction = 0.2209
#   Null 426: |u| = 289 lambda, residual = 0.0549, significance = 26.8 sigma, flux fraction = 0.2209
#   Null 427: |u| = 289 lambda, residual = 0.0549, significance = 26.8 sigma, flux fraction = 0.2209
#   Null 428: |u| = 289 lambda, residual = 0.0549, significance = 26.8 sigma, flux fraction = 0.2209
#   Null 429: |u| = 281 lambda, residual = 0.0577, significance = 30.1 sigma, flux fraction = 0.2249
#   Null 430: |u| = 281 lambda, residual = 0.0577, significance = 30.1 sigma, flux fraction = 0.2249
#   Null 431: |u| = 281 lambda, residual = 0.0577, significance = 30.1 sigma, flux fraction = 0.2249
#   Null 432: |u| = 281 lambda, residual = 0.0577, significance = 30.1 sigma, flux fraction = 0.2249
#   Null 433: |u| = 280 lambda, residual = 0.0584, significance = 32.4 sigma, flux fraction = 0.2258
#   Null 434: |u| = 280 lambda, residual = 0.0584, significance = 32.4 sigma, flux fraction = 0.2258
#   Null 435: |u| = 278 lambda, residual = 0.0622, significance = 31.9 sigma, flux fraction = 0.2312
#   Null 436: |u| = 278 lambda, residual = 0.0622, significance = 31.9 sigma, flux fraction = 0.2312
#   Null 437: |u| = 278 lambda, residual = 0.0622, significance = 31.9 sigma, flux fraction = 0.2312
#   Null 438: |u| = 278 lambda, residual = 0.0622, significance = 31.9 sigma, flux fraction = 0.2312
#   Null 439: |u| = 278 lambda, residual = 0.0622, significance = 31.9 sigma, flux fraction = 0.2312
#   Null 440: |u| = 278 lambda, residual = 0.0622, significance = 31.9 sigma, flux fraction = 0.2312
#   Null 441: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 442: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 443: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 444: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 445: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 446: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 447: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 448: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 449: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 450: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 451: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 452: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 453: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 454: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 455: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 456: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 457: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 458: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 459: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 460: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 461: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 462: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 463: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 464: |u| = 276 lambda, residual = 0.0630, significance = 31.9 sigma, flux fraction = 0.2323
#   Null 465: |u| = 263 lambda, residual = 0.0643, significance = 33.5 sigma, flux fraction = 0.2342
#   Null 466: |u| = 263 lambda, residual = 0.0643, significance = 33.5 sigma, flux fraction = 0.2342
#   Null 467: |u| = 263 lambda, residual = 0.0643, significance = 33.5 sigma, flux fraction = 0.2342
#   Null 468: |u| = 261 lambda, residual = 0.0682, significance = 34.0 sigma, flux fraction = 0.2396
#   Null 469: |u| = 261 lambda, residual = 0.0682, significance = 34.0 sigma, flux fraction = 0.2396
#   Null 470: |u| = 261 lambda, residual = 0.0682, significance = 34.0 sigma, flux fraction = 0.2396
#   Null 471: |u| = 261 lambda, residual = 0.0682, significance = 34.0 sigma, flux fraction = 0.2396
#   Null 472: |u| = 261 lambda, residual = 0.0682, significance = 34.0 sigma, flux fraction = 0.2396
#   Null 473: |u| = 261 lambda, residual = 0.0682, significance = 34.0 sigma, flux fraction = 0.2396
#   Null 474: |u| = 261 lambda, residual = 0.0682, significance = 34.0 sigma, flux fraction = 0.2396
#   Null 475: |u| = 261 lambda, residual = 0.0682, significance = 34.0 sigma, flux fraction = 0.2396
#   Null 476: |u| = 261 lambda, residual = 0.0682, significance = 34.0 sigma, flux fraction = 0.2396
#   Null 477: |u| = 261 lambda, residual = 0.0682, significance = 34.0 sigma, flux fraction = 0.2396
#   Null 478: |u| = 261 lambda, residual = 0.0682, significance = 34.0 sigma, flux fraction = 0.2396
#   Null 479: |u| = 261 lambda, residual = 0.0682, significance = 34.0 sigma, flux fraction = 0.2396
#   Null 480: |u| = 261 lambda, residual = 0.0682, significance = 34.0 sigma, flux fraction = 0.2396
#   Null 481: |u| = 261 lambda, residual = 0.0682, significance = 34.0 sigma, flux fraction = 0.2396
#   Null 482: |u| = 261 lambda, residual = 0.0682, significance = 34.0 sigma, flux fraction = 0.2396
# ...
#   Null 1044: |u| = 87 lambda, residual = -0.0422, significance = 31.0 sigma, flux fraction = 0.0838
#   Null 1045: |u| = 89 lambda, residual = -0.0411, significance = 29.5 sigma, flux fraction = 0.0855
#   Null 1046: |u| = 89 lambda, residual = -0.0411, significance = 29.5 sigma, flux fraction = 0.0855
#   Null 1047: |u| = 89 lambda, residual = -0.0411, significance = 29.5 sigma, flux fraction = 0.0855
#   Null 1048: |u| = 89 lambda, residual = -0.0411, significance = 29.5 sigma, flux fraction = 0.0855
#   Null 1049: |u| = 90 lambda, residual = -0.0406, significance = 30.3 sigma, flux fraction = 0.0862
#   Null 1050: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1051: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1052: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1053: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1054: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1055: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1056: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1057: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1058: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1059: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1060: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1061: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1062: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1063: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1064: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1065: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1066: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1067: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1068: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1069: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1070: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1071: |u| = 103 lambda, residual = -0.0395, significance = 28.2 sigma, flux fraction = 0.0878
#   Null 1072: |u| = 106 lambda, residual = -0.0376, significance = 27.8 sigma, flux fraction = 0.0903
#   Null 1073: |u| = 106 lambda, residual = -0.0376, significance = 27.8 sigma, flux fraction = 0.0903
#   Null 1074: |u| = 106 lambda, residual = -0.0376, significance = 27.8 sigma, flux fraction = 0.0903
#   Null 1075: |u| = 106 lambda, residual = -0.0376, significance = 27.8 sigma, flux fraction = 0.0903
#   Null 1076: |u| = 107 lambda, residual = -0.0373, significance = 26.4 sigma, flux fraction = 0.0909
#   Null 1077: |u| = 107 lambda, residual = -0.0373, significance = 26.4 sigma, flux fraction = 0.0909
#   Null 1078: |u| = 107 lambda, residual = -0.0373, significance = 26.4 sigma, flux fraction = 0.0909
#   Null 1079: |u| = 107 lambda, residual = -0.0369, significance = 26.4 sigma, flux fraction = 0.0914
#   Null 1080: |u| = 108 lambda, residual = -0.0367, significance = 26.5 sigma, flux fraction = 0.0916
#   Null 1081: |u| = 108 lambda, residual = -0.0367, significance = 26.5 sigma, flux fraction = 0.0916
#   Null 1082: |u| = 108 lambda, residual = -0.0363, significance = 26.6 sigma, flux fraction = 0.0922
#   Null 1083: |u| = 132 lambda, residual = 0.0385, significance = 20.9 sigma, flux fraction = 0.1978
#   Null 1084: |u| = 132 lambda, residual = 0.0385, significance = 20.9 sigma, flux fraction = 0.1978
#   Null 1085: |u| = 132 lambda, residual = 0.0385, significance = 20.9 sigma, flux fraction = 0.1978
#   Null 1086: |u| = 132 lambda, residual = 0.0385, significance = 20.9 sigma, flux fraction = 0.1978
#   Null 1087: |u| = 132 lambda, residual = 0.0385, significance = 20.9 sigma, flux fraction = 0.1978
#   Null 1088: |u| = 132 lambda, residual = 0.0385, significance = 20.9 sigma, flux fraction = 0.1978
#   Null 1089: |u| = 132 lambda, residual = 0.0385, significance = 20.9 sigma, flux fraction = 0.1978
#   Null 1090: |u| = 132 lambda, residual = 0.0385, significance = 20.9 sigma, flux fraction = 0.1978
#   Null 1091: |u| = 132 lambda, residual = 0.0385, significance = 20.9 sigma, flux fraction = 0.1978
#   Null 1092: |u| = 132 lambda, residual = 0.0385, significance = 20.9 sigma, flux fraction = 0.1978
#   Null 1093: |u| = 137 lambda, residual = 0.0391, significance = 21.6 sigma, flux fraction = 0.1986
#   Null 1094: |u| = 139 lambda, residual = 0.0398, significance = 20.7 sigma, flux fraction = 0.1996
#   Null 1095: |u| = 140 lambda, residual = 0.0400, significance = 21.8 sigma, flux fraction = 0.1999
#   Null 1096: |u| = 140 lambda, residual = 0.0401, significance = 21.1 sigma, flux fraction = 0.2000
#   Null 1097: |u| = 141 lambda, residual = 0.0410, significance = 22.7 sigma, flux fraction = 0.2012
#   Null 1098: |u| = 141 lambda, residual = 0.0417, significance = 22.8 sigma, flux fraction = 0.2023
#   Null 1099: |u| = 141 lambda, residual = 0.0423, significance = 22.1 sigma, flux fraction = 0.2031
#   Null 1100: |u| = 142 lambda, residual = 0.0433, significance = 23.2 sigma, flux fraction = 0.2045
#   Null 1101: |u| = 142 lambda, residual = 0.0433, significance = 23.2 sigma, flux fraction = 0.2045
#   Null 1102: |u| = 142 lambda, residual = 0.0433, significance = 23.2 sigma, flux fraction = 0.2045
#   Null 1103: |u| = 142 lambda, residual = 0.0433, significance = 23.2 sigma, flux fraction = 0.2045
#   Null 1104: |u| = 142 lambda, residual = 0.0433, significance = 23.2 sigma, flux fraction = 0.2045
#   Null 1105: |u| = 142 lambda, residual = 0.0433, significance = 23.2 sigma, flux fraction = 0.2045
#   Null 1106: |u| = 142 lambda, residual = 0.0433, significance = 23.2 sigma, flux fraction = 0.2045
#   Null 1107: |u| = 147 lambda, residual = 0.0452, significance = 25.5 sigma, flux fraction = 0.2073
#   Null 1108: |u| = 147 lambda, residual = 0.0452, significance = 25.5 sigma, flux fraction = 0.2073
#   Null 1109: |u| = 148 lambda, residual = 0.0464, significance = 26.2 sigma, flux fraction = 0.2090
#   Null 1110: |u| = 149 lambda, residual = 0.0506, significance = 27.4 sigma, flux fraction = 0.2148
#   Null 1111: |u| = 150 lambda, residual = 0.0509, significance = 27.6 sigma, flux fraction = 0.2152
#   Null 1112: |u| = 150 lambda, residual = 0.0509, significance = 27.6 sigma, flux fraction = 0.2152
#   Null 1113: |u| = 151 lambda, residual = 0.0524, significance = 27.2 sigma, flux fraction = 0.2174
#   Null 1114: |u| = 151 lambda, residual = 0.0524, significance = 27.2 sigma, flux fraction = 0.2174
#   Null 1115: |u| = 153 lambda, residual = 0.0534, significance = 28.5 sigma, flux fraction = 0.2187
#   Null 1116: |u| = 153 lambda, residual = 0.0534, significance = 28.5 sigma, flux fraction = 0.2187
#   Null 1117: |u| = 157 lambda, residual = 0.0564, significance = 29.5 sigma, flux fraction = 0.2230
#   Null 1118: |u| = 157 lambda, residual = 0.0564, significance = 29.5 sigma, flux fraction = 0.2230
#   Null 1119: |u| = 158 lambda, residual = 0.0594, significance = 30.2 sigma, flux fraction = 0.2272
#   Null 1120: |u| = 159 lambda, residual = 0.0618, significance = 30.1 sigma, flux fraction = 0.2307
#   Null 1121: |u| = 159 lambda, residual = 0.0618, significance = 30.1 sigma, flux fraction = 0.2307
#   Null 1122: |u| = 159 lambda, residual = 0.0618, significance = 30.1 sigma, flux fraction = 0.2307
#   Null 1123: |u| = 159 lambda, residual = 0.0618, significance = 30.1 sigma, flux fraction = 0.2307
#   Null 1124: |u| = 159 lambda, residual = 0.0618, significance = 30.1 sigma, flux fraction = 0.2307
#   Null 1125: |u| = 159 lambda, residual = 0.0618, significance = 30.1 sigma, flux fraction = 0.2307
#   Null 1126: |u| = 159 lambda, residual = 0.0618, significance = 30.1 sigma, flux fraction = 0.2307
#   Null 1127: |u| = 159 lambda, residual = 0.0618, significance = 30.1 sigma, flux fraction = 0.2307
#   Null 1128: |u| = 159 lambda, residual = 0.0618, significance = 30.1 sigma, flux fraction = 0.2307
#   Null 1129: |u| = 159 lambda, residual = 0.0618, significance = 30.1 sigma, flux fraction = 0.2307
#   Null 1130: |u| = 159 lambda, residual = 0.0618, significance = 30.1 sigma, flux fraction = 0.2307
#   Null 1131: |u| = 169 lambda, residual = 0.0660, significance = 34.3 sigma, flux fraction = 0.2365
#   Null 1132: |u| = 169 lambda, residual = 0.0660, significance = 34.3 sigma, flux fraction = 0.2365
#   Null 1133: |u| = 170 lambda, residual = 0.0685, significance = 35.3 sigma, flux fraction = 0.2401
#   Null 1134: |u| = 170 lambda, residual = 0.0686, significance = 34.4 sigma, flux fraction = 0.2403
#   Null 1135: |u| = 170 lambda, residual = 0.0686, significance = 34.4 sigma, flux fraction = 0.2403
#   Null 1136: |u| = 170 lambda, residual = 0.0686, significance = 34.4 sigma, flux fraction = 0.2403
#   Null 1137: |u| = 170 lambda, residual = 0.0686, significance = 34.4 sigma, flux fraction = 0.2403
#   Null 1138: |u| = 170 lambda, residual = 0.0686, significance = 34.4 sigma, flux fraction = 0.2403
#   Null 1139: |u| = 170 lambda, residual = 0.0686, significance = 34.4 sigma, flux fraction = 0.2403
#   Null 1140: |u| = 170 lambda, residual = 0.0686, significance = 34.4 sigma, flux fraction = 0.2403
#   Null 1141: |u| = 170 lambda, residual = 0.0686, significance = 34.4 sigma, flux fraction = 0.2403
#   Null 1142: |u| = 170 lambda, residual = 0.0686, significance = 34.4 sigma, flux fraction = 0.2403
#   Null 1143: |u| = 170 lambda, residual = 0.0686, significance = 34.4 sigma, flux fraction = 0.2403
#   Null 1144: |u| = 170 lambda, residual = 0.0686, significance = 34.4 sigma, flux fraction = 0.2403
#   Null 1145: |u| = 181 lambda, residual = 0.0704, significance = 35.4 sigma, flux fraction = 0.2428
#   Null 1146: |u| = 181 lambda, residual = 0.0710, significance = 35.6 sigma, flux fraction = 0.2436
#   Null 1147: |u| = 181 lambda, residual = 0.0710, significance = 35.6 sigma, flux fraction = 0.2436
#   Null 1148: |u| = 181 lambda, residual = 0.0710, significance = 35.6 sigma, flux fraction = 0.2436
#   Null 1149: |u| = 181 lambda, residual = 0.0710, significance = 35.6 sigma, flux fraction = 0.2436
#   Null 1150: |u| = 181 lambda, residual = 0.0710, significance = 35.6 sigma, flux fraction = 0.2436
#   Null 1151: |u| = 185 lambda, residual = 0.0715, significance = 34.6 sigma, flux fraction = 0.2444
#   Null 1152: |u| = 185 lambda, residual = 0.0721, significance = 35.7 sigma, flux fraction = 0.2452
#   Null 1153: |u| = 185 lambda, residual = 0.0721, significance = 35.7 sigma, flux fraction = 0.2452
#   Null 1154: |u| = 185 lambda, residual = 0.0721, significance = 35.7 sigma, flux fraction = 0.2452
#   Null 1155: |u| = 185 lambda, residual = 0.0721, significance = 35.7 sigma, flux fraction = 0.2452
#   Null 1156: |u| = 185 lambda, residual = 0.0721, significance = 35.7 sigma, flux fraction = 0.2452
#   Null 1157: |u| = 185 lambda, residual = 0.0721, significance = 35.7 sigma, flux fraction = 0.2452
#   Null 1158: |u| = 185 lambda, residual = 0.0721, significance = 35.7 sigma, flux fraction = 0.2452
#   Null 1159: |u| = 185 lambda, residual = 0.0721, significance = 35.7 sigma, flux fraction = 0.2452
#   Null 1160: |u| = 185 lambda, residual = 0.0721, significance = 35.7 sigma, flux fraction = 0.2452
#   Null 1161: |u| = 185 lambda, residual = 0.0721, significance = 35.7 sigma, flux fraction = 0.2452
#   Null 1162: |u| = 185 lambda, residual = 0.0721, significance = 35.7 sigma, flux fraction = 0.2452
#   Null 1163: |u| = 185 lambda, residual = 0.0721, significance = 35.7 sigma, flux fraction = 0.2452
#   Null 1164: |u| = 185 lambda, residual = 0.0721, significance = 35.7 sigma, flux fraction = 0.2452
#   Null 1165: |u| = 185 lambda, residual = 0.0721, significance = 35.7 sigma, flux fraction = 0.2452
#   Null 1166: |u| = 185 lambda, residual = 0.0721, significance = 35.7 sigma, flux fraction = 0.2452
#   Null 1167: |u| = 185 lambda, residual = 0.0721, significance = 35.7 sigma, flux fraction = 0.2452
#   Null 1168: |u| = 185 lambda, residual = 0.0721, significance = 35.7 sigma, flux fraction = 0.2452
#   Null 1169: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1170: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1171: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1172: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1173: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1174: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1175: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1176: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1177: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1178: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1179: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1180: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1181: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1182: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1183: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1184: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1185: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1186: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1187: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1188: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1189: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1190: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1191: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1192: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1193: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1194: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1195: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1196: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1197: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1198: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#   Null 1199: |u| = 196 lambda, residual = 0.0782, significance = 37.8 sigma, flux fraction = 0.2538
#
# --- Sunspot flux fractions at theoretical null locations ---
#   Null 1: |u|_theory = 515 lambda, amplitude = 0.2137, flux fraction = 0.3015
#   Null 2: |u|_theory = 515 lambda, amplitude = 0.2137, flux fraction = 0.3015
#   Null 3: |u|_theory = 515 lambda, amplitude = 0.2137, flux fraction = 0.3015

# %%
# --- Sunspot residual plot ---
detection_u = np.array([d.u_lambda_at_null for d in detections]) if detections else None

fig, ax = plot_sunspot_residuals(
    np.abs(u_obs), residuals,
    noise_std=noise_est,
    detections_u=detection_u,
)
plt.show()

# %% [markdown]
# # Part VIII: Discussion and Extensions
#
# ## 8.1 Systematic Error Budget
#
# Several systematic effects can bias the baseline and diameter measurements:
#
# ### Bandwidth smearing (chromatic aberration)
# The interferometer has a 250 MHz instantaneous bandwidth (10.29–10.54 GHz). For a source observed at delay $\tau$, the fringe visibility is attenuated by the **bandwidth decorrelation** factor:
#
# $$\eta_{\rm BW} = \mathrm{sinc}\!\left(\frac{\Delta\nu}{\nu}\,\nu\tau\right) = \mathrm{sinc}\!\left(\frac{\Delta\nu\,\tau}{1}\right).$$
#
# For our 70 MHz analysis band and a typical delay of $\sim 60$ ns (at $h \sim 60°$), the decorrelation is $\eta_{\rm BW} \approx \mathrm{sinc}(0.004) \approx 1.000$ — negligible because we analyse per-channel visibilities, not the broadband sum.
#
# ### Atmospheric refraction
# At low elevations ($<10°$), atmospheric refraction bends the apparent source position by up to $\sim 0.5°$, shifting the effective hour angle and biasing the geometric delay. Our elevation limit of $6.5°$ minimises this, but a correction could be applied using a standard atmosphere model.
#
# ### Pointing errors
# The antenna pointing offsets ($\Delta_{\rm alt} = -0.4°$, $\Delta_{\rm az} = +4.5°$ for the west antenna) introduce a differential gain variation across the beam. This affects the fringe *amplitude* but not the *phase*, so it biases the diameter measurement more than the baseline.
#
# ### NS baseline degeneracy
# With $b_{\mathrm{ns}} \approx 0$, the cosine term in the delay equation is nearly degenerate with the cable delay. The NS baseline can only be poorly constrained from these data; a source at high declination or a dedicated NS baseline observation would be needed.
#
# ## 8.2 Radio vs. optical solar diameter
#
# The radio diameter at 10.5 GHz probes the **chromosphere** ($T \sim 10^4\;\mathrm{K}$), which extends above the photospheric limb by $\sim 10''$–$20''$ ($\sim 0.3'$–$0.6'$). We therefore expect the **radio diameter to be slightly larger than the optical diameter** ($\sim 32.0'$ vs $\sim 31.6'$). This chromospheric excess is a direct measure of the temperature structure above the photosphere and varies with solar cycle.
#
# ## 8.3 Limb darkening vs. limb brightening
#
# At optical wavelengths, the Sun shows **limb darkening** (centre-to-limb decrease in brightness) because line-of-sight paths at the limb probe higher, cooler atmospheric layers. At radio wavelengths around 10 GHz, the opposite can occur — **limb brightening** — because the chromospheric temperature *increases* with height (temperature inversion), and limb paths traverse more hot chromospheric material.
#
# Limb brightening would modify the visibility function from the uniform-disk Bessel pattern. A limb-brightened disk has:
# - Deeper Bessel nulls (less filled-in by the bright limb)
# - Slightly shifted null positions
# - A different sidelobe pattern
#
# A more sophisticated analysis would fit a **limb-brightened disk model** (e.g., $I(r) \propto 1 + a\,(r/R)^2$) to the envelope, with the brightening coefficient $a$ as a free parameter.
#
# ## 8.4 Temporal variability
#
# The Sun's radio emission varies on timescales from seconds (flares, type III bursts) to months (solar cycle). Multi-day observations would allow:
# - Tracking the **rotation** of sunspots across the disk (period $\sim 27$ days)
# - Measuring changes in the **radio diameter** with solar activity
# - Detecting **transient events** (flares produce dramatic changes in visibility amplitude)
#
# ## 8.5 What longer baselines would resolve
#
# Our $\sim 20$ m baseline gives a resolution of $\lambda / b \approx 2.9\;\mathrm{cm} / 20\;\mathrm{m} \approx 5'$ — sufficient to resolve the solar disk but not individual active regions ($\sim 1'$–$2'$). With baselines of $\sim 200$ m (achievable with VLBI or a larger array), individual sunspots could be imaged, and the brightness temperature distribution across the disk could be mapped.
#
# ---

# %% [markdown]
# # Part IX: Summary of Results

# %%
# --- Final summary ---
print("=" * 60)
print("INTERFEROMETRIC SOLAR OBSERVATION — RESULTS SUMMARY")
print("=" * 60)

print(f"\nObserving frequency:     {band_center_hz/1e9:.4f} GHz")
print(f"Wavelength:              {C_LIGHT_MS / band_center_hz * 100:.2f} cm")
print(f"Sun declination:         {np.rad2deg(dec_rad_mean):.3f} deg")
print(f"Hour angle coverage:     {ha_deg_arr.min():.1f} to {ha_deg_arr.max():.1f} deg")
print(f"Total captures:          {len(unix_mid)}")
print(f"Observation chips:       {N_chips}")

print(f"\n--- Baseline ---")
print(f"Combined B_EW:           {B_EW:.4f} +/- {combined.b_ew_err_m:.4f} m")
print(f"Combined B_NS:           {B_NS:.4f} +/- {combined.b_ns_err_m:.4f} m")
print(f"Nominal B_EW:            {NOMINAL_B_EW_M:.1f} m")

print(f"\n--- Solar Diameter ---")
if np.isfinite(diameter_fit.diameter_arcmin):
    print(f"Bessel fit:              {diameter_fit.diameter_arcmin:.2f} +/- "
          f"{diameter_fit.diameter_err_arcmin:.2f} arcmin")
if diameter_zeros is not None and np.isfinite(diameter_zeros.diameter_arcmin):
    print(f"Zero crossings:          {diameter_zeros.diameter_arcmin:.2f} +/- "
          f"{diameter_zeros.diameter_err_arcmin:.2f} arcmin")
print(f"Nominal (optical):       {SOLAR_DIAMETER_ARCMIN_NOMINAL:.1f} arcmin")

print(f"\n--- Sunspot Detections ---")
if detections:
    for d in detections:
        print(f"  Null {d.null_index}: flux fraction = {d.estimated_flux_fraction:.4f} "
              f"({d.significance_sigma:.1f} sigma)")
else:
    print("  None detected at >3 sigma")
print("=" * 60)
# Out:
# ============================================================
# INTERFEROMETRIC SOLAR OBSERVATION — RESULTS SUMMARY
# ============================================================
#
# Observing frequency:     10.4499 GHz
# Wavelength:              2.87 cm
# Sun declination:         -0.083 deg
# Hour angle coverage:     -79.9 to 22.0 deg
# Total captures:          8226
# Observation chips:       3
#
# --- Baseline ---
# Combined B_EW:           15.0190 +/- 0.0014 m
# Combined B_NS:           1.0945 +/- 0.0620 m
# Nominal B_EW:            20.0 m
#
# --- Solar Diameter ---
# Bessel fit:              0.00 +/- 197.40 arcmin
# Zero crossings:          23402.07 +/- 122.92 arcmin
# Nominal (optical):       31.6 arcmin
#
# --- Sunspot Detections ---
#   Null 1: flux fraction = 1.0000 (105.5 sigma)
#   Null 2: flux fraction = 1.0000 (105.5 sigma)
#   Null 3: flux fraction = 1.0000 (105.5 sigma)
#   Null 4: flux fraction = 1.0000 (105.5 sigma)
#   Null 5: flux fraction = 1.0000 (105.5 sigma)
#   Null 6: flux fraction = 1.0000 (105.5 sigma)
#   Null 7: flux fraction = 1.0000 (105.5 sigma)
#   Null 8: flux fraction = 1.0000 (105.5 sigma)
#   Null 9: flux fraction = 1.0000 (105.5 sigma)
#   Null 10: flux fraction = 1.0000 (105.5 sigma)
#   Null 11: flux fraction = 1.0000 (105.5 sigma)
#   Null 12: flux fraction = 1.0000 (105.5 sigma)
#   Null 13: flux fraction = 1.0000 (105.5 sigma)
#   Null 14: flux fraction = 1.0000 (105.5 sigma)
#   Null 15: flux fraction = 1.0000 (105.5 sigma)
#   Null 16: flux fraction = 1.0000 (105.5 sigma)
#   Null 17: flux fraction = 1.0000 (105.5 sigma)
#   Null 18: flux fraction = 1.0000 (105.5 sigma)
#   Null 19: flux fraction = 1.0000 (105.5 sigma)
#   Null 20: flux fraction = 1.0000 (105.5 sigma)
#   Null 21: flux fraction = 1.0000 (105.5 sigma)
#   Null 22: flux fraction = 1.0000 (105.5 sigma)
#   Null 23: flux fraction = 1.0000 (105.5 sigma)
#   Null 24: flux fraction = 1.0000 (105.5 sigma)
#   Null 25: flux fraction = 1.0000 (105.5 sigma)
#   Null 26: flux fraction = 1.0000 (105.5 sigma)
#   Null 27: flux fraction = 1.0000 (105.5 sigma)
#   Null 28: flux fraction = 1.0000 (105.5 sigma)
#   Null 29: flux fraction = 1.0000 (105.5 sigma)
#   Null 30: flux fraction = 1.0000 (105.5 sigma)
#   Null 31: flux fraction = 1.0000 (105.5 sigma)
#   Null 32: flux fraction = 1.0000 (105.5 sigma)
#   Null 33: flux fraction = 1.0000 (105.5 sigma)
#   Null 34: flux fraction = 1.0000 (105.5 sigma)
#   Null 35: flux fraction = 1.0000 (105.5 sigma)
#   Null 36: flux fraction = 1.0000 (105.5 sigma)
#   Null 37: flux fraction = 1.0000 (105.5 sigma)
#   Null 38: flux fraction = 1.0000 (105.5 sigma)
#   Null 39: flux fraction = 1.0000 (105.5 sigma)
#   Null 40: flux fraction = 1.0000 (105.5 sigma)
#   Null 41: flux fraction = 1.0000 (105.5 sigma)
#   Null 42: flux fraction = 1.0000 (105.5 sigma)
#   Null 43: flux fraction = 1.0000 (105.5 sigma)
#   Null 44: flux fraction = 1.0000 (105.5 sigma)
#   Null 45: flux fraction = 1.0000 (105.5 sigma)
#   Null 46: flux fraction = 1.0000 (105.5 sigma)
#   Null 47: flux fraction = 1.0000 (105.5 sigma)
#   Null 48: flux fraction = 1.0000 (105.5 sigma)
#   Null 49: flux fraction = 1.0000 (105.5 sigma)
#   Null 50: flux fraction = 1.0000 (105.5 sigma)
#   Null 51: flux fraction = 1.0000 (105.5 sigma)
#   Null 52: flux fraction = 1.0000 (105.5 sigma)
#   Null 53: flux fraction = 1.0000 (105.5 sigma)
#   Null 54: flux fraction = 1.0000 (105.5 sigma)
#   Null 55: flux fraction = 1.0000 (105.5 sigma)
#   Null 56: flux fraction = 1.0000 (105.5 sigma)
#   Null 57: flux fraction = 1.0000 (105.5 sigma)
#   Null 58: flux fraction = 1.0000 (105.5 sigma)
#   Null 59: flux fraction = 1.0000 (105.5 sigma)
#   Null 60: flux fraction = 1.0000 (105.5 sigma)
#   Null 61: flux fraction = 1.0000 (105.5 sigma)
#   Null 62: flux fraction = 1.0000 (105.5 sigma)
#   Null 63: flux fraction = 1.0000 (105.5 sigma)
#   Null 64: flux fraction = 1.0000 (105.5 sigma)
#   Null 65: flux fraction = 1.0000 (105.5 sigma)
#   Null 66: flux fraction = 1.0000 (105.5 sigma)
#   Null 67: flux fraction = 1.0000 (105.5 sigma)
#   Null 68: flux fraction = 1.0000 (105.5 sigma)
#   Null 69: flux fraction = 1.0000 (105.5 sigma)
#   Null 70: flux fraction = 1.0000 (105.5 sigma)
#   Null 71: flux fraction = 1.0000 (105.5 sigma)
#   Null 72: flux fraction = 1.0000 (105.5 sigma)
#   Null 73: flux fraction = 1.0000 (105.5 sigma)
#   Null 74: flux fraction = 1.0000 (105.5 sigma)
#   Null 75: flux fraction = 1.0000 (105.5 sigma)
#   Null 76: flux fraction = 1.0000 (105.5 sigma)
#   Null 77: flux fraction = 1.0000 (105.5 sigma)
#   Null 78: flux fraction = 1.0000 (105.5 sigma)
#   Null 79: flux fraction = 1.0000 (105.5 sigma)
#   Null 80: flux fraction = 1.0000 (105.5 sigma)
#   Null 81: flux fraction = 1.0000 (105.5 sigma)
#   Null 82: flux fraction = 1.0000 (105.5 sigma)
#   Null 83: flux fraction = 1.0000 (105.5 sigma)
#   Null 84: flux fraction = 1.0000 (105.5 sigma)
#   Null 85: flux fraction = 1.0000 (105.5 sigma)
#   Null 86: flux fraction = 1.0000 (105.5 sigma)
#   Null 87: flux fraction = 1.0000 (105.5 sigma)
#   Null 88: flux fraction = 1.0000 (105.5 sigma)
#   Null 89: flux fraction = 1.0000 (105.5 sigma)
#   Null 90: flux fraction = 1.0000 (105.5 sigma)
#   Null 91: flux fraction = 1.0000 (105.5 sigma)
#   Null 92: flux fraction = 1.0000 (105.5 sigma)
#   Null 93: flux fraction = 1.0000 (105.5 sigma)
#   Null 94: flux fraction = 1.0000 (105.5 sigma)
#   Null 95: flux fraction = 1.0000 (105.5 sigma)
#   Null 96: flux fraction = 1.0000 (105.5 sigma)
#   Null 97: flux fraction = 1.0000 (105.5 sigma)
#   Null 98: flux fraction = 1.0000 (105.5 sigma)
#   Null 99: flux fraction = 1.0000 (105.5 sigma)
#   Null 100: flux fraction = 1.0000 (105.5 sigma)
#   Null 101: flux fraction = 1.0000 (105.5 sigma)
#   Null 102: flux fraction = 1.0000 (105.5 sigma)
#   Null 103: flux fraction = 1.0000 (105.5 sigma)
#   Null 104: flux fraction = 1.0000 (105.5 sigma)
#   Null 105: flux fraction = 1.0000 (105.5 sigma)
#   Null 106: flux fraction = 1.0000 (105.5 sigma)
#   Null 107: flux fraction = 1.0000 (105.5 sigma)
#   Null 108: flux fraction = 1.0000 (105.5 sigma)
#   Null 109: flux fraction = 1.0000 (105.5 sigma)
#   Null 110: flux fraction = 1.0000 (105.5 sigma)
#   Null 111: flux fraction = 1.0000 (105.5 sigma)
#   Null 112: flux fraction = 1.0000 (105.5 sigma)
#   Null 113: flux fraction = 1.0000 (105.5 sigma)
#   Null 114: flux fraction = 1.0000 (105.5 sigma)
#   Null 115: flux fraction = 1.0000 (105.5 sigma)
#   Null 116: flux fraction = 1.0000 (105.5 sigma)
#   Null 117: flux fraction = 1.0000 (105.5 sigma)
#   Null 118: flux fraction = 1.0000 (105.5 sigma)
#   Null 119: flux fraction = 1.0000 (105.5 sigma)
#   Null 120: flux fraction = 1.0000 (105.5 sigma)
#   Null 121: flux fraction = 1.0000 (105.5 sigma)
#   Null 122: flux fraction = 1.0000 (105.5 sigma)
#   Null 123: flux fraction = 1.0000 (105.5 sigma)
#   Null 124: flux fraction = 1.0000 (105.5 sigma)
#   Null 125: flux fraction = 1.0000 (105.5 sigma)
#   Null 126: flux fraction = 1.0000 (105.5 sigma)
#   Null 127: flux fraction = 1.0000 (105.5 sigma)
#   Null 128: flux fraction = 1.0000 (105.5 sigma)
#   Null 129: flux fraction = 1.0000 (105.5 sigma)
#   Null 130: flux fraction = 1.0000 (105.5 sigma)
#   Null 131: flux fraction = 1.0000 (105.5 sigma)
#   Null 132: flux fraction = 1.0000 (105.5 sigma)
#   Null 133: flux fraction = 1.0000 (105.5 sigma)
#   Null 134: flux fraction = 1.0000 (105.5 sigma)
#   Null 135: flux fraction = 1.0000 (105.5 sigma)
#   Null 136: flux fraction = 0.9641 (103.6 sigma)
#   Null 137: flux fraction = 0.9641 (103.6 sigma)
#   Null 138: flux fraction = 0.9641 (103.6 sigma)
#   Null 139: flux fraction = 0.9641 (103.6 sigma)
#   Null 140: flux fraction = 0.9641 (103.6 sigma)
#   Null 141: flux fraction = 0.9599 (110.0 sigma)
#   Null 142: flux fraction = 0.9599 (110.0 sigma)
#   Null 143: flux fraction = 0.9599 (110.0 sigma)
#   Null 144: flux fraction = 0.9347 (126.2 sigma)
#   Null 145: flux fraction = 0.9346 (111.0 sigma)
#   Null 146: flux fraction = 0.9261 (122.3 sigma)
#   Null 147: flux fraction = 0.9255 (110.4 sigma)
#   Null 148: flux fraction = 0.8807 (99.0 sigma)
#   Null 149: flux fraction = 0.8807 (99.0 sigma)
#   Null 150: flux fraction = 0.8770 (99.0 sigma)
#   Null 151: flux fraction = 0.7390 (93.1 sigma)
#   Null 152: flux fraction = 0.7255 (120.4 sigma)
#   Null 153: flux fraction = 0.7255 (120.4 sigma)
#   Null 154: flux fraction = 0.6941 (92.4 sigma)
#   Null 155: flux fraction = 0.6828 (112.6 sigma)
#   Null 156: flux fraction = 0.6473 (93.2 sigma)
#   Null 157: flux fraction = 0.6473 (93.2 sigma)
#   Null 158: flux fraction = 0.6092 (87.4 sigma)
#   Null 159: flux fraction = 0.5890 (100.7 sigma)
#   Null 160: flux fraction = 0.4744 (84.5 sigma)
#   Null 161: flux fraction = 0.3981 (64.2 sigma)
#   Null 162: flux fraction = 0.3865 (60.3 sigma)
#   Null 163: flux fraction = 0.3161 (71.0 sigma)
#   Null 164: flux fraction = 0.3093 (49.5 sigma)
#   Null 165: flux fraction = 0.3048 (48.7 sigma)
#   Null 166: flux fraction = 0.3048 (48.7 sigma)
#   Null 167: flux fraction = 0.3048 (48.7 sigma)
#   Null 168: flux fraction = 0.3048 (48.7 sigma)
#   Null 169: flux fraction = 0.3048 (48.7 sigma)
#   Null 170: flux fraction = 0.3048 (48.7 sigma)
#   Null 171: flux fraction = 0.3048 (48.7 sigma)
#   Null 172: flux fraction = 0.3048 (48.7 sigma)
#   Null 173: flux fraction = 0.3048 (48.7 sigma)
#   Null 174: flux fraction = 0.3048 (48.7 sigma)
#   Null 175: flux fraction = 0.3048 (48.7 sigma)
#   Null 176: flux fraction = 0.3048 (48.7 sigma)
#   Null 177: flux fraction = 0.3048 (48.7 sigma)
#   Null 178: flux fraction = 0.3048 (48.7 sigma)
#   Null 179: flux fraction = 0.3048 (48.7 sigma)
#   Null 180: flux fraction = 0.3048 (48.7 sigma)
#   Null 181: flux fraction = 0.3048 (48.7 sigma)
#   Null 182: flux fraction = 0.3048 (48.7 sigma)
#   Null 183: flux fraction = 0.3048 (48.7 sigma)
#   Null 184: flux fraction = 0.3048 (48.7 sigma)
#   Null 185: flux fraction = 0.3048 (48.7 sigma)
#   Null 186: flux fraction = 0.3048 (48.7 sigma)
#   Null 187: flux fraction = 0.3048 (48.7 sigma)
#   Null 188: flux fraction = 0.3048 (48.7 sigma)
#   Null 189: flux fraction = 0.3048 (48.7 sigma)
#   Null 190: flux fraction = 0.3048 (48.7 sigma)
#   Null 191: flux fraction = 0.3048 (48.7 sigma)
#   Null 192: flux fraction = 0.3048 (48.7 sigma)
#   Null 193: flux fraction = 0.3048 (48.7 sigma)
#   Null 194: flux fraction = 0.3048 (48.7 sigma)
#   Null 195: flux fraction = 0.3048 (48.7 sigma)
#   Null 196: flux fraction = 0.3048 (48.7 sigma)
#   Null 197: flux fraction = 0.3048 (48.7 sigma)
#   Null 198: flux fraction = 0.3048 (48.7 sigma)
#   Null 199: flux fraction = 0.3048 (48.7 sigma)
#   Null 200: flux fraction = 0.3048 (48.7 sigma)
#   Null 201: flux fraction = 0.3048 (48.7 sigma)
#   Null 202: flux fraction = 0.3048 (48.7 sigma)
#   Null 203: flux fraction = 0.3048 (48.7 sigma)
#   Null 204: flux fraction = 0.3048 (48.7 sigma)
#   Null 205: flux fraction = 0.3048 (48.7 sigma)
#   Null 206: flux fraction = 0.3037 (48.3 sigma)
#   Null 207: flux fraction = 0.3037 (48.3 sigma)
#   Null 208: flux fraction = 0.2973 (47.2 sigma)
#   Null 209: flux fraction = 0.2973 (47.2 sigma)
#   Null 210: flux fraction = 0.2964 (47.6 sigma)
#   Null 211: flux fraction = 0.2964 (47.6 sigma)
#   Null 212: flux fraction = 0.2964 (47.6 sigma)
#   Null 213: flux fraction = 0.2948 (47.4 sigma)
#   Null 214: flux fraction = 0.2915 (54.3 sigma)
#   Null 215: flux fraction = 0.2909 (48.4 sigma)
#   Null 216: flux fraction = 0.2909 (48.4 sigma)
#   Null 217: flux fraction = 0.2909 (48.4 sigma)
#   Null 218: flux fraction = 0.2909 (48.4 sigma)
#   Null 219: flux fraction = 0.2902 (50.3 sigma)
#   Null 220: flux fraction = 0.2804 (45.4 sigma)
#   Null 221: flux fraction = 0.2804 (45.4 sigma)
#   Null 222: flux fraction = 0.2722 (42.9 sigma)
#   Null 223: flux fraction = 0.2722 (42.9 sigma)
#   Null 224: flux fraction = 0.2722 (42.9 sigma)
#   Null 225: flux fraction = 0.2669 (43.6 sigma)
#   Null 226: flux fraction = 0.2669 (43.6 sigma)
#   Null 227: flux fraction = 0.2669 (43.6 sigma)
#   Null 228: flux fraction = 0.2669 (43.6 sigma)
#   Null 229: flux fraction = 0.2669 (43.6 sigma)
#   Null 230: flux fraction = 0.2591 (41.0 sigma)
#   Null 231: flux fraction = 0.0296 (117.3 sigma)
#   Null 232: flux fraction = 0.0296 (117.3 sigma)
#   Null 233: flux fraction = 0.0296 (117.3 sigma)
#   Null 234: flux fraction = 0.0296 (117.3 sigma)
#   Null 235: flux fraction = 0.0296 (117.3 sigma)
#   Null 236: flux fraction = 0.0296 (117.3 sigma)
#   Null 237: flux fraction = 0.0296 (117.3 sigma)
#   Null 238: flux fraction = 0.0296 (117.3 sigma)
#   Null 239: flux fraction = 0.0296 (117.3 sigma)
#   Null 240: flux fraction = 0.0296 (117.3 sigma)
#   Null 241: flux fraction = 0.0296 (117.3 sigma)
#   Null 242: flux fraction = 0.0296 (117.3 sigma)
#   Null 243: flux fraction = 0.0296 (117.3 sigma)
#   Null 244: flux fraction = 0.0296 (117.3 sigma)
#   Null 245: flux fraction = 0.0296 (117.3 sigma)
#   Null 246: flux fraction = 0.0296 (117.3 sigma)
#   Null 247: flux fraction = 0.0296 (117.3 sigma)
#   Null 248: flux fraction = 0.0296 (117.3 sigma)
#   Null 249: flux fraction = 0.0296 (117.3 sigma)
#   Null 250: flux fraction = 0.0296 (117.3 sigma)
#   Null 251: flux fraction = 0.0296 (117.3 sigma)
#   Null 252: flux fraction = 0.0296 (117.3 sigma)
#   Null 253: flux fraction = 0.0296 (117.3 sigma)
#   Null 254: flux fraction = 0.0296 (117.3 sigma)
#   Null 255: flux fraction = 0.0296 (117.3 sigma)
#   Null 256: flux fraction = 0.0296 (117.3 sigma)
#   Null 257: flux fraction = 0.0296 (117.3 sigma)
#   Null 258: flux fraction = 0.0296 (117.3 sigma)
#   Null 259: flux fraction = 0.0296 (117.3 sigma)
#   Null 260: flux fraction = 0.0296 (117.3 sigma)
#   Null 261: flux fraction = 0.0296 (117.3 sigma)
#   Null 262: flux fraction = 0.0296 (117.3 sigma)
#   Null 263: flux fraction = 0.0296 (117.3 sigma)
#   Null 264: flux fraction = 0.0296 (117.3 sigma)
#   Null 265: flux fraction = 0.0296 (117.3 sigma)
#   Null 266: flux fraction = 0.0296 (117.3 sigma)
#   Null 267: flux fraction = 0.0296 (117.3 sigma)
#   Null 268: flux fraction = 0.0296 (117.3 sigma)
#   Null 269: flux fraction = 0.0296 (117.3 sigma)
#   Null 270: flux fraction = 0.0296 (117.3 sigma)
#   Null 271: flux fraction = 0.0296 (117.3 sigma)
#   Null 272: flux fraction = 0.0296 (117.3 sigma)
#   Null 273: flux fraction = 0.0306 (109.3 sigma)
#   Null 274: flux fraction = 0.0324 (106.3 sigma)
#   Null 275: flux fraction = 0.0324 (106.3 sigma)
#   Null 276: flux fraction = 0.0338 (101.3 sigma)
#   Null 277: flux fraction = 0.0377 (92.7 sigma)
#   Null 278: flux fraction = 0.0377 (92.7 sigma)
#   Null 279: flux fraction = 0.0462 (74.4 sigma)
#   Null 280: flux fraction = 0.0462 (74.4 sigma)
#   Null 281: flux fraction = 0.0468 (72.7 sigma)
#   Null 282: flux fraction = 0.0468 (72.7 sigma)
#   Null 283: flux fraction = 0.0575 (62.7 sigma)
#   Null 284: flux fraction = 0.0575 (62.7 sigma)
#   Null 285: flux fraction = 0.2262 (30.6 sigma)
#   Null 286: flux fraction = 0.2262 (30.6 sigma)
#   Null 287: flux fraction = 0.2262 (30.6 sigma)
#   Null 288: flux fraction = 0.2262 (30.6 sigma)
#   Null 289: flux fraction = 0.2262 (30.6 sigma)
#   Null 290: flux fraction = 0.2262 (30.6 sigma)
#   Null 291: flux fraction = 0.2262 (30.6 sigma)
#   Null 292: flux fraction = 0.2262 (30.6 sigma)
#   Null 293: flux fraction = 0.2262 (30.6 sigma)
#   Null 294: flux fraction = 0.2262 (30.6 sigma)
#   Null 295: flux fraction = 0.2262 (30.6 sigma)
#   Null 296: flux fraction = 0.2262 (30.6 sigma)
#   Null 297: flux fraction = 0.2262 (30.6 sigma)
#   Null 298: flux fraction = 0.2262 (30.6 sigma)
#   Null 299: flux fraction = 0.2262 (30.6 sigma)
#   Null 300: flux fraction = 0.2262 (30.6 sigma)
#   Null 301: flux fraction = 0.2262 (30.6 sigma)
#   Null 302: flux fraction = 0.2262 (30.6 sigma)
#   Null 303: flux fraction = 0.2262 (30.6 sigma)
#   Null 304: flux fraction = 0.2262 (30.6 sigma)
#   Null 305: flux fraction = 0.2262 (30.6 sigma)
#   Null 306: flux fraction = 0.2262 (30.6 sigma)
#   Null 307: flux fraction = 0.2262 (30.6 sigma)
#   Null 308: flux fraction = 0.2262 (30.6 sigma)
#   Null 309: flux fraction = 0.2262 (30.6 sigma)
#   Null 310: flux fraction = 0.2262 (30.6 sigma)
#   Null 311: flux fraction = 0.2262 (30.6 sigma)
#   Null 312: flux fraction = 0.2262 (30.6 sigma)
#   Null 313: flux fraction = 0.2262 (30.6 sigma)
#   Null 314: flux fraction = 0.2262 (30.6 sigma)
#   Null 315: flux fraction = 0.2262 (30.6 sigma)
#   Null 316: flux fraction = 0.2262 (30.6 sigma)
#   Null 317: flux fraction = 0.2262 (30.6 sigma)
#   Null 318: flux fraction = 0.2262 (30.6 sigma)
#   Null 319: flux fraction = 0.2262 (30.6 sigma)
#   Null 320: flux fraction = 0.2262 (30.6 sigma)
#   Null 321: flux fraction = 0.2262 (30.6 sigma)
#   Null 322: flux fraction = 0.2262 (30.6 sigma)
#   Null 323: flux fraction = 0.2262 (30.6 sigma)
#   Null 324: flux fraction = 0.2262 (30.6 sigma)
#   Null 325: flux fraction = 0.2262 (30.6 sigma)
#   Null 326: flux fraction = 0.2262 (30.6 sigma)
#   Null 327: flux fraction = 0.2262 (30.6 sigma)
#   Null 328: flux fraction = 0.2262 (30.6 sigma)
#   Null 329: flux fraction = 0.2262 (30.6 sigma)
#   Null 330: flux fraction = 0.2262 (30.6 sigma)
#   Null 331: flux fraction = 0.2262 (30.6 sigma)
#   Null 332: flux fraction = 0.2262 (30.6 sigma)
#   Null 333: flux fraction = 0.2262 (30.6 sigma)
#   Null 334: flux fraction = 0.2262 (30.6 sigma)
#   Null 335: flux fraction = 0.2262 (30.6 sigma)
#   Null 336: flux fraction = 0.2262 (30.6 sigma)
#   Null 337: flux fraction = 0.2262 (30.6 sigma)
#   Null 338: flux fraction = 0.2262 (30.6 sigma)
#   Null 339: flux fraction = 0.2262 (30.6 sigma)
#   Null 340: flux fraction = 0.2262 (30.6 sigma)
#   Null 341: flux fraction = 0.2262 (30.6 sigma)
#   Null 342: flux fraction = 0.2262 (30.6 sigma)
#   Null 343: flux fraction = 0.2262 (30.6 sigma)
#   Null 344: flux fraction = 0.2262 (30.6 sigma)
#   Null 345: flux fraction = 0.2262 (30.6 sigma)
#   Null 346: flux fraction = 0.2262 (30.6 sigma)
#   Null 347: flux fraction = 0.2262 (30.6 sigma)
#   Null 348: flux fraction = 0.2262 (30.6 sigma)
#   Null 349: flux fraction = 0.2262 (30.6 sigma)
#   Null 350: flux fraction = 0.2262 (30.6 sigma)
#   Null 351: flux fraction = 0.2262 (30.6 sigma)
#   Null 352: flux fraction = 0.2262 (30.6 sigma)
#   Null 353: flux fraction = 0.2262 (30.6 sigma)
#   Null 354: flux fraction = 0.2262 (30.6 sigma)
#   Null 355: flux fraction = 0.2262 (30.6 sigma)
#   Null 356: flux fraction = 0.2262 (30.6 sigma)
#   Null 357: flux fraction = 0.2246 (32.2 sigma)
#   Null 358: flux fraction = 0.2246 (32.2 sigma)
#   Null 359: flux fraction = 0.2246 (32.2 sigma)
#   Null 360: flux fraction = 0.2246 (32.2 sigma)
#   Null 361: flux fraction = 0.2241 (31.3 sigma)
#   Null 362: flux fraction = 0.2237 (29.8 sigma)
#   Null 363: flux fraction = 0.2212 (30.5 sigma)
#   Null 364: flux fraction = 0.2189 (29.8 sigma)
#   Null 365: flux fraction = 0.2189 (29.8 sigma)
#   Null 366: flux fraction = 0.2189 (29.8 sigma)
#   Null 367: flux fraction = 0.1929 (19.5 sigma)
#   Null 368: flux fraction = 0.1917 (21.2 sigma)
#   Null 369: flux fraction = 0.1901 (19.4 sigma)
#   Null 370: flux fraction = 0.1901 (19.4 sigma)
#   Null 371: flux fraction = 0.1901 (19.4 sigma)
#   Null 372: flux fraction = 0.1901 (19.4 sigma)
#   Null 373: flux fraction = 0.1901 (19.4 sigma)
#   Null 374: flux fraction = 0.1901 (19.4 sigma)
#   Null 375: flux fraction = 0.1901 (19.4 sigma)
#   Null 376: flux fraction = 0.1901 (18.7 sigma)
#   Null 377: flux fraction = 0.1863 (18.0 sigma)
#   Null 378: flux fraction = 0.1874 (17.0 sigma)
#   Null 379: flux fraction = 0.1874 (17.0 sigma)
#   Null 380: flux fraction = 0.1874 (17.0 sigma)
#   Null 381: flux fraction = 0.1874 (17.0 sigma)
#   Null 382: flux fraction = 0.1874 (17.0 sigma)
#   Null 383: flux fraction = 0.1902 (18.6 sigma)
#   Null 384: flux fraction = 0.1905 (18.6 sigma)
#   Null 385: flux fraction = 0.1905 (18.6 sigma)
#   Null 386: flux fraction = 0.1907 (20.4 sigma)
#   Null 387: flux fraction = 0.1930 (20.0 sigma)
#   Null 388: flux fraction = 0.1952 (20.4 sigma)
#   Null 389: flux fraction = 0.1967 (21.2 sigma)
#   Null 390: flux fraction = 0.1980 (22.3 sigma)
#   Null 391: flux fraction = 0.2008 (22.5 sigma)
#   Null 392: flux fraction = 0.2008 (22.5 sigma)
#   Null 393: flux fraction = 0.2008 (22.5 sigma)
#   Null 394: flux fraction = 0.2008 (22.5 sigma)
#   Null 395: flux fraction = 0.2027 (23.7 sigma)
#   Null 396: flux fraction = 0.2027 (23.7 sigma)
#   Null 397: flux fraction = 0.2047 (22.6 sigma)
#   Null 398: flux fraction = 0.2051 (22.7 sigma)
#   Null 399: flux fraction = 0.2051 (22.7 sigma)
#   Null 400: flux fraction = 0.2051 (22.7 sigma)
#   Null 401: flux fraction = 0.2051 (22.7 sigma)
#   Null 402: flux fraction = 0.2051 (22.7 sigma)
#   Null 403: flux fraction = 0.2052 (23.6 sigma)
#   Null 404: flux fraction = 0.2071 (25.3 sigma)
#   Null 405: flux fraction = 0.2071 (25.3 sigma)
#   Null 406: flux fraction = 0.2071 (25.3 sigma)
#   Null 407: flux fraction = 0.2071 (25.3 sigma)
#   Null 408: flux fraction = 0.2098 (27.0 sigma)
#   Null 409: flux fraction = 0.2098 (27.0 sigma)
#   Null 410: flux fraction = 0.2104 (24.5 sigma)
#   Null 411: flux fraction = 0.2104 (24.5 sigma)
#   Null 412: flux fraction = 0.2134 (28.5 sigma)
#   Null 413: flux fraction = 0.2185 (27.0 sigma)
#   Null 414: flux fraction = 0.2209 (26.8 sigma)
#   Null 415: flux fraction = 0.2209 (26.8 sigma)
#   Null 416: flux fraction = 0.2209 (26.8 sigma)
#   Null 417: flux fraction = 0.2209 (26.8 sigma)
#   Null 418: flux fraction = 0.2209 (26.8 sigma)
#   Null 419: flux fraction = 0.2209 (26.8 sigma)
#   Null 420: flux fraction = 0.2209 (26.8 sigma)
#   Null 421: flux fraction = 0.2209 (26.8 sigma)
#   Null 422: flux fraction = 0.2209 (26.8 sigma)
#   Null 423: flux fraction = 0.2209 (26.8 sigma)
#   Null 424: flux fraction = 0.2209 (26.8 sigma)
#   Null 425: flux fraction = 0.2209 (26.8 sigma)
#   Null 426: flux fraction = 0.2209 (26.8 sigma)
#   Null 427: flux fraction = 0.2209 (26.8 sigma)
#   Null 428: flux fraction = 0.2209 (26.8 sigma)
#   Null 429: flux fraction = 0.2249 (30.1 sigma)
#   Null 430: flux fraction = 0.2249 (30.1 sigma)
#   Null 431: flux fraction = 0.2249 (30.1 sigma)
#   Null 432: flux fraction = 0.2249 (30.1 sigma)
#   Null 433: flux fraction = 0.2258 (32.4 sigma)
#   Null 434: flux fraction = 0.2258 (32.4 sigma)
#   Null 435: flux fraction = 0.2312 (31.9 sigma)
#   Null 436: flux fraction = 0.2312 (31.9 sigma)
#   Null 437: flux fraction = 0.2312 (31.9 sigma)
#   Null 438: flux fraction = 0.2312 (31.9 sigma)
#   Null 439: flux fraction = 0.2312 (31.9 sigma)
#   Null 440: flux fraction = 0.2312 (31.9 sigma)
#   Null 441: flux fraction = 0.2323 (31.9 sigma)
#   Null 442: flux fraction = 0.2323 (31.9 sigma)
#   Null 443: flux fraction = 0.2323 (31.9 sigma)
#   Null 444: flux fraction = 0.2323 (31.9 sigma)
#   Null 445: flux fraction = 0.2323 (31.9 sigma)
#   Null 446: flux fraction = 0.2323 (31.9 sigma)
#   Null 447: flux fraction = 0.2323 (31.9 sigma)
#   Null 448: flux fraction = 0.2323 (31.9 sigma)
#   Null 449: flux fraction = 0.2323 (31.9 sigma)
#   Null 450: flux fraction = 0.2323 (31.9 sigma)
#   Null 451: flux fraction = 0.2323 (31.9 sigma)
#   Null 452: flux fraction = 0.2323 (31.9 sigma)
#   Null 453: flux fraction = 0.2323 (31.9 sigma)
#   Null 454: flux fraction = 0.2323 (31.9 sigma)
#   Null 455: flux fraction = 0.2323 (31.9 sigma)
#   Null 456: flux fraction = 0.2323 (31.9 sigma)
#   Null 457: flux fraction = 0.2323 (31.9 sigma)
#   Null 458: flux fraction = 0.2323 (31.9 sigma)
#   Null 459: flux fraction = 0.2323 (31.9 sigma)
#   Null 460: flux fraction = 0.2323 (31.9 sigma)
#   Null 461: flux fraction = 0.2323 (31.9 sigma)
#   Null 462: flux fraction = 0.2323 (31.9 sigma)
#   Null 463: flux fraction = 0.2323 (31.9 sigma)
#   Null 464: flux fraction = 0.2323 (31.9 sigma)
#   Null 465: flux fraction = 0.2342 (33.5 sigma)
#   Null 466: flux fraction = 0.2342 (33.5 sigma)
#   Null 467: flux fraction = 0.2342 (33.5 sigma)
#   Null 468: flux fraction = 0.2396 (34.0 sigma)
#   Null 469: flux fraction = 0.2396 (34.0 sigma)
#   Null 470: flux fraction = 0.2396 (34.0 sigma)
#   Null 471: flux fraction = 0.2396 (34.0 sigma)
#   Null 472: flux fraction = 0.2396 (34.0 sigma)
#   Null 473: flux fraction = 0.2396 (34.0 sigma)
#   Null 474: flux fraction = 0.2396 (34.0 sigma)
#   Null 475: flux fraction = 0.2396 (34.0 sigma)
#   Null 476: flux fraction = 0.2396 (34.0 sigma)
#   Null 477: flux fraction = 0.2396 (34.0 sigma)
#   Null 478: flux fraction = 0.2396 (34.0 sigma)
#   Null 479: flux fraction = 0.2396 (34.0 sigma)
#   Null 480: flux fraction = 0.2396 (34.0 sigma)
#   Null 481: flux fraction = 0.2396 (34.0 sigma)
#   Null 482: flux fraction = 0.2396 (34.0 sigma)
#   Null 483: flux fraction = 0.2396 (34.0 sigma)
#   Null 484: flux fraction = 0.2396 (34.0 sigma)
#   Null 485: flux fraction = 0.2396 (34.0 sigma)
#   Null 486: flux fraction = 0.2396 (34.0 sigma)
#   Null 487: flux fraction = 0.2396 (34.0 sigma)
#   Null 488: flux fraction = 0.2396 (34.0 sigma)
#   Null 489: flux fraction = 0.2396 (34.0 sigma)
#   Null 490: flux fraction = 0.2396 (34.0 sigma)
#   Null 491: flux fraction = 0.2396 (34.0 sigma)
#   Null 492: flux fraction = 0.2396 (34.0 sigma)
#   Null 493: flux fraction = 0.2396 (34.0 sigma)
#   Null 494: flux fraction = 0.2396 (34.0 sigma)
#   Null 495: flux fraction = 0.2396 (34.0 sigma)
#   Null 496: flux fraction = 0.2396 (34.0 sigma)
#   Null 497: flux fraction = 0.2396 (34.0 sigma)
#   Null 498: flux fraction = 0.2396 (34.0 sigma)
#   Null 499: flux fraction = 0.2396 (34.0 sigma)
#   Null 500: flux fraction = 0.2396 (34.0 sigma)
#   Null 501: flux fraction = 0.2396 (34.0 sigma)
#   Null 502: flux fraction = 0.2396 (34.0 sigma)
#   Null 503: flux fraction = 0.2396 (34.0 sigma)
#   Null 504: flux fraction = 0.2396 (34.0 sigma)
#   Null 505: flux fraction = 0.2396 (34.0 sigma)
#   Null 506: flux fraction = 0.2396 (34.0 sigma)
#   Null 507: flux fraction = 0.2396 (34.0 sigma)
#   Null 508: flux fraction = 0.2396 (34.0 sigma)
#   Null 509: flux fraction = 0.2396 (34.0 sigma)
#   Null 510: flux fraction = 0.2396 (34.0 sigma)
#   Null 511: flux fraction = 0.2396 (34.0 sigma)
#   Null 512: flux fraction = 0.2396 (34.0 sigma)
#   Null 513: flux fraction = 0.2396 (34.0 sigma)
#   Null 514: flux fraction = 0.2396 (34.0 sigma)
#   Null 515: flux fraction = 0.2396 (34.0 sigma)
#   Null 516: flux fraction = 0.2396 (34.0 sigma)
#   Null 517: flux fraction = 0.2396 (34.0 sigma)
#   Null 518: flux fraction = 0.2396 (34.0 sigma)
#   Null 519: flux fraction = 0.2396 (34.0 sigma)
#   Null 520: flux fraction = 0.2396 (34.0 sigma)
#   Null 521: flux fraction = 0.2396 (34.0 sigma)
#   Null 522: flux fraction = 0.2396 (34.0 sigma)
#   Null 523: flux fraction = 0.2396 (34.0 sigma)
#   Null 524: flux fraction = 0.2396 (34.0 sigma)
#   Null 525: flux fraction = 0.2396 (34.0 sigma)
#   Null 526: flux fraction = 0.2396 (34.0 sigma)
#   Null 527: flux fraction = 0.2396 (34.0 sigma)
#   Null 528: flux fraction = 0.2396 (34.0 sigma)
#   Null 529: flux fraction = 0.2396 (34.0 sigma)
#   Null 530: flux fraction = 0.2396 (34.0 sigma)
#   Null 531: flux fraction = 0.2396 (34.0 sigma)
#   Null 532: flux fraction = 0.2396 (34.0 sigma)
#   Null 533: flux fraction = 0.2396 (34.0 sigma)
#   Null 534: flux fraction = 0.2396 (34.0 sigma)
#   Null 535: flux fraction = 0.2396 (34.0 sigma)
#   Null 536: flux fraction = 0.2396 (34.0 sigma)
#   Null 537: flux fraction = 0.2396 (34.0 sigma)
#   Null 538: flux fraction = 0.2396 (34.0 sigma)
#   Null 539: flux fraction = 0.2396 (34.0 sigma)
#   Null 540: flux fraction = 0.2396 (34.0 sigma)
#   Null 541: flux fraction = 0.2396 (34.0 sigma)
#   Null 542: flux fraction = 0.2396 (34.0 sigma)
#   Null 543: flux fraction = 0.2396 (34.0 sigma)
#   Null 544: flux fraction = 0.2396 (34.0 sigma)
#   Null 545: flux fraction = 0.2396 (34.0 sigma)
#   Null 546: flux fraction = 0.2396 (34.0 sigma)
#   Null 547: flux fraction = 0.2396 (34.0 sigma)
#   Null 548: flux fraction = 0.2396 (34.0 sigma)
#   Null 549: flux fraction = 0.2396 (34.0 sigma)
#   Null 550: flux fraction = 0.2396 (34.0 sigma)
#   Null 551: flux fraction = 0.2396 (34.0 sigma)
#   Null 552: flux fraction = 0.2396 (34.0 sigma)
#   Null 553: flux fraction = 0.2396 (34.0 sigma)
#   Null 554: flux fraction = 0.2396 (34.0 sigma)
#   Null 555: flux fraction = 0.2396 (34.0 sigma)
#   Null 556: flux fraction = 0.2396 (34.0 sigma)
#   Null 557: flux fraction = 0.2396 (34.0 sigma)
#   Null 558: flux fraction = 0.2365 (33.1 sigma)
#   Null 559: flux fraction = 0.2365 (33.1 sigma)
#   Null 560: flux fraction = 0.2365 (33.1 sigma)
#   Null 561: flux fraction = 0.2365 (33.1 sigma)
#   Null 562: flux fraction = 0.2365 (33.1 sigma)
#   Null 563: flux fraction = 0.2365 (33.1 sigma)
#   Null 564: flux fraction = 0.2365 (33.1 sigma)
#   Null 565: flux fraction = 0.2365 (33.1 sigma)
#   Null 566: flux fraction = 0.2365 (33.1 sigma)
#   Null 567: flux fraction = 0.2365 (33.1 sigma)
#   Null 568: flux fraction = 0.2365 (33.1 sigma)
#   Null 569: flux fraction = 0.2365 (33.1 sigma)
#   Null 570: flux fraction = 0.2365 (33.1 sigma)
#   Null 571: flux fraction = 0.2365 (33.1 sigma)
#   Null 572: flux fraction = 0.2365 (33.1 sigma)
#   Null 573: flux fraction = 0.2365 (33.1 sigma)
#   Null 574: flux fraction = 0.2365 (33.1 sigma)
#   Null 575: flux fraction = 0.2365 (33.1 sigma)
#   Null 576: flux fraction = 0.2365 (33.1 sigma)
#   Null 577: flux fraction = 0.2365 (33.1 sigma)
#   Null 578: flux fraction = 0.2365 (33.1 sigma)
#   Null 579: flux fraction = 0.2365 (33.1 sigma)
#   Null 580: flux fraction = 0.2365 (33.1 sigma)
#   Null 581: flux fraction = 0.2325 (30.4 sigma)
#   Null 582: flux fraction = 0.2325 (30.4 sigma)
#   Null 583: flux fraction = 0.2306 (31.3 sigma)
#   Null 584: flux fraction = 0.2306 (31.3 sigma)
#   Null 585: flux fraction = 0.2306 (31.3 sigma)
#   Null 586: flux fraction = 0.2294 (31.2 sigma)
#   Null 587: flux fraction = 0.2294 (31.2 sigma)
#   Null 588: flux fraction = 0.2294 (31.2 sigma)
#   Null 589: flux fraction = 0.2294 (31.2 sigma)
#   Null 590: flux fraction = 0.2294 (31.2 sigma)
#   Null 591: flux fraction = 0.2317 (29.4 sigma)
#   Null 592: flux fraction = 0.2381 (32.8 sigma)
#   Null 593: flux fraction = 0.2510 (36.1 sigma)
#   Null 594: flux fraction = 0.2538 (37.8 sigma)
#   Null 595: flux fraction = 0.2538 (37.8 sigma)
#   Null 596: flux fraction = 0.2538 (37.8 sigma)
#   Null 597: flux fraction = 0.2538 (37.8 sigma)
#   Null 598: flux fraction = 0.2538 (37.8 sigma)
#   Null 599: flux fraction = 0.2538 (37.8 sigma)
#   Null 600: flux fraction = 0.2538 (37.8 sigma)
#   Null 601: flux fraction = 0.2538 (37.8 sigma)
#   Null 602: flux fraction = 0.2538 (37.8 sigma)
#   Null 603: flux fraction = 0.2538 (37.8 sigma)
#   Null 604: flux fraction = 0.2538 (37.8 sigma)
#   Null 605: flux fraction = 0.2538 (37.8 sigma)
#   Null 606: flux fraction = 0.2538 (37.8 sigma)
#   Null 607: flux fraction = 0.2538 (37.8 sigma)
#   Null 608: flux fraction = 0.2538 (37.8 sigma)
#   Null 609: flux fraction = 0.2538 (37.8 sigma)
#   Null 610: flux fraction = 0.2538 (37.8 sigma)
#   Null 611: flux fraction = 0.2538 (37.8 sigma)
#   Null 612: flux fraction = 0.2538 (37.8 sigma)
#   Null 613: flux fraction = 0.2538 (37.8 sigma)
#   Null 614: flux fraction = 0.2538 (37.8 sigma)
#   Null 615: flux fraction = 0.2538 (37.8 sigma)
#   Null 616: flux fraction = 0.2538 (37.8 sigma)
#   Null 617: flux fraction = 0.2538 (37.8 sigma)
#   Null 618: flux fraction = 0.2538 (37.8 sigma)
#   Null 619: flux fraction = 0.2538 (37.8 sigma)
#   Null 620: flux fraction = 0.2538 (37.8 sigma)
#   Null 621: flux fraction = 0.2538 (37.8 sigma)
#   Null 622: flux fraction = 0.2538 (37.8 sigma)
#   Null 623: flux fraction = 0.2538 (37.8 sigma)
#   Null 624: flux fraction = 0.2538 (37.8 sigma)
#   Null 625: flux fraction = 0.2538 (37.8 sigma)
#   Null 626: flux fraction = 0.2538 (37.8 sigma)
#   Null 627: flux fraction = 0.2538 (37.8 sigma)
#   Null 628: flux fraction = 0.2538 (37.8 sigma)
#   Null 629: flux fraction = 0.2538 (37.8 sigma)
#   Null 630: flux fraction = 0.2538 (37.8 sigma)
#   Null 631: flux fraction = 0.2538 (37.8 sigma)
#   Null 632: flux fraction = 0.2538 (37.8 sigma)
#   Null 633: flux fraction = 0.2538 (37.8 sigma)
#   Null 634: flux fraction = 0.2538 (37.8 sigma)
#   Null 635: flux fraction = 0.2538 (37.8 sigma)
#   Null 636: flux fraction = 0.2538 (37.8 sigma)
#   Null 637: flux fraction = 0.2538 (37.8 sigma)
#   Null 638: flux fraction = 0.2538 (37.8 sigma)
#   Null 639: flux fraction = 0.2538 (37.8 sigma)
#   Null 640: flux fraction = 0.2538 (37.8 sigma)
#   Null 641: flux fraction = 0.2538 (37.8 sigma)
#   Null 642: flux fraction = 0.2538 (37.8 sigma)
#   Null 643: flux fraction = 0.2538 (37.8 sigma)
#   Null 644: flux fraction = 0.2538 (37.8 sigma)
#   Null 645: flux fraction = 0.2538 (37.8 sigma)
#   Null 646: flux fraction = 0.2538 (37.8 sigma)
#   Null 647: flux fraction = 0.2538 (37.8 sigma)
#   Null 648: flux fraction = 0.2538 (37.8 sigma)
#   Null 649: flux fraction = 0.2538 (37.8 sigma)
#   Null 650: flux fraction = 0.2452 (35.7 sigma)
#   Null 651: flux fraction = 0.2452 (35.7 sigma)
#   Null 652: flux fraction = 0.2452 (35.7 sigma)
#   Null 653: flux fraction = 0.2452 (35.7 sigma)
#   Null 654: flux fraction = 0.2452 (35.7 sigma)
#   Null 655: flux fraction = 0.2452 (35.7 sigma)
#   Null 656: flux fraction = 0.2452 (35.7 sigma)
#   Null 657: flux fraction = 0.2452 (35.7 sigma)
#   Null 658: flux fraction = 0.2452 (35.7 sigma)
#   Null 659: flux fraction = 0.2452 (35.7 sigma)
#   Null 660: flux fraction = 0.2452 (35.7 sigma)
#   Null 661: flux fraction = 0.2452 (35.7 sigma)
#   Null 662: flux fraction = 0.2452 (35.7 sigma)
#   Null 663: flux fraction = 0.2452 (35.7 sigma)
#   Null 664: flux fraction = 0.2452 (35.7 sigma)
#   Null 665: flux fraction = 0.2436 (35.6 sigma)
#   Null 666: flux fraction = 0.2436 (35.6 sigma)
#   Null 667: flux fraction = 0.2436 (35.6 sigma)
#   Null 668: flux fraction = 0.2436 (35.6 sigma)
#   Null 669: flux fraction = 0.2436 (35.6 sigma)
#   Null 670: flux fraction = 0.2426 (35.4 sigma)
#   Null 671: flux fraction = 0.2403 (34.4 sigma)
#   Null 672: flux fraction = 0.2403 (34.4 sigma)
#   Null 673: flux fraction = 0.2403 (34.4 sigma)
#   Null 674: flux fraction = 0.2403 (34.4 sigma)
#   Null 675: flux fraction = 0.2403 (34.4 sigma)
#   Null 676: flux fraction = 0.2403 (34.4 sigma)
#   Null 677: flux fraction = 0.2403 (34.4 sigma)
#   Null 678: flux fraction = 0.2403 (34.4 sigma)
#   Null 679: flux fraction = 0.2403 (34.4 sigma)
#   Null 680: flux fraction = 0.2403 (34.4 sigma)
#   Null 681: flux fraction = 0.2403 (34.4 sigma)
#   Null 682: flux fraction = 0.2403 (34.4 sigma)
#   Null 683: flux fraction = 0.2403 (34.4 sigma)
#   Null 684: flux fraction = 0.2378 (34.8 sigma)
#   Null 685: flux fraction = 0.2365 (34.3 sigma)
#   Null 686: flux fraction = 0.2365 (34.3 sigma)
#   Null 687: flux fraction = 0.2356 (33.0 sigma)
#   Null 688: flux fraction = 0.2356 (33.0 sigma)
#   Null 689: flux fraction = 0.2356 (33.0 sigma)
#   Null 690: flux fraction = 0.2341 (32.8 sigma)
#   Null 691: flux fraction = 0.2307 (30.1 sigma)
#   Null 692: flux fraction = 0.2307 (30.1 sigma)
#   Null 693: flux fraction = 0.2307 (30.1 sigma)
#   Null 694: flux fraction = 0.2307 (30.1 sigma)
#   Null 695: flux fraction = 0.2307 (30.1 sigma)
#   Null 696: flux fraction = 0.2307 (30.1 sigma)
#   Null 697: flux fraction = 0.2307 (30.1 sigma)
#   Null 698: flux fraction = 0.2307 (30.1 sigma)
#   Null 699: flux fraction = 0.2307 (30.1 sigma)
#   Null 700: flux fraction = 0.2272 (30.2 sigma)
#   Null 701: flux fraction = 0.2272 (30.2 sigma)
#   Null 702: flux fraction = 0.2236 (29.0 sigma)
#   Null 703: flux fraction = 0.2230 (29.5 sigma)
#   Null 704: flux fraction = 0.2216 (29.2 sigma)
#   Null 705: flux fraction = 0.2216 (29.2 sigma)
#   Null 706: flux fraction = 0.2216 (29.2 sigma)
#   Null 707: flux fraction = 0.2204 (29.2 sigma)
#   Null 708: flux fraction = 0.2187 (28.5 sigma)
#   Null 709: flux fraction = 0.2187 (28.5 sigma)
#   Null 710: flux fraction = 0.2187 (28.5 sigma)
#   Null 711: flux fraction = 0.2187 (28.5 sigma)
#   Null 712: flux fraction = 0.2174 (27.2 sigma)
#   Null 713: flux fraction = 0.2174 (27.2 sigma)
#   Null 714: flux fraction = 0.2174 (27.2 sigma)
#   Null 715: flux fraction = 0.2152 (27.6 sigma)
#   Null 716: flux fraction = 0.2148 (27.4 sigma)
#   Null 717: flux fraction = 0.2077 (25.8 sigma)
#   Null 718: flux fraction = 0.2073 (25.5 sigma)
#   Null 719: flux fraction = 0.2045 (23.2 sigma)
#   Null 720: flux fraction = 0.2045 (23.2 sigma)
#   Null 721: flux fraction = 0.2045 (23.2 sigma)
#   Null 722: flux fraction = 0.2045 (23.2 sigma)
#   Null 723: flux fraction = 0.2045 (23.2 sigma)
#   Null 724: flux fraction = 0.2045 (23.2 sigma)
#   Null 725: flux fraction = 0.2045 (23.2 sigma)
#   Null 726: flux fraction = 0.2045 (23.2 sigma)
#   Null 727: flux fraction = 0.2045 (23.2 sigma)
#   Null 728: flux fraction = 0.2045 (23.2 sigma)
#   Null 729: flux fraction = 0.2031 (22.1 sigma)
#   Null 730: flux fraction = 0.2023 (22.8 sigma)
#   Null 731: flux fraction = 0.1999 (21.8 sigma)
#   Null 732: flux fraction = 0.1996 (20.7 sigma)
#   Null 733: flux fraction = 0.1996 (20.7 sigma)
#   Null 734: flux fraction = 0.1996 (20.7 sigma)
#   Null 735: flux fraction = 0.1996 (20.7 sigma)
#   Null 736: flux fraction = 0.1986 (21.6 sigma)
#   Null 737: flux fraction = 0.1986 (21.6 sigma)
#   Null 738: flux fraction = 0.1978 (20.9 sigma)
#   Null 739: flux fraction = 0.1978 (20.9 sigma)
#   Null 740: flux fraction = 0.1978 (20.9 sigma)
#   Null 741: flux fraction = 0.1978 (20.9 sigma)
#   Null 742: flux fraction = 0.1978 (20.9 sigma)
#   Null 743: flux fraction = 0.1978 (20.9 sigma)
#   Null 744: flux fraction = 0.1978 (20.9 sigma)
#   Null 745: flux fraction = 0.1962 (20.4 sigma)
#   Null 746: flux fraction = 0.0938 (25.1 sigma)
#   Null 747: flux fraction = 0.0938 (25.1 sigma)
#   Null 748: flux fraction = 0.0922 (26.6 sigma)
#   Null 749: flux fraction = 0.0916 (26.5 sigma)
#   Null 750: flux fraction = 0.0903 (27.8 sigma)
#   Null 751: flux fraction = 0.0903 (27.8 sigma)
#   Null 752: flux fraction = 0.0903 (27.8 sigma)
#   Null 753: flux fraction = 0.0903 (27.8 sigma)
#   Null 754: flux fraction = 0.0903 (27.8 sigma)
#   Null 755: flux fraction = 0.0903 (27.8 sigma)
#   Null 756: flux fraction = 0.0903 (27.8 sigma)
#   Null 757: flux fraction = 0.0893 (27.5 sigma)
#   Null 758: flux fraction = 0.0878 (28.2 sigma)
#   Null 759: flux fraction = 0.0878 (28.2 sigma)
#   Null 760: flux fraction = 0.0878 (28.2 sigma)
#   Null 761: flux fraction = 0.0878 (28.2 sigma)
#   Null 762: flux fraction = 0.0878 (28.2 sigma)
#   Null 763: flux fraction = 0.0878 (28.2 sigma)
#   Null 764: flux fraction = 0.0878 (28.2 sigma)
#   Null 765: flux fraction = 0.0878 (28.2 sigma)
#   Null 766: flux fraction = 0.0878 (28.2 sigma)
#   Null 767: flux fraction = 0.0878 (28.2 sigma)
#   Null 768: flux fraction = 0.0878 (28.2 sigma)
#   Null 769: flux fraction = 0.0878 (28.2 sigma)
#   Null 770: flux fraction = 0.0878 (28.2 sigma)
#   Null 771: flux fraction = 0.0878 (28.2 sigma)
#   Null 772: flux fraction = 0.0878 (28.2 sigma)
#   Null 773: flux fraction = 0.0878 (28.2 sigma)
#   Null 774: flux fraction = 0.0878 (28.2 sigma)
#   Null 775: flux fraction = 0.0862 (30.3 sigma)
#   Null 776: flux fraction = 0.0862 (30.3 sigma)
#   Null 777: flux fraction = 0.0862 (30.3 sigma)
#   Null 778: flux fraction = 0.0855 (29.5 sigma)
#   Null 779: flux fraction = 0.0855 (29.5 sigma)
#   Null 780: flux fraction = 0.0838 (31.0 sigma)
#   Null 781: flux fraction = 0.0838 (31.0 sigma)
#   Null 782: flux fraction = 0.0838 (31.0 sigma)
#   Null 783: flux fraction = 0.0838 (31.0 sigma)
#   Null 784: flux fraction = 0.0838 (31.0 sigma)
#   Null 785: flux fraction = 0.0838 (31.0 sigma)
#   Null 786: flux fraction = 0.0838 (31.0 sigma)
#   Null 787: flux fraction = 0.0838 (31.0 sigma)
#   Null 788: flux fraction = 0.0838 (31.0 sigma)
#   Null 789: flux fraction = 0.0838 (31.0 sigma)
#   Null 790: flux fraction = 0.0838 (31.0 sigma)
#   Null 791: flux fraction = 0.0838 (31.0 sigma)
#   Null 792: flux fraction = 0.0838 (31.0 sigma)
#   Null 793: flux fraction = 0.0812 (32.9 sigma)
#   Null 794: flux fraction = 0.0812 (32.9 sigma)
#   Null 795: flux fraction = 0.0800 (33.0 sigma)
#   Null 796: flux fraction = 0.0800 (33.0 sigma)
#   Null 797: flux fraction = 0.0800 (33.0 sigma)
#   Null 798: flux fraction = 0.0800 (33.0 sigma)
#   Null 799: flux fraction = 0.0800 (33.0 sigma)
#   Null 800: flux fraction = 0.0800 (33.0 sigma)
#   Null 801: flux fraction = 0.0800 (33.0 sigma)
#   Null 802: flux fraction = 0.0800 (33.0 sigma)
#   Null 803: flux fraction = 0.0800 (33.0 sigma)
#   Null 804: flux fraction = 0.0800 (33.0 sigma)
#   Null 805: flux fraction = 0.0800 (33.0 sigma)
#   Null 806: flux fraction = 0.0800 (33.0 sigma)
#   Null 807: flux fraction = 0.0800 (33.0 sigma)
#   Null 808: flux fraction = 0.0744 (39.3 sigma)
#   Null 809: flux fraction = 0.0744 (39.3 sigma)
#   Null 810: flux fraction = 0.0744 (39.3 sigma)
#   Null 811: flux fraction = 0.0737 (37.3 sigma)
#   Null 812: flux fraction = 0.0737 (37.3 sigma)
#   Null 813: flux fraction = 0.0737 (37.3 sigma)
#   Null 814: flux fraction = 0.0737 (37.3 sigma)
#   Null 815: flux fraction = 0.0737 (37.3 sigma)
#   Null 816: flux fraction = 0.0737 (37.3 sigma)
#   Null 817: flux fraction = 0.0737 (37.3 sigma)
#   Null 818: flux fraction = 0.0737 (37.3 sigma)
#   Null 819: flux fraction = 0.0737 (37.3 sigma)
#   Null 820: flux fraction = 0.0737 (37.3 sigma)
#   Null 821: flux fraction = 0.0737 (37.3 sigma)
#   Null 822: flux fraction = 0.0737 (37.3 sigma)
#   Null 823: flux fraction = 0.0737 (37.3 sigma)
#   Null 824: flux fraction = 0.0737 (37.3 sigma)
#   Null 825: flux fraction = 0.0737 (37.3 sigma)
#   Null 826: flux fraction = 0.0737 (37.3 sigma)
#   Null 827: flux fraction = 0.0737 (37.3 sigma)
#   Null 828: flux fraction = 0.0739 (38.9 sigma)
#   Null 829: flux fraction = 0.0739 (38.9 sigma)
#   Null 830: flux fraction = 0.0739 (38.9 sigma)
#   Null 831: flux fraction = 0.0739 (38.9 sigma)
#   Null 832: flux fraction = 0.0739 (38.9 sigma)
#   Null 833: flux fraction = 0.0745 (37.7 sigma)
#   Null 834: flux fraction = 0.0749 (38.7 sigma)
#   Null 835: flux fraction = 0.0749 (38.7 sigma)
#   Null 836: flux fraction = 0.0749 (38.7 sigma)
#   Null 837: flux fraction = 0.0751 (38.7 sigma)
#   Null 838: flux fraction = 0.0759 (36.8 sigma)
#   Null 839: flux fraction = 0.0759 (36.8 sigma)
#   Null 840: flux fraction = 0.0753 (38.3 sigma)
#   Null 841: flux fraction = 0.0753 (38.3 sigma)
#   Null 842: flux fraction = 0.0753 (38.3 sigma)
#   Null 843: flux fraction = 0.0753 (38.3 sigma)
#   Null 844: flux fraction = 0.0753 (38.3 sigma)
#   Null 845: flux fraction = 0.0753 (38.3 sigma)
#   Null 846: flux fraction = 0.0753 (38.3 sigma)
#   Null 847: flux fraction = 0.0753 (38.3 sigma)
#   Null 848: flux fraction = 0.0753 (38.3 sigma)
#   Null 849: flux fraction = 0.0753 (38.3 sigma)
#   Null 850: flux fraction = 0.0753 (38.3 sigma)
#   Null 851: flux fraction = 0.0753 (38.3 sigma)
#   Null 852: flux fraction = 0.0748 (37.5 sigma)
#   Null 853: flux fraction = 0.0748 (37.5 sigma)
#   Null 854: flux fraction = 0.0748 (37.5 sigma)
#   Null 855: flux fraction = 0.0747 (37.3 sigma)
#   Null 856: flux fraction = 0.0746 (37.7 sigma)
#   Null 857: flux fraction = 0.0746 (37.7 sigma)
#   Null 858: flux fraction = 0.0746 (37.7 sigma)
#   Null 859: flux fraction = 0.0746 (37.7 sigma)
#   Null 860: flux fraction = 0.0733 (38.9 sigma)
#   Null 861: flux fraction = 0.0733 (38.9 sigma)
#   Null 862: flux fraction = 0.0733 (38.9 sigma)
#   Null 863: flux fraction = 0.0733 (38.9 sigma)
#   Null 864: flux fraction = 0.0693 (40.0 sigma)
#   Null 865: flux fraction = 0.0693 (40.0 sigma)
#   Null 866: flux fraction = 0.0693 (40.0 sigma)
#   Null 867: flux fraction = 0.0709 (40.6 sigma)
#   Null 868: flux fraction = 0.0709 (40.6 sigma)
#   Null 869: flux fraction = 0.0709 (40.6 sigma)
#   Null 870: flux fraction = 0.0723 (38.9 sigma)
#   Null 871: flux fraction = 0.0723 (38.9 sigma)
#   Null 872: flux fraction = 0.0732 (37.8 sigma)
#   Null 873: flux fraction = 0.0732 (37.8 sigma)
#   Null 874: flux fraction = 0.0752 (37.1 sigma)
#   Null 875: flux fraction = 0.0754 (36.5 sigma)
#   Null 876: flux fraction = 0.0754 (36.5 sigma)
#   Null 877: flux fraction = 0.0754 (36.5 sigma)
#   Null 878: flux fraction = 0.0754 (36.5 sigma)
#   Null 879: flux fraction = 0.0758 (37.7 sigma)
#   Null 880: flux fraction = 0.0755 (36.6 sigma)
#   Null 881: flux fraction = 0.0743 (39.4 sigma)
#   Null 882: flux fraction = 0.0735 (40.1 sigma)
#   Null 883: flux fraction = 0.0725 (36.8 sigma)
#   Null 884: flux fraction = 0.0725 (36.8 sigma)
#   Null 885: flux fraction = 0.0745 (37.9 sigma)
#   Null 886: flux fraction = 0.0761 (36.8 sigma)
#   Null 887: flux fraction = 0.0761 (36.8 sigma)
#   Null 888: flux fraction = 0.0763 (36.5 sigma)
#   Null 889: flux fraction = 0.0764 (35.5 sigma)
#   Null 890: flux fraction = 0.0771 (35.8 sigma)
#   Null 891: flux fraction = 0.0771 (35.8 sigma)
#   Null 892: flux fraction = 0.0781 (33.7 sigma)
#   Null 893: flux fraction = 0.0797 (33.3 sigma)
#   Null 894: flux fraction = 0.0799 (35.2 sigma)
#   Null 895: flux fraction = 0.0799 (35.2 sigma)
#   Null 896: flux fraction = 0.0799 (35.2 sigma)
#   Null 897: flux fraction = 0.0776 (36.0 sigma)
#   Null 898: flux fraction = 0.0757 (36.1 sigma)
#   Null 899: flux fraction = 0.0752 (36.0 sigma)
#   Null 900: flux fraction = 0.0747 (36.2 sigma)
#   Null 901: flux fraction = 0.0770 (36.5 sigma)
#   Null 902: flux fraction = 0.0744 (37.6 sigma)
#   Null 903: flux fraction = 0.0799 (32.2 sigma)
#   Null 904: flux fraction = 0.0776 (36.0 sigma)
#   Null 905: flux fraction = 0.0799 (35.2 sigma)
#   Null 906: flux fraction = 0.0793 (33.8 sigma)
#   Null 907: flux fraction = 0.0793 (34.1 sigma)
#   Null 908: flux fraction = 0.0771 (35.8 sigma)
#   Null 909: flux fraction = 0.0764 (35.5 sigma)
#   Null 910: flux fraction = 0.0763 (36.5 sigma)
#   Null 911: flux fraction = 0.0763 (36.5 sigma)
#   Null 912: flux fraction = 0.0761 (36.8 sigma)
#   Null 913: flux fraction = 0.0761 (36.8 sigma)
#   Null 914: flux fraction = 0.0761 (36.8 sigma)
#   Null 915: flux fraction = 0.0761 (36.8 sigma)
#   Null 916: flux fraction = 0.0751 (32.9 sigma)
#   Null 917: flux fraction = 0.0748 (34.3 sigma)
#   Null 918: flux fraction = 0.0748 (34.3 sigma)
#   Null 919: flux fraction = 0.0748 (34.3 sigma)
#   Null 920: flux fraction = 0.0747 (34.6 sigma)
#   Null 921: flux fraction = 0.0747 (34.6 sigma)
#   Null 922: flux fraction = 0.0730 (36.8 sigma)
#   Null 923: flux fraction = 0.0725 (36.8 sigma)
#   Null 924: flux fraction = 0.0725 (36.8 sigma)
#   Null 925: flux fraction = 0.0725 (36.8 sigma)
#   Null 926: flux fraction = 0.0725 (36.8 sigma)
#   Null 927: flux fraction = 0.0725 (36.8 sigma)
#   Null 928: flux fraction = 0.0725 (36.8 sigma)
#   Null 929: flux fraction = 0.0725 (36.8 sigma)
#   Null 930: flux fraction = 0.0743 (39.4 sigma)
#   Null 931: flux fraction = 0.0758 (37.7 sigma)
#   Null 932: flux fraction = 0.0758 (37.7 sigma)
#   Null 933: flux fraction = 0.0754 (36.5 sigma)
#   Null 934: flux fraction = 0.0754 (36.5 sigma)
#   Null 935: flux fraction = 0.0752 (37.1 sigma)
#   Null 936: flux fraction = 0.0752 (37.1 sigma)
#   Null 937: flux fraction = 0.0744 (37.6 sigma)
#   Null 938: flux fraction = 0.0723 (38.9 sigma)
#   Null 939: flux fraction = 0.0723 (38.9 sigma)
#   Null 940: flux fraction = 0.0714 (40.3 sigma)
#   Null 941: flux fraction = 0.0709 (40.6 sigma)
#   Null 942: flux fraction = 0.0709 (40.6 sigma)
#   Null 943: flux fraction = 0.0709 (40.6 sigma)
#   Null 944: flux fraction = 0.0709 (40.6 sigma)
#   Null 945: flux fraction = 0.0693 (40.0 sigma)
#   Null 946: flux fraction = 0.0693 (40.0 sigma)
#   Null 947: flux fraction = 0.0693 (40.0 sigma)
#   Null 948: flux fraction = 0.0693 (40.0 sigma)
#   Null 949: flux fraction = 0.0693 (40.0 sigma)
#   Null 950: flux fraction = 0.0733 (38.9 sigma)
#   Null 951: flux fraction = 0.0733 (38.9 sigma)
#   Null 952: flux fraction = 0.0733 (38.9 sigma)
#   Null 953: flux fraction = 0.0746 (37.7 sigma)
#   Null 954: flux fraction = 0.0746 (37.7 sigma)
#   Null 955: flux fraction = 0.0748 (37.5 sigma)
#   Null 956: flux fraction = 0.0748 (37.5 sigma)
#   Null 957: flux fraction = 0.0753 (36.7 sigma)
#   Null 958: flux fraction = 0.0753 (38.3 sigma)
#   Null 959: flux fraction = 0.0753 (38.3 sigma)
#   Null 960: flux fraction = 0.0753 (38.3 sigma)
#   Null 961: flux fraction = 0.0753 (38.3 sigma)
#   Null 962: flux fraction = 0.0753 (38.3 sigma)
#   Null 963: flux fraction = 0.0753 (38.3 sigma)
#   Null 964: flux fraction = 0.0753 (38.3 sigma)
#   Null 965: flux fraction = 0.0753 (38.3 sigma)
#   Null 966: flux fraction = 0.0753 (38.3 sigma)
#   Null 967: flux fraction = 0.0753 (38.3 sigma)
#   Null 968: flux fraction = 0.0759 (36.8 sigma)
#   Null 969: flux fraction = 0.0759 (36.8 sigma)
#   Null 970: flux fraction = 0.0749 (38.7 sigma)
#   Null 971: flux fraction = 0.0749 (38.7 sigma)
#   Null 972: flux fraction = 0.0745 (37.7 sigma)
#   Null 973: flux fraction = 0.0745 (37.7 sigma)
#   Null 974: flux fraction = 0.0739 (38.9 sigma)
#   Null 975: flux fraction = 0.0739 (38.9 sigma)
#   Null 976: flux fraction = 0.0739 (38.9 sigma)
#   Null 977: flux fraction = 0.0737 (37.3 sigma)
#   Null 978: flux fraction = 0.0737 (37.3 sigma)
#   Null 979: flux fraction = 0.0737 (37.3 sigma)
#   Null 980: flux fraction = 0.0737 (37.3 sigma)
#   Null 981: flux fraction = 0.0737 (37.3 sigma)
#   Null 982: flux fraction = 0.0737 (37.3 sigma)
#   Null 983: flux fraction = 0.0737 (37.3 sigma)
#   Null 984: flux fraction = 0.0737 (37.3 sigma)
#   Null 985: flux fraction = 0.0737 (37.3 sigma)
#   Null 986: flux fraction = 0.0737 (37.3 sigma)
#   Null 987: flux fraction = 0.0737 (37.3 sigma)
#   Null 988: flux fraction = 0.0737 (37.3 sigma)
#   Null 989: flux fraction = 0.0737 (37.3 sigma)
#   Null 990: flux fraction = 0.0737 (37.3 sigma)
#   Null 991: flux fraction = 0.0737 (37.3 sigma)
#   Null 992: flux fraction = 0.0737 (37.3 sigma)
#   Null 993: flux fraction = 0.0744 (39.3 sigma)
#   Null 994: flux fraction = 0.0744 (39.3 sigma)
#   Null 995: flux fraction = 0.0744 (39.3 sigma)
#   Null 996: flux fraction = 0.0744 (39.3 sigma)
#   Null 997: flux fraction = 0.0744 (39.3 sigma)
#   Null 998: flux fraction = 0.0744 (39.3 sigma)
#   Null 999: flux fraction = 0.0764 (37.8 sigma)
#   Null 1000: flux fraction = 0.0764 (37.8 sigma)
#   Null 1001: flux fraction = 0.0764 (37.8 sigma)
#   Null 1002: flux fraction = 0.0793 (33.1 sigma)
#   Null 1003: flux fraction = 0.0793 (33.1 sigma)
#   Null 1004: flux fraction = 0.0800 (33.0 sigma)
#   Null 1005: flux fraction = 0.0800 (33.0 sigma)
#   Null 1006: flux fraction = 0.0800 (33.0 sigma)
#   Null 1007: flux fraction = 0.0800 (33.0 sigma)
#   Null 1008: flux fraction = 0.0800 (33.0 sigma)
#   Null 1009: flux fraction = 0.0800 (33.0 sigma)
#   Null 1010: flux fraction = 0.0800 (33.0 sigma)
#   Null 1011: flux fraction = 0.0800 (33.0 sigma)
#   Null 1012: flux fraction = 0.0800 (33.0 sigma)
#   Null 1013: flux fraction = 0.0800 (33.0 sigma)
#   Null 1014: flux fraction = 0.0800 (33.0 sigma)
#   Null 1015: flux fraction = 0.0800 (33.0 sigma)
#   Null 1016: flux fraction = 0.0800 (33.0 sigma)
#   Null 1017: flux fraction = 0.0800 (33.0 sigma)
#   Null 1018: flux fraction = 0.0800 (33.0 sigma)
#   Null 1019: flux fraction = 0.0800 (33.0 sigma)
#   Null 1020: flux fraction = 0.0800 (33.0 sigma)
#   Null 1021: flux fraction = 0.0802 (33.1 sigma)
#   Null 1022: flux fraction = 0.0812 (32.9 sigma)
#   Null 1023: flux fraction = 0.0812 (32.9 sigma)
#   Null 1024: flux fraction = 0.0812 (32.9 sigma)
#   Null 1025: flux fraction = 0.0822 (32.5 sigma)
#   Null 1026: flux fraction = 0.0838 (31.0 sigma)
#   Null 1027: flux fraction = 0.0838 (31.0 sigma)
#   Null 1028: flux fraction = 0.0838 (31.0 sigma)
#   Null 1029: flux fraction = 0.0838 (31.0 sigma)
#   Null 1030: flux fraction = 0.0838 (31.0 sigma)
#   Null 1031: flux fraction = 0.0838 (31.0 sigma)
#   Null 1032: flux fraction = 0.0838 (31.0 sigma)
#   Null 1033: flux fraction = 0.0838 (31.0 sigma)
#   Null 1034: flux fraction = 0.0838 (31.0 sigma)
#   Null 1035: flux fraction = 0.0838 (31.0 sigma)
#   Null 1036: flux fraction = 0.0838 (31.0 sigma)
#   Null 1037: flux fraction = 0.0838 (31.0 sigma)
#   Null 1038: flux fraction = 0.0838 (31.0 sigma)
#   Null 1039: flux fraction = 0.0838 (31.0 sigma)
#   Null 1040: flux fraction = 0.0838 (31.0 sigma)
#   Null 1041: flux fraction = 0.0838 (31.0 sigma)
#   Null 1042: flux fraction = 0.0838 (31.0 sigma)
#   Null 1043: flux fraction = 0.0838 (31.0 sigma)
#   Null 1044: flux fraction = 0.0838 (31.0 sigma)
#   Null 1045: flux fraction = 0.0855 (29.5 sigma)
#   Null 1046: flux fraction = 0.0855 (29.5 sigma)
#   Null 1047: flux fraction = 0.0855 (29.5 sigma)
#   Null 1048: flux fraction = 0.0855 (29.5 sigma)
#   Null 1049: flux fraction = 0.0862 (30.3 sigma)
#   Null 1050: flux fraction = 0.0878 (28.2 sigma)
#   Null 1051: flux fraction = 0.0878 (28.2 sigma)
#   Null 1052: flux fraction = 0.0878 (28.2 sigma)
#   Null 1053: flux fraction = 0.0878 (28.2 sigma)
#   Null 1054: flux fraction = 0.0878 (28.2 sigma)
#   Null 1055: flux fraction = 0.0878 (28.2 sigma)
#   Null 1056: flux fraction = 0.0878 (28.2 sigma)
#   Null 1057: flux fraction = 0.0878 (28.2 sigma)
#   Null 1058: flux fraction = 0.0878 (28.2 sigma)
#   Null 1059: flux fraction = 0.0878 (28.2 sigma)
#   Null 1060: flux fraction = 0.0878 (28.2 sigma)
#   Null 1061: flux fraction = 0.0878 (28.2 sigma)
#   Null 1062: flux fraction = 0.0878 (28.2 sigma)
#   Null 1063: flux fraction = 0.0878 (28.2 sigma)
#   Null 1064: flux fraction = 0.0878 (28.2 sigma)
#   Null 1065: flux fraction = 0.0878 (28.2 sigma)
#   Null 1066: flux fraction = 0.0878 (28.2 sigma)
#   Null 1067: flux fraction = 0.0878 (28.2 sigma)
#   Null 1068: flux fraction = 0.0878 (28.2 sigma)
#   Null 1069: flux fraction = 0.0878 (28.2 sigma)
#   Null 1070: flux fraction = 0.0878 (28.2 sigma)
#   Null 1071: flux fraction = 0.0878 (28.2 sigma)
#   Null 1072: flux fraction = 0.0903 (27.8 sigma)
#   Null 1073: flux fraction = 0.0903 (27.8 sigma)
#   Null 1074: flux fraction = 0.0903 (27.8 sigma)
#   Null 1075: flux fraction = 0.0903 (27.8 sigma)
#   Null 1076: flux fraction = 0.0909 (26.4 sigma)
#   Null 1077: flux fraction = 0.0909 (26.4 sigma)
#   Null 1078: flux fraction = 0.0909 (26.4 sigma)
#   Null 1079: flux fraction = 0.0914 (26.4 sigma)
#   Null 1080: flux fraction = 0.0916 (26.5 sigma)
#   Null 1081: flux fraction = 0.0916 (26.5 sigma)
#   Null 1082: flux fraction = 0.0922 (26.6 sigma)
#   Null 1083: flux fraction = 0.1978 (20.9 sigma)
#   Null 1084: flux fraction = 0.1978 (20.9 sigma)
#   Null 1085: flux fraction = 0.1978 (20.9 sigma)
#   Null 1086: flux fraction = 0.1978 (20.9 sigma)
#   Null 1087: flux fraction = 0.1978 (20.9 sigma)
#   Null 1088: flux fraction = 0.1978 (20.9 sigma)
#   Null 1089: flux fraction = 0.1978 (20.9 sigma)
#   Null 1090: flux fraction = 0.1978 (20.9 sigma)
#   Null 1091: flux fraction = 0.1978 (20.9 sigma)
#   Null 1092: flux fraction = 0.1978 (20.9 sigma)
#   Null 1093: flux fraction = 0.1986 (21.6 sigma)
#   Null 1094: flux fraction = 0.1996 (20.7 sigma)
#   Null 1095: flux fraction = 0.1999 (21.8 sigma)
#   Null 1096: flux fraction = 0.2000 (21.1 sigma)
#   Null 1097: flux fraction = 0.2012 (22.7 sigma)
#   Null 1098: flux fraction = 0.2023 (22.8 sigma)
#   Null 1099: flux fraction = 0.2031 (22.1 sigma)
#   Null 1100: flux fraction = 0.2045 (23.2 sigma)
#   Null 1101: flux fraction = 0.2045 (23.2 sigma)
#   Null 1102: flux fraction = 0.2045 (23.2 sigma)
#   Null 1103: flux fraction = 0.2045 (23.2 sigma)
#   Null 1104: flux fraction = 0.2045 (23.2 sigma)
#   Null 1105: flux fraction = 0.2045 (23.2 sigma)
#   Null 1106: flux fraction = 0.2045 (23.2 sigma)
#   Null 1107: flux fraction = 0.2073 (25.5 sigma)
#   Null 1108: flux fraction = 0.2073 (25.5 sigma)
#   Null 1109: flux fraction = 0.2090 (26.2 sigma)
#   Null 1110: flux fraction = 0.2148 (27.4 sigma)
#   Null 1111: flux fraction = 0.2152 (27.6 sigma)
#   Null 1112: flux fraction = 0.2152 (27.6 sigma)
#   Null 1113: flux fraction = 0.2174 (27.2 sigma)
#   Null 1114: flux fraction = 0.2174 (27.2 sigma)
#   Null 1115: flux fraction = 0.2187 (28.5 sigma)
#   Null 1116: flux fraction = 0.2187 (28.5 sigma)
#   Null 1117: flux fraction = 0.2230 (29.5 sigma)
#   Null 1118: flux fraction = 0.2230 (29.5 sigma)
#   Null 1119: flux fraction = 0.2272 (30.2 sigma)
#   Null 1120: flux fraction = 0.2307 (30.1 sigma)
#   Null 1121: flux fraction = 0.2307 (30.1 sigma)
#   Null 1122: flux fraction = 0.2307 (30.1 sigma)
#   Null 1123: flux fraction = 0.2307 (30.1 sigma)
#   Null 1124: flux fraction = 0.2307 (30.1 sigma)
#   Null 1125: flux fraction = 0.2307 (30.1 sigma)
#   Null 1126: flux fraction = 0.2307 (30.1 sigma)
#   Null 1127: flux fraction = 0.2307 (30.1 sigma)
#   Null 1128: flux fraction = 0.2307 (30.1 sigma)
#   Null 1129: flux fraction = 0.2307 (30.1 sigma)
#   Null 1130: flux fraction = 0.2307 (30.1 sigma)
#   Null 1131: flux fraction = 0.2365 (34.3 sigma)
#   Null 1132: flux fraction = 0.2365 (34.3 sigma)
#   Null 1133: flux fraction = 0.2401 (35.3 sigma)
#   Null 1134: flux fraction = 0.2403 (34.4 sigma)
#   Null 1135: flux fraction = 0.2403 (34.4 sigma)
#   Null 1136: flux fraction = 0.2403 (34.4 sigma)
#   Null 1137: flux fraction = 0.2403 (34.4 sigma)
#   Null 1138: flux fraction = 0.2403 (34.4 sigma)
#   Null 1139: flux fraction = 0.2403 (34.4 sigma)
#   Null 1140: flux fraction = 0.2403 (34.4 sigma)
#   Null 1141: flux fraction = 0.2403 (34.4 sigma)
#   Null 1142: flux fraction = 0.2403 (34.4 sigma)
#   Null 1143: flux fraction = 0.2403 (34.4 sigma)
#   Null 1144: flux fraction = 0.2403 (34.4 sigma)
#   Null 1145: flux fraction = 0.2428 (35.4 sigma)
#   Null 1146: flux fraction = 0.2436 (35.6 sigma)
#   Null 1147: flux fraction = 0.2436 (35.6 sigma)
#   Null 1148: flux fraction = 0.2436 (35.6 sigma)
#   Null 1149: flux fraction = 0.2436 (35.6 sigma)
#   Null 1150: flux fraction = 0.2436 (35.6 sigma)
#   Null 1151: flux fraction = 0.2444 (34.6 sigma)
#   Null 1152: flux fraction = 0.2452 (35.7 sigma)
#   Null 1153: flux fraction = 0.2452 (35.7 sigma)
#   Null 1154: flux fraction = 0.2452 (35.7 sigma)
#   Null 1155: flux fraction = 0.2452 (35.7 sigma)
#   Null 1156: flux fraction = 0.2452 (35.7 sigma)
#   Null 1157: flux fraction = 0.2452 (35.7 sigma)
#   Null 1158: flux fraction = 0.2452 (35.7 sigma)
#   Null 1159: flux fraction = 0.2452 (35.7 sigma)
#   Null 1160: flux fraction = 0.2452 (35.7 sigma)
#   Null 1161: flux fraction = 0.2452 (35.7 sigma)
#   Null 1162: flux fraction = 0.2452 (35.7 sigma)
#   Null 1163: flux fraction = 0.2452 (35.7 sigma)
#   Null 1164: flux fraction = 0.2452 (35.7 sigma)
#   Null 1165: flux fraction = 0.2452 (35.7 sigma)
#   Null 1166: flux fraction = 0.2452 (35.7 sigma)
#   Null 1167: flux fraction = 0.2452 (35.7 sigma)
#   Null 1168: flux fraction = 0.2452 (35.7 sigma)
#   Null 1169: flux fraction = 0.2538 (37.8 sigma)
#   Null 1170: flux fraction = 0.2538 (37.8 sigma)
#   Null 1171: flux fraction = 0.2538 (37.8 sigma)
#   Null 1172: flux fraction = 0.2538 (37.8 sigma)
#   Null 1173: flux fraction = 0.2538 (37.8 sigma)
#   Null 1174: flux fraction = 0.2538 (37.8 sigma)
#   Null 1175: flux fraction = 0.2538 (37.8 sigma)
#   Null 1176: flux fraction = 0.2538 (37.8 sigma)
#   Null 1177: flux fraction = 0.2538 (37.8 sigma)
#   Null 1178: flux fraction = 0.2538 (37.8 sigma)
#   Null 1179: flux fraction = 0.2538 (37.8 sigma)
#   Null 1180: flux fraction = 0.2538 (37.8 sigma)
#   Null 1181: flux fraction = 0.2538 (37.8 sigma)
#   Null 1182: flux fraction = 0.2538 (37.8 sigma)
#   Null 1183: flux fraction = 0.2538 (37.8 sigma)
#   Null 1184: flux fraction = 0.2538 (37.8 sigma)
#   Null 1185: flux fraction = 0.2538 (37.8 sigma)
#   Null 1186: flux fraction = 0.2538 (37.8 sigma)
#   Null 1187: flux fraction = 0.2538 (37.8 sigma)
#   Null 1188: flux fraction = 0.2538 (37.8 sigma)
#   Null 1189: flux fraction = 0.2538 (37.8 sigma)
#   Null 1190: flux fraction = 0.2538 (37.8 sigma)
#   Null 1191: flux fraction = 0.2538 (37.8 sigma)
#   Null 1192: flux fraction = 0.2538 (37.8 sigma)
#   Null 1193: flux fraction = 0.2538 (37.8 sigma)
#   Null 1194: flux fraction = 0.2538 (37.8 sigma)
#   Null 1195: flux fraction = 0.2538 (37.8 sigma)
#   Null 1196: flux fraction = 0.2538 (37.8 sigma)
#   Null 1197: flux fraction = 0.2538 (37.8 sigma)
#   Null 1198: flux fraction = 0.2538 (37.8 sigma)
#   Null 1199: flux fraction = 0.2538 (37.8 sigma)
# ============================================================
